# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import os
import sys
import importlib
import pandas as pd
import matplotlib.pyplot as plt

sys.path.append('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikewise/Action potential waveforms are state-dependent paper/AP_empirical_paper_all_analyses/datasets/spe-1/spe1_helper_modules/')
import spk_feat_cluster_comp_analysis
importlib.reload(spk_feat_cluster_comp_analysis)
from spk_feat_cluster_comp_analysis import (
    compile_experiment_results,
    plot_spike_to_avg_distances,
    plot_waveform_dist_kde,
    plot_spike_feat_value_within_vs_between,
    plot_pct_within_exceeds_between,
)
import config

CLUSTER_PKL_DIR = config.SPE1_PICKLE_ROOT + '/cluster_pickles/'
SPIKE_FIT_DIR   = config.SPE1_PICKLE_ROOT + '/spike_fit_pickles/'

# %%
df_master = compile_experiment_results(CLUSTER_PKL_DIR)

# %% [markdown]
# ## Panel A — Within vs between: full distribution (KDE, all spikes, whole waveform)

# %%
plot_waveform_dist_kde(df_master, wf_dir=CLUSTER_PKL_DIR, spike_fit_dir=SPIKE_FIT_DIR)

# %% [markdown]
# ## Panel B — Subgroups: whole-waveform nRMSE (within vs PC-PC, IN-IN, Juxta-Juxta, WC-WC)

# %%
plot_spike_to_avg_distances(
    df_master,
    wf_dir=CLUSTER_PKL_DIR,
    spike_fit_dir=SPIKE_FIT_DIR,
    half_win=75,
    metrics=['nRMSE'],
)
# Out:
# [spike_to_avg] cache HIT — loading
# /Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikewise/Action potential waveforms are state-dependent paper/AP_empirical_paper_all_analyses/datasets/spe-1/spe1_helper_modules/spk_feat_cluster_comp_analysis.py:3421: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(GROUP_ORDER, fontsize=_FS, ha='center', multialignment='center')
# ── nRMSE (spike-to-avg) ──
#   Within (all)          : median=0.076  IQR=[0.050, 0.133]  n=167006
#   Between (all)         : median=0.257  IQR=[0.189, 0.320]  n=200000
#   Between PC–PC         : median=0.263  IQR=[0.197, 0.324]  n=200000
#   Between IN–IN         : median=0.236  IQR=[0.178, 0.294]  n=200000
#   Between Juxta–Juxta   : median=0.241  IQR=[0.167, 0.303]  n=200000
#   Between WC–WC         : median=0.290  IQR=[0.211, 0.399]  n=77752

# %% [markdown]
# ## Panel C — Subgroups: whole-waveform cos sim

# %%
plot_spike_to_avg_distances(
    df_master,
    wf_dir=CLUSTER_PKL_DIR,
    spike_fit_dir=SPIKE_FIT_DIR,
    half_win=75,
    metrics=['Cos Sim'],
)
# Out:
# [spike_to_avg] cache HIT — loading
# /Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikewise/Action potential waveforms are state-dependent paper/AP_empirical_paper_all_analyses/datasets/spe-1/spe1_helper_modules/spk_feat_cluster_comp_analysis.py:3421: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(GROUP_ORDER, fontsize=_FS, ha='center', multialignment='center')
# ── Cos Sim (spike-to-avg) ──
#   Within (all)          : median=0.984  IQR=[0.965, 0.992]  n=167006
#   Between (all)         : median=0.762  IQR=[0.465, 0.903]  n=200000
#   Between PC–PC         : median=0.752  IQR=[0.477, 0.900]  n=200000
#   Between IN–IN         : median=0.828  IQR=[0.587, 0.908]  n=200000
#   Between Juxta–Juxta   : median=0.819  IQR=[0.614, 0.918]  n=200000
#   Between WC–WC         : median=0.953  IQR=[0.868, 0.979]  n=77752

# %% [markdown]
# ## Panel D — Per-feature: |spike value − cell mean| within vs between, in feature units

# %%
plot_spike_feat_value_within_vs_between(SPIKE_FIT_DIR)
# Out:
# Loaded 42 cells
#   ramp_amp: cache hit
#   inflection_amp: cache hit
#   inflection_time: cache hit
#   peak_amp: cache hit
#   peak_sharpness: cache hit
#   peak_width: cache hit
#   exp_lambda: cache hit
#   exp_const: cache hit
#   log_isi: cache hit

# %% [markdown]
# ## Panel E — % of within-cell spikes exceeding mean between-cell distance (per metric + feature)

# %%
plot_pct_within_exceeds_between(
    df_master,
    wf_dir=CLUSTER_PKL_DIR,
    spike_fit_dir=SPIKE_FIT_DIR,
)
# Out:
# ── Cells with > 80% within spikes exceeding median between ──
#   nRMSE          : c27 (98%)
#   Ramp amp       : c19 (87%)
#   Infl. amp      : c19 (87%)
#   Infl. time     : c27 (82%)
#   Peak width     : c5 (93%)
#   Exp λ          : c31 (100%), c15 (99%), c22 (99%), c44 (99%), c2 (96%), c1 (93%), c20 (92%)
#   Exp const      : c18 (100%), c27 (90%), c43 (86%)
#   Log ISI        : c3 (88%)

# %% [markdown]
# **Supplementary Figure X. Within- vs between-cell waveform distances.**
#
# *[Caption placeholder — fill in after panel selection.]*
