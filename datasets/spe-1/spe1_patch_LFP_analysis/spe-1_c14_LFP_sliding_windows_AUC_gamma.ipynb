# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # high res plotting

import sys
sys.path.append('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/spikeparam')
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/'))
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/spe-1/spe1_helper_modules/'))
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/shared_helper_modules'))

# General imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import warnings
import pickle

# NeuroDSP and FOOOF modules
from neurodsp import spectral

from specparam import Bands


# Custom modules
from lfp_spike_window_analysis import *

from spe1_plotting import *
from spikeparam.patch.fit import Spike

from config import NPX_CHANNELS, CELL_IDS, DICT_PATCH_FS, DICT_CHAN_PRED, DICT_SPK_THRESH, FILTER_SETTINGS

# %%
cell_num =14 #MODIFY THIS WHEN RUNNING DIFFERENT CELLS 

npx_fs = 30000 # sampling rate
lfp_fs = 2500 # sampling rate

patch_fs = DICT_PATCH_FS[cell_num ]
spk_thresh = DICT_SPK_THRESH[cell_num]

npx_channels = NPX_CHANNELS
npx_patch_channel = DICT_CHAN_PRED[cell_num ]

# %% [markdown]
# ### Loading spe-1 data:
#
# I moved the data loading steps to a separate Jupyter Notebook (spe-1_load_data)

# %% [markdown]
# ## Cell 42
# ### Analyze Gamma LFP and whole patch clamp AP relationship for cell 42

# %% [markdown]
# ## Step 0: Get loaded data #CHANGE DIRECTORIES FOR CELL DATA

# %%
lfp_dir= '/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/Neuropixel Paired Recordings/Recordings/filt_lfp_recordings/c14_lfp_filt.npy'
patch_dir= '/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/Neuropixel Paired Recordings/Recordings/filt_patch_recordings/c14patch_filt.npy'

# %%
#get cell number 
cell_num = lfp_dir.split('/')[len(lfp_dir.split('/'))-1].split('_')[0]

#get LFP data
lfp_filt = np.load(lfp_dir)
lfp_one_ms = float(lfp_fs / 1000)
lfp_times = np.arange(0, np.shape(lfp_filt)[0]) / lfp_one_ms # in ms instead of sec

#get patch data 
patch_filt = np.load(patch_dir)
patch_one_ms = float(patch_fs  / 1000)
patch_times = np.arange(0, np.shape(patch_filt )[0]) / patch_one_ms # in ms instead of sec

# %%
# Plot simultaneous patch and LFP data
# Convert time arrays to minutes
patch_times_min = patch_times / 60000  # Convert milliseconds to minutes
lfp_times_min = lfp_times / 60000  # Convert milliseconds to minutes

# Set the common time axis in minutes (e.g., from 13.3333 to 25.6667 minutes)
common_time_range_min = np.arange(80000 / 60000, 154000 / 60000, 1 / 60000)  # Adjust as needed

# Interpolate patch data onto the common time axis
patch_interp = np.interp(common_time_range_min, patch_times_min, patch_filt)

# Interpolate LFP data onto the common time axis
lfp_interp = np.interp(common_time_range_min, lfp_times_min, lfp_filt)

# Plot patch data with common time axis in minutes
plt.figure(figsize=(10, 6))
plt.plot(common_time_range_min, patch_interp, label='Patch Data')
plt.xlabel('Time (minutes)')
plt.ylabel('Voltage')
plt.title('Patch Data with Common Time Axis (minutes)')
plt.legend()
plt.show()

# Plot LFP data with common time axis in minutes
plt.figure(figsize=(10, 6))
plt.plot(common_time_range_min, lfp_interp, label='LFP Data')
plt.xlabel('Time (minutes)')
plt.ylabel('Voltage')
plt.title('LFP Data with Common Time Axis (minutes)')
plt.legend()
plt.show()

# %% [markdown]
# ## STEP 1: ANALYZE LFP DATA BY WINDOWS

# %%
# plot power spectrum
fxx, pxx = spectral.compute_spectrum(lfp_filt, lfp_fs, method='welch', window='hann', nperseg=lfp_fs*4)

xlim = (10e-3, 250)
ylim = (10e-4, 10e4)
plt.loglog(fxx, pxx)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power (V^2/Hz)')
plt.xlim(xlim)
plt.ylim(ylim)
plt.title("LFP PSD for cell "+ cell_num)
plt.show()

# %%
bands = Bands({'gamma' : [30, 60]})

# %%
decim_factor = 10

# %% [markdown]
# ###### SLIDING WINDOWS APPROACH - Multitaper

# %%
model_mt, freqs_mt, window_times_mt = compute_lfp_windows(
    lfp_signal=lfp_filt,
    window_length_sec = 0.1,
    freq_range = (5,90),
    fs=lfp_fs,
    method="multitaper",
    decim_factor = decim_factor
)

summary_df_multitaper = model_mt.to_df()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model_mt, freqs_mt, window_times_mt = compute_lfp_windows(
#       2     lfp_signal=lfp_filt,
#       3     window_length_sec = 0.1,
#       4     freq_range = (5,90),
#       5     fs=lfp_fs,
#       6     method="multitaper",
#       7     decim_factor = decim_factor
#       8 )
#      10 summary_df_multitaper = model_mt.to_df()
#
# File ~/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/spe-1/spe1_helper_modules/lfp_spike_window_analysis.py:107, in compute_lfp_windows(lfp_signal, fs, method, window_length_sec, freq_range, n_freqs, time_bandwidth, decim_factor, progress, n_jobs)
#     104 tb = max(float(time_bandwidth), 2.0)  # ensure ≥ ~3 tapers
#     106 epochs = lfp_signal[np.newaxis, np.newaxis, :]  # (1, 1, n_times)
# --> 107 tfr = mne.time_frequency.tfr_array_multitaper(
#     108     epochs, sfreq=fs, freqs=freqs, n_cycles=n_cycles,
#     109     time_bandwidth=tb, output="power", decim=decim_factor, verbose=False
#     110 )                                              # (1, 1, n_freqs, n_bins)
#     111 spec = np.squeeze(tfr, axis=(0, 1))            # (n_freqs, n_bins)
#     112 powers = spec.T                                # (n_bins, n_freqs)
#
# File <decorator-gen-100>:10, in tfr_array_multitaper(epoch_data, sfreq, freqs, n_cycles, zero_mean, time_bandwidth, use_fft, decim, output, n_jobs, verbose)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mne/time_frequency/multitaper.py:554, in tfr_array_multitaper(epoch_data, sfreq, freqs, n_cycles, zero_mean, time_bandwidth, use_fft, decim, output, n_jobs, verbose)
#     483 """Compute Time-Frequency Representation (TFR) using DPSS tapers.
#     484
#     485 Same computation as `~mne.time_frequency.tfr_multitaper`, but operates on
#    (...)
#     551 .. versionadded:: 0.14.0
#     552 """
#     553 from .tfr import _compute_tfr
# --> 554 return _compute_tfr(epoch_data, freqs, sfreq=sfreq,
#     555                     method='multitaper', n_cycles=n_cycles,
#     556                     zero_mean=zero_mean, time_bandwidth=time_bandwidth,
#     557                     use_fft=use_fft, decim=decim, output=output,
#     558                     n_jobs=n_jobs, verbose=verbose)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mne/time_frequency/tfr.py:398, in _compute_tfr(epoch_data, freqs, sfreq, method, n_cycles, zero_mean, time_bandwidth, use_fft, decim, output, n_jobs, verbose)
#     395 parallel, my_cwt, n_jobs = parallel_func(_time_frequency_loop, n_jobs)
#     397 # Parallelization is applied across channels.
# --> 398 tfrs = parallel(
#     399     my_cwt(channel, Ws, output, use_fft, 'same', decim, method)
#     400     for channel in epoch_data.transpose(1, 0, 2))
#     402 # FIXME: to avoid overheads we should use np.array_split()
#     403 for channel_idx, tfr in enumerate(tfrs):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mne/time_frequency/tfr.py:541, in _time_frequency_loop(X, Ws, output, use_fft, mode, decim, method)
#     538     plf = np.zeros((n_freqs, n_times), dtype=np.complex128)
#     540 # Loop across epochs
# --> 541 for epoch_idx, tfr in enumerate(coefs):
#     542     # Transform complex values
#     543     if output in ['power', 'avg_power']:
#     544         tfr = (tfr * tfr.conj()).real  # power
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mne/time_frequency/tfr.py:246, in _cwt_gen(X, Ws, fsize, mode, decim, use_fft)
#     244 for ii, W in enumerate(Ws):
#     245     if use_fft:
# --> 246         ret = ifft(fft_x * fft_Ws[ii])[:n_times + W.size - 1]
#     247     else:
#     248         ret = np.convolve(x, W, mode=mode)
#
# KeyboardInterrupt:

# %%
#model_mt.report(peak_org=bands)
model_mt.print_results()
model_mt.plot(peak_org=bands)
#try plot and print results - to avoid re-fitting??

# %%
#save as pickles 
"""
with open('mtc14_model_mt.pkl', 'wb') as file:
    pickle.dump(model_mt, file)

with open('mtc14_freqs_mt.pkl', 'wb') as file:
    pickle.dump(freqs_mt, file)

with open('mtc14_window_times_mt.pkl', 'wb') as file:
    pickle.dump(window_times_mt, file)"""
# Out:
# "\nwith open('mtc14_model_mt.pkl', 'wb') as file:\n    pickle.dump(model_mt, file)\n\nwith open('mtc14_freqs_mt.pkl', 'wb') as file:\n    pickle.dump(freqs_mt, file)\n\nwith open('mtc14_window_times_mt.pkl', 'wb') as file:\n    pickle.dump(window_times_mt, file)"

# %%
#open pickle
with open('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/multitaper_pickles/c14/mtc14_model_mt_fq5t90.pkl ', 'rb') as file:
    model_mt = pickle.load(file)

with open('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/multitaper_pickles/c14/mtc14_freqs_mt_fq5t90.pkl ', 'rb') as file:
    freqs_mt = pickle.load(file)

with open('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/multitaper_pickles/c14/mtc14_window_times_mt_fq5t90.pkl ', 'rb') as file:
    window_times_mt = pickle.load(file)

# %%
# Existing summary from specparam (offset, exponent, r_squared, error, n_peaks, etc.)
summary_df_multitaper = model_mt.to_df().reset_index(drop=True)

# %% [markdown]
# ## STEP 2: Get AUC gamma (subtract off the aperiodic exponent from the raw spectrum)

# %%
#compute gamma AUC + exponent per window 
specp_auc_df = gamma_auc_and_exponent_per_window(model_mt, band=(25, 60), space="log")
# Out:
# Computing gamma AUC + exponent:   0%|          | 0/270012 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 #compute gamma AUC + exponent per window
# ----> 2 specp_auc_df = gamma_auc_and_exponent_per_window(model_mt, band=(25, 60), space="log")
#
# File ~/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/spe-1/spe1_helper_modules/lfp_spike_window_analysis.py:1498, in gamma_auc_and_exponent_per_window(model, band, space, show_progress, min_rsq)
#    1496 out = []
#    1497 for i in iterator:
# -> 1498     m = model.get_model(i)  # <- per-window SpectralModel
#    1499     if m is None:
#    1500         continue
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/specparam/objs/results.py:553, in BaseResults2D.get_model(self, ind, regenerate)
#     550 model.set_run_modes(*self.get_run_modes())
#     552 # Add data for specified single power spectrum, if available
# --> 553 if self.has_data:
#     554     model.power_spectrum = self.power_spectra[ind]
#     556 # Add results for specified power spectrum, regenerating full fit if requested
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/specparam/objs/data.py:269, in BaseData2D.has_data(self)
#     265 @property
#     266 def has_data(self):
#     267     """Indicator for if the object contains data."""
# --> 269     return True if np.any(self.power_spectra) else False
#
# File <__array_function__ internals>:200, in any(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy-1.24.1-py3.9-macosx-10.9-x86_64.egg/numpy/core/fromnumeric.py:2423, in any(a, axis, out, keepdims, where)
#    2333 @array_function_dispatch(_any_dispatcher)
#    2334 def any(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#    2335     """
#    2336     Test whether any array element along a given axis evaluates to True.
#    2337
#    (...)
#    2421
#    2422     """
# -> 2423     return _wrapreduction(a, np.logical_or, 'any', axis, None, out,
#    2424                           keepdims=keepdims, where=where)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy-1.24.1-py3.9-macosx-10.9-x86_64.egg/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
specp_auc_df

# %%
#Show example of process for one window idx
auc_val = plot_spectra_and_auc(
    model_mt,
    win_idx=30604,
    band=(25, 60),
    freq_range=(1, 90),   # optional, for display only
    title="Aperiodic-adjusted gamma AUC"
)

# %%
plot_mean_spectra_fast(model_mt, max_windows=1500)

# %% [markdown]
# ## STEP 3: Detect spikes from patch data

# %%
plt.plot(patch_filt[:100000] )

# %%
#threshold in mVs
sp = Spike(thresh_amp=100, window_length=(5., 5.), smooth_frac=.01)

# %%
sp.fit(patch_filt, patch_fs, n_jobs=-1, progress=tqdm, flip_signal=True)

# %%
sp.plot()

# %% [markdown]
# ### Filter spikes

# %%
sp.filter_features()  # Applies default filters in-place

# %% [markdown]
# ### Get spike dataframe (with spike times column)

# %%
df_features = sp.df_features

#add columns for spike times, both in idx and ms
df_features['spk_times_idx'] = sp.spike_inds
df_features['spk_times_ms'] = patch_times[sp.spike_inds]
df_features['spk_id'] = range(len(df_features))

# %%
df_features

# %% [markdown]
# ### Get spike times

# %%
spk_times_idx = df_features['spk_times_idx']
spk_times_ms = df_features['spk_times_ms']
spk_ids = df_features['spk_id']

# %% [markdown]
# ## STEP 4: Get avg waveform and for every spike, calculate error (aligned to peak)

# %%
#get root mean squared errors
errs = spike_waveform_errors(sp, metric="rmse")

# %%
#Examples
e = visualize_spike_error(sp, spike_idx=0, metric="rmse", show_residual=True)
e = visualize_spike_error(sp, spike_idx=100, metric="rmse", show_residual=True)
e = visualize_spike_error(sp, spike_idx=22, metric="rmse", show_residual=True)
e = visualize_spike_error(sp, spike_idx=419, metric="rmse", show_residual=True)

# %% [markdown]
# ## STEP 4: Map spikes to windows and create df with spike error, LFP AUC and aperiodic exponent

# %%
#generate df with spike waveform errors, lfp window auc and aperiodic exponent
spike_lfp_df = make_spike_waveform_error_and_auc_df(errs, df_features, window_times_mt, lfp_fs, specp_auc_df)

# %%
spike_lfp_df

# %%
plt.scatter(spike_lfp_df['wf_error'], spike_lfp_df['gamma_auc'])
plt.xlabel("spk wf error")
plt.ylabel("gamma auc")

# %%
plt.scatter(spike_lfp_df['wf_error'], spike_lfp_df['aperiodic_exponent'])
plt.xlabel("spk wf error")
plt.ylabel("aperiodic exponent")

# %% [markdown]
# ## STEP 5: Build regression to predict per-spike error as a combination of the gamma AUC and the aperiodic exponent - RIP - didn't work

# %%
res = fit_linear_regression(
    spike_lfp_df,
    y_col="wf_error",
    x_cols=["gamma_auc", "aperiodic_exponent"],
    standardize=True,
    interactions=False,
    robust_se=True,
    do_cv=True,
    cv_splits=5,
    plot=True,
)
print(res["coefs"])

# %% [markdown]
# ### STEP 6: See if AUC and aperiodic exponent correlate with spike params

# %%
#create combined df with new LFP features and spike params 

#make sure the left DF has a 'spk_id' column to join on
spike_lfp_df_ = spike_lfp_df.copy()
if "spk_id" not in spike_lfp_df_.columns and "pk_id" in spike_lfp_df_.columns:
    spike_lfp_df_ = spike_lfp_df_.rename(columns={"pk_id": "spk_id"})

# select the feature columns you want from df_features (index by spk_id for a clean join)
feat_cols = [
    "ramp_amp",
    "inflection_time",
    "inflection_amp",
    "peak_amp",
    "peak_width",
    "peak_sharpness",
    "exp_lambda",
    "exp_const",
    "log_isi",
]
feat = df_features.set_index("spk_id")[feat_cols]

# left join by spk_id
spike_lfp_with_feats = spike_lfp_df_.join(feat, on="spk_id", how="left")

# %%
spike_lfp_with_feats

# %%
#look for correlations 

from scipy.stats import pearsonr, spearmanr

df = spike_lfp_with_feats  # your merged dataframe

lfp_feats   = ["gamma_auc", "aperiodic_exponent"]
spike_feats = [
    "ramp_amp","inflection_time","inflection_amp","peak_amp",
    "peak_width","peak_sharpness","exp_lambda","exp_const","log_isi","wf_error"
]

lfp_feats   = [c for c in lfp_feats   if c in df.columns]
spike_feats = [c for c in spike_feats if c in df.columns]

def fmt_p(p, decimals=4):
    thresh = 10**(-decimals)
    return f"< {thresh:.{decimals}f}" if p < thresh else f"{p:.{decimals}f}"

for x in lfp_feats:
    for y in spike_feats:
        d = df[[x, y]].dropna()
        n = len(d)
        if n < 3:
            continue

        r_p, p_p = pearsonr(d[x], d[y])
        r_s, p_s = spearmanr(d[x], d[y])

        fig, ax = plt.subplots(figsize=(5.8, 4.6))
        ax.scatter(d[x].to_numpy(), d[y].to_numpy(), s=14, alpha=0.75)
        ax.set_xlabel(x)
        ax.set_ylabel(y)
        ax.set_title(
            f"{y} vs {x}\n"
            f"Pearson r={r_p:.3f}, p={fmt_p(p_p)} | "
            f"Spearman ρ={r_s:.3f}, p={fmt_p(p_s)}  (n={n})"
        )

       

        plt.tight_layout()
        plt.show()

# %%
plt.scatter (spike_feats['log_isi'], spike_feats['exp_lambda'])

# %%
plt.scatter (spike_feats['log_isi'], spike_feats['exp_const'])

# %%
df = spike_lfp_with_feats  # your merged dataframe

lfp_feats   = ["gamma_auc", "aperiodic_exponent"]
spike_feats = [
    "ramp_amp","inflection_time","inflection_amp","peak_amp",
    "peak_width","peak_sharpness","exp_lambda","exp_const","log_isi","wf_error"
