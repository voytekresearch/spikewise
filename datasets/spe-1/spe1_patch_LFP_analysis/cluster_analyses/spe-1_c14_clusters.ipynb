# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # high res plotting

import sys
sys.path.append('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/spikeparam')
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/'))
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/spe-1/spe1_helper_modules/'))
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/shared_helper_modules'))

# General imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import warnings
import pickle

warnings.filterwarnings(
    "ignore",
    message="use_inf_as_na option is deprecated",
    category=FutureWarning,
    module="seaborn")

warnings.filterwarnings(
    "ignore",
    message=r"invalid value encountered in log10",
    category=RuntimeWarning,
    module=r".*specparam.*",
)


# NeuroDSP and FOOOF modules
from neurodsp import spectral

from specparam import Bands


# Custom modules

from spk_feat_cluster_analysis import *

from spe1_plotting import *
from spikeparam.patch.fit import Spike

from config import NPX_CHANNELS, CELL_IDS, DICT_PATCH_FS, DICT_CHAN_PRED, DICT_SPK_THRESH, FILTER_SETTINGS

# %%
cell_num =14 #MODIFY THIS WHEN RUNNING DIFFERENT CELLS 

npx_fs = 30000 # sampling rate
lfp_fs = 2500 # sampling rate

patch_fs = DICT_PATCH_FS[cell_num ]
spk_thresh = DICT_SPK_THRESH[cell_num]

npx_channels = NPX_CHANNELS
npx_patch_channel = DICT_CHAN_PRED[cell_num ]

# %% [markdown]
# ### Loading spe-1 data:
#
# I moved the data loading steps to a separate Jupyter Notebook (spe-1_load_data)

# %% [markdown]
# ## Cell 14
# ### Analyze Gamma LFP and whole patch clamp AP relationship for cell 14

# %% [markdown]
# ## Step 0: Get loaded data

# %%
lfp_dir= '/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/Neuropixel Paired Recordings/Recordings/filt_lfp_recordings/c14_lfp.npy'
patch_dir= '/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/Neuropixel Paired Recordings/Recordings/filt_patch_recordings/c14patch_filt.npy'

# %%
#get cell number 
cell_num = lfp_dir.split('/')[len(lfp_dir.split('/'))-1].split('_')[0]

#get LFP data
lfp_filt = np.load(lfp_dir)
lfp_one_ms = float(lfp_fs / 1000)
lfp_times = np.arange(0, np.shape(lfp_filt)[0]) / lfp_one_ms # in ms instead of sec

#get patch data 
patch_filt = np.load(patch_dir)
patch_one_ms = float(patch_fs  / 1000)
patch_times = np.arange(0, np.shape(patch_filt )[0]) / patch_one_ms # in ms instead of sec

# %%
# Plot simultaneous patch and LFP data
# Convert time arrays to minutes
patch_times_min = patch_times / 60000  # Convert milliseconds to minutes
lfp_times_min = lfp_times / 60000  # Convert milliseconds to minutes

# Set the common time axis in minutes (e.g., from 13.3333 to 25.6667 minutes)
common_time_range_min = np.arange(80000 / 60000, 154000 / 60000, 1 / 60000)  # Adjust as needed

# Interpolate patch data onto the common time axis
patch_interp = np.interp(common_time_range_min, patch_times_min, patch_filt)

# Interpolate LFP data onto the common time axis
lfp_interp = np.interp(common_time_range_min, lfp_times_min, lfp_filt)

# Plot patch data with common time axis in minutes
plt.figure(figsize=(10, 6))
plt.plot(common_time_range_min, patch_interp, label='Patch Data')
plt.xlabel('Time (minutes)')
plt.ylabel('Voltage')
plt.title('Patch Data with Common Time Axis (minutes)')
plt.legend()
plt.show()

# Plot LFP data with common time axis in minutes
plt.figure(figsize=(10, 6))
plt.plot(common_time_range_min, lfp_interp, label='LFP Data')
plt.xlabel('Time (minutes)')
plt.ylabel('Voltage')
plt.title('LFP Data with Common Time Axis (minutes)')
plt.legend()
plt.show()

# %% [markdown]
# ## STEP 1: Detect and fit spikes from patch data

# %%
plt.plot(patch_filt[:1000000] )

# %%
#threshold in mVs
sp = Spike(thresh_amp=100, window_length=(5., 5.), smooth_frac=.01)

# %%
sp.fit(patch_filt, patch_fs, n_jobs=-1, progress=tqdm, flip_signal=True)
# Out:
# Spike:   0%|          | 0/4504 [00:00<?, ?it/s]
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
sp.plot()

# %% [markdown]
# ### Filter spikes

# %%
sp.filter_features()  # Applies default filters in-place

# %% [markdown]
# ### Get spike dataframe (with spike times column)

# %%
df_features = sp.df_features

#add columns for spike times, both in idx and ms
df_features['spk_times_idx'] = sp.spike_inds
df_features['spk_times_ms'] = patch_times[sp.spike_inds]
df_features['spk_id'] = range(len(df_features))

# %%
df_features
# Out:
#        ramp_amp  inflection_time  inflection_amp    peak_amp  peak_width  \
# 0     10.961881             0.30       18.382591  395.951470        0.62
# 1     11.199292             0.30       25.167280  410.769554        0.58
# 2     18.679989             0.26      -16.844094  380.923194        0.66
# 3     27.569685             0.36       24.323961  386.861926        0.68
# 4     11.695808             0.30        7.862321  412.076375        0.50
# ...         ...              ...             ...         ...         ...
# 4496  10.949018             0.22       30.747441  500.183396        0.56
# 4497  16.978693             0.22       25.482944  635.452971        0.44
# 4498  16.588751             0.24       33.900754  592.427963        0.46
# 4501  21.334151             0.24       34.382807  642.778547        0.46
# 4502  11.457570             0.24       22.811053  599.141551        0.46
#
#       peak_sharpness  exp_lambda  exp_const   log_isi  spk_times_idx  \
# 0          79.815607    3.948223  -7.969183  2.013977          21998
# 1          38.602095    3.252343  10.962803  2.176694          27164
# 2         104.931446    2.765642  -9.252601  1.491714          34678
# 3          51.947039    2.844248  16.399738  2.982055          36230
# 4          73.183001    5.008926  -3.030722  2.366962          84229
# ...              ...         ...        ...       ...            ...
# 4496      171.615948    1.280002   2.863477  2.762231       53960086
# 4497      254.095983    2.919569  -6.782038  1.301257       53989020
# 4498      217.024450    1.659293  15.158946  1.830894       53990021
# 4501      256.968232    1.976378  15.565057  1.705998       54001877
# 4502      239.975334    1.980195  14.101782  2.596192       54004419
#
#       spk_times_ms  spk_id
# 0     4.397498e+02       0
# 1     5.430205e+02       1
# 2     6.932287e+02       2
# 3     7.242538e+02       3
# 4     1.683775e+03       4
# ...            ...     ...
# 4496  1.078686e+06    3792
# 4497  1.079265e+06    3793
# 4498  1.079285e+06    3794
# 4501  1.079522e+06    3795
# 4502  1.079572e+06    3796
#
# [3797 rows x 12 columns]

# %% [markdown]
# ### Get spike times

# %%
spk_times_idx = df_features['spk_times_idx']
spk_times_ms = df_features['spk_times_ms']
spk_ids = df_features['spk_id']

# %% [markdown]
# ## STEP 2: Cluster ISI spike groups

# %%
# scan all numeric features and only cluster the ones that look multimodal
df_features_clust, rep = cluster_multimodal_features(
    df_features,
    max_k=3,
    suffix="_cluster",
    plot_each=True  # set True if you want a quick plot per clustered feature
)

# %%
df_features_clust
# Out:
#        ramp_amp  inflection_time  inflection_amp    peak_amp  peak_width  \
# 0     10.961881             0.30       18.382591  395.951470        0.62
# 1     11.199292             0.30       25.167280  410.769554        0.58
# 2     18.679989             0.26      -16.844094  380.923194        0.66
# 3     27.569685             0.36       24.323961  386.861926        0.68
# 4     11.695808             0.30        7.862321  412.076375        0.50
# ...         ...              ...             ...         ...         ...
# 4496  10.949018             0.22       30.747441  500.183396        0.56
# 4497  16.978693             0.22       25.482944  635.452971        0.44
# 4498  16.588751             0.24       33.900754  592.427963        0.46
# 4501  21.334151             0.24       34.382807  642.778547        0.46
# 4502  11.457570             0.24       22.811053  599.141551        0.46
#
#       peak_sharpness  exp_lambda  exp_const   log_isi  spk_times_idx  \
# 0          79.815607    3.948223  -7.969183  2.013977          21998
# 1          38.602095    3.252343  10.962803  2.176694          27164
# 2         104.931446    2.765642  -9.252601  1.491714          34678
# 3          51.947039    2.844248  16.399738  2.982055          36230
# 4          73.183001    5.008926  -3.030722  2.366962          84229
# ...              ...         ...        ...       ...            ...
# 4496      171.615948    1.280002   2.863477  2.762231       53960086
# 4497      254.095983    2.919569  -6.782038  1.301257       53989020
# 4498      217.024450    1.659293  15.158946  1.830894       53990021
# 4501      256.968232    1.976378  15.565057  1.705998       54001877
# 4502      239.975334    1.980195  14.101782  2.596192       54004419
#
#       spk_times_ms  spk_id log_isi_cluster
# 0     4.397498e+02       0             mid
# 1     5.430205e+02       1             mid
# 2     6.932287e+02       2             low
# 3     7.242538e+02       3            high
# 4     1.683775e+03       4             mid
# ...            ...     ...             ...
# 4496  1.078686e+06    3792            high
# 4497  1.079265e+06    3793             low
# 4498  1.079285e+06    3794             mid
# 4501  1.079522e+06    3795             low
# 4502  1.079572e+06    3796            high
#
# [3797 rows x 13 columns]

# %% [markdown]
# ### STETP 3: Separate spikes into short ISIs and long ISIs and find transition points (long ISI spikes to group of short ISI spikes)

# %% [markdown]
# #### Visualize ISI spike cluster groups over time

# %%
plot_clusters_over_time_min(
    df_features_clust,
    time_col="spk_times_ms",
    label_col="log_isi_cluster",   
    time_unit="ms",
    bin_size_ms=1000,
    sigma_bins=2
)

# %% [markdown]
# #### Calculate transition probabilities

# %%
trans_mat = cluster_transition_matrix(df_features_clust, "log_isi_cluster")
print(trans_mat)

sns.heatmap(trans_mat, annot=True, cmap="magma", cbar=False)
plt.title("ISI cluster transition probabilities")
plt.xlabel("Next spike cluster")
plt.ylabel("Current spike cluster")
plt.show()
# Out:
#           high       low       mid
# high  0.172678  0.432787  0.394536
# low   0.265934  0.230037  0.504029
# mid   0.260554  0.432058  0.307388

# %% [markdown]
# #### Find transition points

# %%
# Identify high spikes that start low bursts
df_marked = mark_high_burst_onsets(
    df_features_clust,
    cluster_col="log_isi_cluster",
    time_col="spk_times_ms",
    min_low_run=3  # how many LOW spikes must follow to count as a burst
)

# Plot full timeline
plot_long_to_short_isi_onsets(
    df_marked,
    time_col="spk_times_ms",
    cluster_col="log_isi_cluster"          

)


# Zoom into a specific range 
plot_long_to_short_isi_onsets(
    df_marked,
    time_col="spk_times_ms",
    cluster_col="log_isi_cluster",
    time_range=(00, 20)  # seconds
)

# %%
df_marked
# Out:
#        ramp_amp  inflection_time  inflection_amp    peak_amp  peak_width  \
# 0     10.961881             0.30       18.382591  395.951470        0.62
# 1     11.199292             0.30       25.167280  410.769554        0.58
# 2     18.679989             0.26      -16.844094  380.923194        0.66
# 3     27.569685             0.36       24.323961  386.861926        0.68
# 4     11.695808             0.30        7.862321  412.076375        0.50
# ...         ...              ...             ...         ...         ...
# 3792  10.949018             0.22       30.747441  500.183396        0.56
# 3793  16.978693             0.22       25.482944  635.452971        0.44
# 3794  16.588751             0.24       33.900754  592.427963        0.46
# 3795  21.334151             0.24       34.382807  642.778547        0.46
# 3796  11.457570             0.24       22.811053  599.141551        0.46
#
#       peak_sharpness  exp_lambda  exp_const   log_isi  spk_times_idx  \
# 0          79.815607    3.948223  -7.969183  2.013977          21998
# 1          38.602095    3.252343  10.962803  2.176694          27164
# 2         104.931446    2.765642  -9.252601  1.491714          34678
# 3          51.947039    2.844248  16.399738  2.982055          36230
# 4          73.183001    5.008926  -3.030722  2.366962          84229
# ...              ...         ...        ...       ...            ...
# 3792      171.615948    1.280002   2.863477  2.762231       53960086
# 3793      254.095983    2.919569  -6.782038  1.301257       53989020
# 3794      217.024450    1.659293  15.158946  1.830894       53990021
# 3795      256.968232    1.976378  15.565057  1.705998       54001877
# 3796      239.975334    1.980195  14.101782  2.596192       54004419
#
#       spk_times_ms  spk_id log_isi_cluster  is_long_to_short_isi_onset
# 0     4.397498e+02       0             mid                       False
# 1     5.430205e+02       1             mid                       False
# 2     6.932287e+02       2             low                       False
# 3     7.242538e+02       3            high                       False
# 4     1.683775e+03       4             mid                       False
# ...            ...     ...             ...                         ...
# 3792  1.078686e+06    3792            high                       False
# 3793  1.079265e+06    3793             low                       False
# 3794  1.079285e+06    3794             mid                       False
# 3795  1.079522e+06    3795             low                       False
# 3796  1.079572e+06    3796            high                       False
#
# [3797 rows x 14 columns]

# %% [markdown]
# #### Look at the other waveform features for the "transition" spikes
# There are no significant differences in the waveform features forr the transition spikes vs other spikes

# %%
res = compare_feature_groups(
    df_marked,
    features= ["peak_width","ramp_amp","peak_sharpness", "inflection_amp", "exp_lambda"],
    group_col="is_long_to_short_isi_onset",
    groups=(True, False),              
    group_names=("transition spike ","non-transition spike "),  
    show_plots=True
)
# Out:
# Comparing groups: True (transition spike ) vs False (non-transition spike ) using column 'is_long_to_short_isi_onset'
#
# peak_width          : t-test        (p=0.0420)
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# ramp_amp            : t-test        (p=0.9504)
# peak_sharpness      : t-test        (p=0.1659)
# inflection_amp      : t-test        (p=0.0002)
# exp_lambda          : t-test        (p=0.0204)

# %%
#also look at long ISI vs short ISI

features = ["ramp_amp", "peak_width", "peak_sharpness", "inflection_amp", "exp_lambda"]

compare_feature_groups(
    df_features_clust,
    features= features,
    group_col="log_isi_cluster",
    groups=("high", "low", "medium"),              # which two cluster labels to compare
    group_names=("long ISI", "short ISI", "medium ISI"),    # names for plot labels
    show_plots=True
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 5
#       1 #also look at long ISI vs short ISI
#       3 features = ["ramp_amp", "peak_width", "peak_sharpness", "inflection_amp", "exp_lambda"]
# ----> 5 compare_feature_groups(
#       6     df_features_clust,
#       7     features= features,
#       8     group_col="log_isi_cluster",
#       9     groups=("high", "low", "medium"),              # which two cluster labels to compare
#      10     group_names=("long ISI", "short ISI", "medium ISI"),    # names for plot labels
#      11     show_plots=True
#      12 )
#
# File ~/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/spe-1/spe1_helper_modules/spk_feat_cluster_analysis.py:646, in compare_feature_groups(df, features, group_col, groups, group_names, show_plots, alpha_normality, alpha_var)
#     643 if group_names is None:
#     644     group_names = groups
# --> 646 g1, g2 = groups
#     647 name1, name2 = group_names
#     649 print(f"\nComparing groups: {g1} ({name1}) vs {g2} ({name2}) using column '{group_col}'\n")
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# ## LOOK AT PEAK WIDTH CLUSTERS
# #### What do the feature distributions look like for the peak width clusters?
#
# For the peak width groups the other spike feature also follow the same groupping/clustering, except for ISI

# %%
plot_clusters_over_time_min(
    df_features_clust,
    time_col="spk_times_ms",
    label_col="peak_width_cluster",   
    time_unit="ms",
    bin_size_ms=1000,
    sigma_bins=2
)

# %%
trans_mat_peak_width = cluster_transition_matrix(df_features_clust, "log_isi_cluster")
print(trans_mat_peak_width)

sns.heatmap(trans_mat_peak_width, annot=True, cmap="magma", cbar=False)
plt.title("Peak width cluster transition probabilities")
plt.xlabel("Next spike cluster")
plt.ylabel("Current spike cluster")
plt.show()

# %%
results_pw = compare_feature_groups(
    df_features_clust,
    features= ["ramp_amp","peak_sharpness", "inflection_amp", "exp_lambda", "log_isi"],
    group_col="peak_width_cluster",
    groups=("high", "low"),              # which two cluster labels to compare
    group_names=("wide peak","narrow peak"),    # names for plot labels
    show_plots=True
)

results_pw

# %% [markdown]
# ### STEP 4: Analyze LFP around spikes

# %% [markdown]
# ### 1) Extract LFP windows and visualize

# %%
df_marked
# Out:
#        ramp_amp  inflection_time  inflection_amp    peak_amp  peak_width  \
# 0     10.961881             0.30       18.382591  395.951470        0.62
# 1     11.199292             0.30       25.167280  410.769554        0.58
# 2     18.679989             0.26      -16.844094  380.923194        0.66
# 3     27.569685             0.36       24.323961  386.861926        0.68
# 4     11.695808             0.30        7.862321  412.076375        0.50
# ...         ...              ...             ...         ...         ...
# 3792  10.949018             0.22       30.747441  500.183396        0.56
# 3793  16.978693             0.22       25.482944  635.452971        0.44
# 3794  16.588751             0.24       33.900754  592.427963        0.46
# 3795  21.334151             0.24       34.382807  642.778547        0.46
# 3796  11.457570             0.24       22.811053  599.141551        0.46
#
#       peak_sharpness  exp_lambda  exp_const   log_isi  spk_times_idx  \
# 0          79.815607    3.948223  -7.969183  2.013977          21998
# 1          38.602095    3.252343  10.962803  2.176694          27164
# 2         104.931446    2.765642  -9.252601  1.491714          34678
# 3          51.947039    2.844248  16.399738  2.982055          36230
# 4          73.183001    5.008926  -3.030722  2.366962          84229
# ...              ...         ...        ...       ...            ...
# 3792      171.615948    1.280002   2.863477  2.762231       53960086
# 3793      254.095983    2.919569  -6.782038  1.301257       53989020
# 3794      217.024450    1.659293  15.158946  1.830894       53990021
# 3795      256.968232    1.976378  15.565057  1.705998       54001877
# 3796      239.975334    1.980195  14.101782  2.596192       54004419
#
#       spk_times_ms  spk_id log_isi_cluster  is_long_to_short_isi_onset
# 0     4.397498e+02       0             mid                       False
# 1     5.430205e+02       1             mid                       False
# 2     6.932287e+02       2             low                       False
# 3     7.242538e+02       3            high                       False
# 4     1.683775e+03       4             mid                       False
# ...            ...     ...             ...                         ...
# 3792  1.078686e+06    3792            high                       False
# 3793  1.079265e+06    3793             low                       False
# 3794  1.079285e+06    3794             mid                       False
# 3795  1.079522e+06    3795             low                       False
# 3796  1.079572e+06    3796            high                       False
#
# [3797 rows x 14 columns]

# %%
#get transition spike LFP windows 

transition_spike_extractor = extract_lfp_windows(
    spk_df=df_marked,
    lfp_times_ms=lfp_times,
    lfp_signal=lfp_filt,
    pre_s=1.0,
    post_s=1.5, 
    condition="is_long_to_short_isi_onset"

)

windows_transition = transition_spike_extractor["windows"]
t_rel_transitions = transition_spike_extractor["times_rel_ms"]
spike_times_transition = transition_spike_extractor["spike_times_ms"]
next_spk_times_transition = transition_spike_extractor["next_spike_times_ms"]
meta_df_transitions = transition_spike_extractor["meta_df"]

#get control  spike LFP windows 

ctrl_spike_extractor = extract_lfp_windows(
    spk_df=df_marked,
    lfp_times_ms=lfp_times,
    lfp_signal=lfp_filt,
    pre_s=1.0,
    post_s=1.5, 
    condition="is_long_to_short_isi_onset == False"

)

windows_ctrl = ctrl_spike_extractor["windows"]
t_rel_ctrl = ctrl_spike_extractor["times_rel_ms"]
spike_times_ctrl = ctrl_spike_extractor["spike_times_ms"]
next_spk_times_ctrl = ctrl_spike_extractor["next_spike_times_ms"]
meta_df_ctrl = ctrl_spike_extractor["meta_df"]


#get long ISI spikes windows
longISI_spike_extractor = extract_lfp_windows(
    spk_df=df_marked,
    lfp_times_ms=lfp_times,
    lfp_signal=lfp_filt,
    pre_s=1.0,
    post_s=1.5, 
    condition="log_isi_cluster == 'high'"

)

windows_longISI = longISI_spike_extractor["windows"]
t_rel_longISI = longISI_spike_extractor["times_rel_ms"]
spike_times_longISI = longISI_spike_extractor["spike_times_ms"]
next_spk_times_longISI = longISI_spike_extractor["next_spike_times_ms"]
meta_df_longISI = longISI_spike_extractor["meta_df"]


#get short ISI spikes windows
shortISI_spike_extractor = extract_lfp_windows(
    spk_df=df_marked,
    lfp_times_ms=lfp_times,
    lfp_signal=lfp_filt,
    pre_s=1.0,
    post_s=1.5, 
    condition="log_isi_cluster == 'low'"

)

windows_shortISI = shortISI_spike_extractor["windows"]
t_rel_shortISI = shortISI_spike_extractor["times_rel_ms"]
spike_times_shortISI = shortISI_spike_extractor["spike_times_ms"]
next_spk_times_shortISI = shortISI_spike_extractor["next_spike_times_ms"]
meta_df_shortISI = shortISI_spike_extractor["meta_df"]

#get wide peak spike windows
widepeak_spike_extractor = extract_lfp_windows(
    spk_df=df_marked,
    lfp_times_ms=lfp_times,
    lfp_signal=lfp_filt,
    pre_s=1.0,
    post_s=1.5, 
    condition="peak_width_cluster == 'high'"

)

windows_widepeak = widepeak_spike_extractor["windows"]
t_rel_widepeak = widepeak_spike_extractor["times_rel_ms"]
spike_times_widepeak = widepeak_spike_extractor["spike_times_ms"]
next_spk_times_widepeak = widepeak_spike_extractor["next_spike_times_ms"]
meta_df_widepeak =widepeak_spike_extractor["meta_df"]

#get narrow peak spike windows 
narrpeak_spike_extractor = extract_lfp_windows(
    spk_df=df_marked,
    lfp_times_ms=lfp_times,
    lfp_signal=lfp_filt,
    pre_s=1.0,
    post_s=1.5, 
    condition="peak_width_cluster == 'low'"

)

windows_narrpeak = narrpeak_spike_extractor["windows"]
t_rel_narrpeak = narrpeak_spike_extractor["times_rel_ms"]
spike_times_narrpeak = narrpeak_spike_extractor["spike_times_ms"]
next_spk_times_narrpeak = narrpeak_spike_extractor["next_spike_times_ms"]
meta_df_narrpeak =narrpeak_spike_extractor["meta_df"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File ~/opt/anaconda3/lib/python3.9/collections/__init__.py:941, in ChainMap.__getitem__(self, key)
#     940         pass
# --> 941 return self.__missing__(key)
#
# File ~/opt/anaconda3/lib/python3.9/collections/__init__.py:933, in ChainMap.__missing__(self, key)
#     932 def __missing__(self, key):
# --> 933     raise KeyError(key)
#
# KeyError: 'peak_width_cluster'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'peak_width_cluster'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[24], line 74
#      71 meta_df_shortISI = shortISI_spike_extractor["meta_df"]
#      73 #get wide peak spike windows
# ---> 74 widepeak_spike_extractor = extract_lfp_windows(
#      75     spk_df=df_marked,
#      76     lfp_times_ms=lfp_times,
#      77     lfp_signal=lfp_filt,
#      78     pre_s=1.0,
#      79     post_s=1.5,
#      80     condition="peak_width_cluster == 'high'"
#      81
#      82 )
#      84 windows_widepeak = widepeak_spike_extractor["windows"]
#      85 t_rel_widepeak = widepeak_spike_extractor["times_rel_ms"]
#
# File ~/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/spe-1/spe1_helper_modules/spk_feat_cluster_analysis.py:1045, in extract_lfp_windows(spk_df, lfp_times_ms, lfp_signal, pre_s, post_s, condition)
#    1043 # Apply condition if provided
#    1044 if condition is not None:
# -> 1045     df = df.query(condition)
#    1047 if df.empty:
#    1048     print("No spikes matched the condition — returning empty output.")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4811, in DataFrame.query(self, expr, inplace, **kwargs)
#    4809 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4810 kwargs["target"] = None
# -> 4811 res = self.eval(expr, **kwargs)
#    4813 try:
#    4814     result = self.loc[res]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4937, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4934     kwargs["target"] = self
#    4935 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4937 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:418, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     416     raise SyntaxError("only a single expression is allowed")
#     417 expr = node.body[0]
# --> 418 return self.visit(expr, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:421, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     420 def visit_Expr(self, node, **kwargs):
# --> 421     return self.visit(node.value, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:532, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     531 def visit_BinOp(self, node, **kwargs):
# --> 532     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533     left, right = self._maybe_downcast_constants(left, right)
#     534     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:452, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     450 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     451     if left is None:
# --> 452         left = self.visit(node.left, side="left")
#     453     if right is None:
#     454         right = self.visit(node.right, side="right")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expr.py:545, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     544 def visit_Name(self, node, **kwargs) -> Term:
# --> 545     return self.term_type(node.id, self.env, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and res.ndim > 2:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/scope.py:244, in Scope.resolve(self, key, is_local)
#     242     return self.temps[key]
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'peak_width_cluster' is not defined

# %%
#Plot LFP heatmap

next_rel_trans = (
    np.asarray(next_spk_times_transition, dtype=float)
    - np.asarray(spike_times_transition, dtype=float)
) 

next_rel_ctrl = (
    np.asarray(next_spk_times_ctrl, dtype=float)
    - np.asarray(spike_times_ctrl, dtype=float)
) 

next_rel_longISI = (
    np.asarray(next_spk_times_longISI, dtype=float)
    - np.asarray(spike_times_longISI, dtype=float)
) 

next_rel_shortISI = (
    np.asarray(next_spk_times_shortISI, dtype=float)
    - np.asarray(spike_times_shortISI, dtype=float)
) 

next_rel_widepeak = (
    np.asarray(next_spk_times_widepeak, dtype=float)
    - np.asarray(spike_times_widepeak, dtype=float)
) 

next_rel_narrpeak = (
    np.asarray(next_spk_times_narrpeak, dtype=float)
    - np.asarray(spike_times_narrpeak, dtype=float)
) 

groups = {
    "Transition spikes (LFP)": {
        "windows":   windows_transition,   # list of LFP traces
        "times_rel": t_rel_transitions,
        "next_rel":  next_rel_trans,
    },
    "Control spikes (LFP)": {
        "windows":   windows_ctrl,
        "times_rel": t_rel_ctrl,
        "next_rel":  next_rel_ctrl,
    },
    "Long ISI spikes (LFP)": {
        "windows":   windows_longISI,
        "times_rel": t_rel_longISI,
        "next_rel":  next_rel_longISI,
    },
    "Short ISI spikes (LFP)": {
        "windows":   windows_shortISI,
        "times_rel": t_rel_shortISI,
        "next_rel":  next_rel_shortISI,
    },
    "Wide spikes (LFP)": {
        "windows":   windows_widepeak,
        "times_rel": t_rel_widepeak,
        "next_rel":  next_rel_widepeak,
    },
    "Narrow spikes (LFP)": {
        "windows":   windows_narrpeak,
        "times_rel": t_rel_narrpeak,
        "next_rel":  next_rel_narrpeak,
    },
    
}

lfp_heatmaps = plot_window_feature_groups_heatmap(
    groups,
    feature_label="LFP (µV)",
    cmap="viridis",
    time_unit="ms",
)

# %%
#plot mean LFP aprpind spike 
fig, ax, out_traces = plot_window_feature_group_traces(
    groups,
    time_unit="ms",             # if your t_rel_* are already in seconds
    ylabel="LFP (µV)",
    title="Average LFP around spikes (all groups)",
    band_k=1.0,                # 1×STD band
)

# %% [markdown]
# ### 2) Run time resolved specparam on windows

# %%
"""time_res_results = run_time_resolved_specparam_for_groups(
    groups,
    fs=lfp_fs,
    inner_window_sec=0.5,
    freq_range=(4, 90),
    n_freqs=256,
    time_bandwidth=2.0,
    decim_factor=10,
    aperiodic_mode="fixed",     
    max_windows_per_group=None,     # or None for all
)
"""

# %%
"""with open('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/multitaper_pickles/c14/specp_cluster.pkl', 'wb') as file:
    pickle.dump(time_res_results, file)"""

# %%
#open pickle
with open('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/multitaper_pickles/c14/specp_cluster.pkl', 'rb') as file:
    time_res_results = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 #open pickle
# ----> 2 with open('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/multitaper_pickles/c14/specp_cluster.pkl', 'rb') as file:
#       3     time_res_results = pickle.load(file)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/multitaper_pickles/c14/specp_cluster.pkl'

# %%
#trim edges
time_res_results = trim_edges(time_res_results, edge_sec=0.5)

# %% [markdown]
# ### 3) Visualize specparam results (heatmap, traces, and aperiodic vs raw spctrum plots

# %%
my_colors = {
    "Transition spikes (LFP)": "#1f77b4",
    "Control spikes (LFP)":    "#ff7f0e",
    "Long ISI spikes (LFP)":   "#2ca02c",
    "Short ISI spikes (LFP)":  "#d61428",
    "Wide spikes (LFP)":       "brown",
    "Narrow spikes (LFP)":     "darkgreen",
}

# %%
exp_groups
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 exp_groups
#
# NameError: name 'exp_groups' is not defined

# %%
exp_groups = make_feature_groups(time_res_results, feature="exponent")

for gname in exp_groups.keys():
    exp_groups[gname]["color"] = my_colors[gname]

results_exp = plot_window_feature_groups_heatmap(
    exp_groups,
    feature_label="Exponent",
    cmap="viridis",
    time_unit="s",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 exp_groups = make_feature_groups(time_res_results, feature="exponent")
#       3 for gname in exp_groups.keys():
#       4     exp_groups[gname]["color"] = my_colors[gname]
#
# NameError: name 'time_res_results' is not defined

# %%
gamma_groups = make_feature_groups(time_res_results, "band", band="gamma")
for gname in gamma_groups.keys():
    gamma_groups[gname]["color"] = my_colors[gname]
results_gamma = plot_window_feature_groups_heatmap(
    gamma_groups,
    feature_label="AUC gamma",
    cmap="viridis",
    time_unit="s",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 gamma_groups = make_feature_groups(time_res_results, "band", band="gamma")
#       2 for gname in gamma_groups.keys():
#       3     gamma_groups[gname]["color"] = my_colors[gname]
#
# NameError: name 'time_res_results' is not defined

# %%
fig, ax, out_traces = plot_window_feature_group_traces(
    exp_groups,
    time_unit="s",   # exponent timeline is in seconds now
    ylabel="Aperiodic exponent",
    title="Average exponent around spikes (time-resolved specparam)",
    band_k=0.5, tmin = -0.5
)

# %%
fig, ax, out_traces = plot_window_feature_group_traces(
    gamma_groups,
    time_unit="s",   # exponent timeline is in seconds now
    ylabel="AUC gamma",
    title="Average AUC gamma around spikes (time-resolved specparam)",
    band_k=0.5, tmin = -0.5
)

# %%
group_name = "Transition spikes (LFP)"
window_i   = 59
epoch_i    = 10   # or whichever time bin you want

res = time_res_results[group_name][window_i]

fig, ax, auc = plot_aperiodic_fit_with_band_auc(
    freqs   = res["freqs"],
    powers  = res["powers"],   # (n_epochs, n_freqs), linear
    time_model = res["model"], # SpectralTimeModel
    epoch_i = epoch_i,
    band_range = (30, 55),     # gamma
    title = f"{group_name} | window {window_i} | epoch {epoch_i}",
)

# %% [markdown]
# ### 4) Further analyze specparam results

# %%
# exponent groups already made earlier:
# exp_groups = make_feature_groups(time_res_results, feature="exponent")

window = (-0.2, 0.0)  # -200 ms to spike; times_rel is in seconds

stats_res = boxplot_feature_window_stats(
    exp_groups,
    window=window,
    reducer="mean",
    feature_label="Exponent",
    time_unit="s",   # 
)

print(stats_res)

# %%
# exponent groups already made earlier:
# exp_groups = make_feature_groups(time_res_results, feature="exponent")

window = (-0.2, 0.0)  # -200 ms to spike; times_rel is in seconds

stats_res = boxplot_feature_window_stats(
    gamma_groups,
    window=window,
    reducer="mean",
    feature_label="auc gamma",
    time_unit="s",   # 
)

print(stats_res)

# %% [markdown]
# ### 4) Compare transition spikes vs control

# %%
#make only transition vs control dict
trans_ctrl_keys = ['Transition spikes (LFP)', 'Control spikes (LFP)']
trans_ctrl_exp_groups = {key: exp_groups[key] for key in trans_ctrl_keys if key in exp_groups}
trans_ctrl_gamma_groups = {key: gamma_groups[key] for key in trans_ctrl_keys if key in gamma_groups}

# %%
fig, ax, out_traces = plot_window_feature_group_traces(
    trans_ctrl_exp_groups,
    time_unit="s",   # exponent timeline is in seconds now
    ylabel="Aperiodic exponent",
    title="Average exponent around spikes (time-resolved specparam)",
    band_k=0.5, tmin = -0.5, tmax = 2
)

# %%
fig, ax, out_traces = plot_window_feature_group_traces(
    trans_ctrl_gamma_groups,
    time_unit="s",   # exponent timeline is in seconds now
    ylabel="AUC gamma",
    title="Average AUC gammaaround spikes (time-resolved specparam)",
    band_k=0.5, tmin = -0.5,  tmax = 2
)

# %%
# exponent groups already made earlier:
# exp_groups = make_feature_groups(time_res_results, feature="exponent")

window = (-0.2, 0.0)  # -200 ms to spike; times_rel is in seconds

stats_res = boxplot_feature_window_stats(
    trans_ctrl_exp_groups,
    window=window,
    reducer="mean",
    feature_label="ap exp ",
    time_unit="s",   # 
)

print(stats_res)

# %%
# exponent groups already made earlier:
# exp_groups = make_feature_groups(time_res_results, feature="exponent")

window = (-0.2, 0.0)  # -200 ms to spike; times_rel is in seconds

stats_res = boxplot_feature_window_stats(
    trans_ctrl_gamma_groups,
    window=window,
    reducer="mean",
    feature_label="auc gamma ",
    time_unit="s",   # 
)

print(stats_res)

# %% [markdown]
# ### 5) Compare wide spikes vs narrow

# %%
peak_width_keys = ['Wide spikes (LFP)', 'Narrow spikes (LFP)']
peak_width_exp_groups = {key: exp_groups[key] for key in peak_width_keys if key in exp_groups}
peak_width_gamma_groups = {key: gamma_groups[key] for key in peak_width_keys if key in gamma_groups}
#manually change colors bc wtf 
peak_width_exp_groups['Wide spikes (LFP)']['color'] = 'brown'
peak_width_exp_groups['Narrow spikes (LFP)']['color'] = 'darkgreen'
peak_width_gamma_groups['Wide spikes (LFP)']['color'] = 'brown'
peak_width_gamma_groups['Narrow spikes (LFP)']['color']= 'darkgreen'

# %%
fig, ax, out_traces = plot_window_feature_group_traces(
    peak_width_exp_groups,
    time_unit="s",
    ylabel="Aperiodic exponent",
    title="Average exponent around spikes",
    
    band_k=0.5,
    tmin=-0.5,   
    tmax=0.5,    # OR let it autoinfer
)

# %%
fig, ax, out_traces = plot_window_feature_group_traces(
    peak_width_gamma_groups,
    time_unit="s",   # exponent timeline is in seconds now
    ylabel="AUC gamma",
    title="Average exponent around spikes (time-resolved specparam)",
    band_k=0.5, tmin = -0.5, tmax=0.5,
)

# %%
# exponent groups already made earlier:
# exp_groups = make_feature_groups(time_res_results, feature="exponent")

window = (-0.2, 0.0)  # -200 ms to spike; times_rel is in seconds

stats_res = boxplot_feature_window_stats(
    peak_width_exp_groups,
    window=window,
    reducer="mean",
    feature_label="ap exp ",
    time_unit="s",   # 
)

print(stats_res)

# %%
# exponent groups already made earlier:
# exp_groups = make_feature_groups(time_res_results, feature="exponent")

window = (-0.002, 0.0)  # -200 ms to spike; times_rel is in seconds

stats_res = boxplot_feature_window_stats(
    peak_width_gamma_groups,
    window=window,
    reducer="mean",
    feature_label="auc gamma ",
    time_unit="s",   # 
)

print(stats_res)

# %%
patch_times_min = patch_times / 60000
lfp_times_min   = lfp_times   / 60000

plt.figure(figsize=(12, 4))
plt.plot(patch_times_min, patch_filt)
plt.title("Patch (full recording)")
plt.xlabel("Time (min)")
plt.show()

plt.figure(figsize=(12, 4))
plt.plot(lfp_times_min, lfp_filt)
plt.title("LFP (full recording)")
plt.xlabel("Time (min)")
plt.show()
