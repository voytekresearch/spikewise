# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # high res plotting

import sys
sys.path.append('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/spikeparam')
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/'))
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/spe-1/spe1_helper_modules/'))
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/shared_helper_modules'))

# General imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import warnings
import pickle

warnings.filterwarnings(
    "ignore",
    message="use_inf_as_na option is deprecated",
    category=FutureWarning,
    module="seaborn")

warnings.filterwarnings(
    "ignore",
    message=r"invalid value encountered in log10",
    category=RuntimeWarning,
    module=r".*specparam.*",
)


# NeuroDSP and FOOOF modules
from neurodsp import spectral

from specparam import Bands


# Custom modules
from lfp_spike_window_analysis import *
from spk_feat_cluster_analysis import *

from spe1_plotting import *
from spikeparam.patch.fit import Spike

from config import NPX_CHANNELS, CELL_IDS, DICT_PATCH_FS, DICT_CHAN_PRED, DICT_SPK_THRESH, FILTER_SETTINGS

# %%
cell_num =27 #MODIFY THIS WHEN RUNNING DIFFERENT CELLS 

npx_fs = 30000 # sampling rate
lfp_fs = 2500 # sampling rate

patch_fs = DICT_PATCH_FS[cell_num ]
spk_thresh = DICT_SPK_THRESH[cell_num]

npx_channels = NPX_CHANNELS
npx_patch_channel = DICT_CHAN_PRED[cell_num ]

# %% [markdown]
# ### Loading spe-1 data:
#
# I moved the data loading steps to a separate Jupyter Notebook (spe-1_load_data)

# %% [markdown]
# ## Cell 27
# ### Analyze Gamma LFP and whole patch clamp AP relationship for cell 27

# %% [markdown]
# ## Step 0: Get loaded data

# %%
lfp_dir= '/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/Neuropixel Paired Recordings/Recordings/filt_lfp_recordings/c27_lfp.npy'
patch_dir= '/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/Neuropixel Paired Recordings/Recordings/filt_patch_recordings/c27patch_filt.npy'

# %%
#get cell number 
cell_num = lfp_dir.split('/')[len(lfp_dir.split('/'))-1].split('_')[0]

#get LFP data
lfp_filt = np.load(lfp_dir)
lfp_one_ms = float(lfp_fs / 1000)
lfp_times = np.arange(0, np.shape(lfp_filt)[0]) / lfp_one_ms # in ms instead of sec

#get patch data 
patch_filt = np.load(patch_dir)
patch_one_ms = float(patch_fs  / 1000)
patch_times = np.arange(0, np.shape(patch_filt )[0]) / patch_one_ms # in ms instead of sec

# %%
# Plot simultaneous patch and LFP data
# Convert time arrays to minutes
patch_times_min = patch_times / 60000  # Convert milliseconds to minutes
lfp_times_min = lfp_times / 60000  # Convert milliseconds to minutes

# Set the common time axis in minutes (e.g., from 13.3333 to 25.6667 minutes)
common_time_range_min = np.arange(80000 / 60000, 154000 / 60000, 1 / 60000)  # Adjust as needed

# Interpolate patch data onto the common time axis
patch_interp = np.interp(common_time_range_min, patch_times_min, patch_filt)

# Interpolate LFP data onto the common time axis
lfp_interp = np.interp(common_time_range_min, lfp_times_min, lfp_filt)

# Plot patch data with common time axis in minutes
plt.figure(figsize=(10, 6))
plt.plot(common_time_range_min, patch_interp, label='Patch Data')
plt.xlabel('Time (minutes)')
plt.ylabel('Voltage')
plt.title('Patch Data with Common Time Axis (minutes)')
plt.legend()
plt.show()

# Plot LFP data with common time axis in minutes
plt.figure(figsize=(10, 6))
plt.plot(common_time_range_min, lfp_interp, label='LFP Data')
plt.xlabel('Time (minutes)')
plt.ylabel('Voltage')
plt.title('LFP Data with Common Time Axis (minutes)')
plt.legend()
plt.show()

# %% [markdown]
# ## STEP 1: Detect and fit spikes from patch data

# %%
plt.plot(patch_filt[:1000000] )

# %%
#threshold in mVs
sp = Spike(thresh_amp=15, window_length=(5., 5.), smooth_frac=.01)

# %%
sp.fit(patch_filt, patch_fs, n_jobs=-1, progress=tqdm, flip_signal=False)
# Out:
# Spike:   0%|                                           | 0/1496 [00:00<?, ?it/s]
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Spike: 100%|████████████████████████████████| 1496/1496 [00:17<00:00, 86.03it/s]

# %%
sp.plot()

# %% [markdown]
# ### Filter spikes

# %%
sp.filter_features()  # Applies default filters in-place

# %% [markdown]
# ### Get spike dataframe (with spike times column)

# %%
df_features = sp.df_features

#add columns for spike times, both in idx and ms
df_features['spk_times_idx'] = sp.spike_inds
df_features['spk_times_ms'] = patch_times[sp.spike_inds]
df_features['spk_id'] = range(len(df_features))

# %%
df_features
# Out:
#       ramp_amp  inflection_time  inflection_amp   peak_amp  peak_width  \
# 0     0.831264             0.76        2.175625  37.159431        1.54
# 1     1.301123             0.68        2.432262  26.044590        1.28
# 3     1.208969             0.66        1.659889  33.597074        1.08
# 4     0.901014             0.66       -1.549076  30.813059        1.12
# 6     0.848046             0.66        3.066991  35.618422        1.08
# ...        ...              ...             ...        ...         ...
# 1491  1.045474             0.66        4.731849  38.264729        1.08
# 1492  0.867023             0.72        3.797083  32.244505        1.14
# 1493  0.927436             0.74        3.426125  25.883916        1.48
# 1494  0.579992             0.64        4.471907  36.945890        1.06
# 1495  1.359570             0.68        1.995027  35.648128        1.10
#
#       peak_sharpness  exp_lambda  exp_const   log_isi  spk_times_idx  \
# 0           0.488185    1.060599   6.280598  1.822091          28974
# 1           0.565906    0.785925   1.198710  1.469320          32295
# 3           0.883541    1.675188   2.721035  3.078032          54213
# 4           0.899997    1.446296  -0.961640  1.517516         114083
# 6           0.978739    1.788263   4.431164  1.679039         118955
# ...              ...         ...        ...       ...            ...
# 1491        0.899013    1.643298   6.161639  1.922207       40394322
# 1492        0.731312    1.293713   3.493535  3.164163       40398504
# 1493        0.471966    0.963138   5.629404  1.815370       40471507
# 1494        0.991244    1.668280   4.414232  1.683380       40474777
# 1495        0.914450    1.806246   4.627336       NaN       40477190
#
#        spk_times_ms  spk_id
# 0        579.203281       0
# 1        645.591564       1
# 3       1083.742234       2
# 4       2280.570440       3
# 6       2377.963910       4
# ...             ...     ...
# 1491  807500.650423    1405
# 1492  807584.250482    1406
# 1493  809043.613260    1407
# 1494  809108.982030    1408
# 1495  809157.218984    1409
#
# [1410 rows x 12 columns]

# %% [markdown]
# ### Get spike times

# %%
spk_times_idx = df_features['spk_times_idx']
spk_times_ms = df_features['spk_times_ms']
spk_ids = df_features['spk_id']

# %% [markdown]
# ## STEP 2: Cluster ISI spike groups

# %%
# scan all numeric features and only cluster the ones that look multimodal
df_features_clust, rep = cluster_multimodal_features(
    df_features,
    max_k=3,
    suffix="_cluster",
    plot_each=True  # set True if you want a quick plot per clustered feature
)

# %%
df_features_clust
# Out:
#       ramp_amp  inflection_time  inflection_amp   peak_amp  peak_width  \
# 0     0.831264             0.76        2.175625  37.159431        1.54
# 1     1.301123             0.68        2.432262  26.044590        1.28
# 3     1.208969             0.66        1.659889  33.597074        1.08
# 4     0.901014             0.66       -1.549076  30.813059        1.12
# 6     0.848046             0.66        3.066991  35.618422        1.08
# ...        ...              ...             ...        ...         ...
# 1491  1.045474             0.66        4.731849  38.264729        1.08
# 1492  0.867023             0.72        3.797083  32.244505        1.14
# 1493  0.927436             0.74        3.426125  25.883916        1.48
# 1494  0.579992             0.64        4.471907  36.945890        1.06
# 1495  1.359570             0.68        1.995027  35.648128        1.10
#
#       peak_sharpness  exp_lambda  exp_const   log_isi  spk_times_idx  \
# 0           0.488185    1.060599   6.280598  1.822091          28974
# 1           0.565906    0.785925   1.198710  1.469320          32295
# 3           0.883541    1.675188   2.721035  3.078032          54213
# 4           0.899997    1.446296  -0.961640  1.517516         114083
# 6           0.978739    1.788263   4.431164  1.679039         118955
# ...              ...         ...        ...       ...            ...
# 1491        0.899013    1.643298   6.161639  1.922207       40394322
# 1492        0.731312    1.293713   3.493535  3.164163       40398504
# 1493        0.471966    0.963138   5.629404  1.815370       40471507
# 1494        0.991244    1.668280   4.414232  1.683380       40474777
# 1495        0.914450    1.806246   4.627336       NaN       40477190
#
#        spk_times_ms  spk_id ramp_amp_cluster peak_width_cluster  \
# 0        579.203281       0             high               high
# 1        645.591564       1             high                low
# 3       1083.742234       2             high                low
# 4       2280.570440       3             high                low
# 6       2377.963910       4             high                low
# ...             ...     ...              ...                ...
# 1491  807500.650423    1405             high                low
# 1492  807584.250482    1406             high                low
# 1493  809043.613260    1407             high                low
# 1494  809108.982030    1408             high                low
# 1495  809157.218984    1409             high                low
#
#      peak_sharpness_cluster log_isi_cluster
# 0                       low             low
# 1                      high             low
# 3                      high            high
# 4                      high             low
# 6                      high             low
# ...                     ...             ...
# 1491                   high             low
# 1492                   high            high
# 1493                    low             low
# 1494                   high             low
# 1495                   high             NaN
#
# [1410 rows x 16 columns]

# %% [markdown]
# ### STETP 3: Separate spikes into short ISIs and long ISIs and find transition points (long ISI spikes to group of short ISI spikes)

# %% [markdown]
# #### Visualize ISI spike cluster groups over time

# %%
plot_clusters_over_time_min(
    df_features_clust,
    time_col="spk_times_ms",
    label_col="log_isi_cluster",   
    time_unit="ms",
    bin_size_ms=1000,
    sigma_bins=2
)

# %% [markdown]
# #### Calculate transition probabilities

# %%
trans_mat = cluster_transition_matrix(df_features_clust, "log_isi_cluster")
print(trans_mat)

sns.heatmap(trans_mat, annot=True, cmap="magma", cbar=False)
plt.title("ISI cluster transition probabilities")
plt.xlabel("Next spike cluster")
plt.ylabel("Current spike cluster")
plt.show()
# Out:
#           high       low
# high  0.279743  0.720257
# low   0.569975  0.430025

# %% [markdown]
# #### Find transition points

# %%
# Identify high spikes that start low bursts
df_marked = mark_high_burst_onsets(
    df_features_clust,
    cluster_col="log_isi_cluster",
    time_col="spk_times_ms",
    min_low_run=3  # how many LOW spikes must follow to count as a burst
)

# Plot full timeline
plot_long_to_short_isi_onsets(
    df_marked,
    time_col="spk_times_ms",
    cluster_col="log_isi_cluster"          

)


# Zoom into a specific range 
plot_long_to_short_isi_onsets(
    df_marked,
    time_col="spk_times_ms",
    cluster_col="log_isi_cluster",
    time_range=(00, 20)  # seconds
)

# %%
df_marked
# Out:
#       ramp_amp  inflection_time  inflection_amp   peak_amp  peak_width  \
# 0     0.831264             0.76        2.175625  37.159431        1.54
# 1     1.301123             0.68        2.432262  26.044590        1.28
# 2     1.208969             0.66        1.659889  33.597074        1.08
# 3     0.901014             0.66       -1.549076  30.813059        1.12
# 4     0.848046             0.66        3.066991  35.618422        1.08
# ...        ...              ...             ...        ...         ...
# 1405  1.045474             0.66        4.731849  38.264729        1.08
# 1406  0.867023             0.72        3.797083  32.244505        1.14
# 1407  0.927436             0.74        3.426125  25.883916        1.48
# 1408  0.579992             0.64        4.471907  36.945890        1.06
# 1409  1.359570             0.68        1.995027  35.648128        1.10
#
#       peak_sharpness  exp_lambda  exp_const   log_isi  spk_times_idx  \
# 0           0.488185    1.060599   6.280598  1.822091          28974
# 1           0.565906    0.785925   1.198710  1.469320          32295
# 2           0.883541    1.675188   2.721035  3.078032          54213
# 3           0.899997    1.446296  -0.961640  1.517516         114083
# 4           0.978739    1.788263   4.431164  1.679039         118955
# ...              ...         ...        ...       ...            ...
# 1405        0.899013    1.643298   6.161639  1.922207       40394322
# 1406        0.731312    1.293713   3.493535  3.164163       40398504
# 1407        0.471966    0.963138   5.629404  1.815370       40471507
# 1408        0.991244    1.668280   4.414232  1.683380       40474777
# 1409        0.914450    1.806246   4.627336       NaN       40477190
#
#        spk_times_ms  spk_id ramp_amp_cluster peak_width_cluster  \
# 0        579.203281       0             high               high
# 1        645.591564       1             high                low
# 2       1083.742234       2             high                low
# 3       2280.570440       3             high                low
# 4       2377.963910       4             high                low
# ...             ...     ...              ...                ...
# 1405  807500.650423    1405             high                low
# 1406  807584.250482    1406             high                low
# 1407  809043.613260    1407             high                low
# 1408  809108.982030    1408             high                low
# 1409  809157.218984    1409             high                low
#
#      peak_sharpness_cluster log_isi_cluster  is_long_to_short_isi_onset
# 0                       low             low                       False
# 1                      high             low                       False
# 2                      high            high                        True
# 3                      high             low                       False
# 4                      high             low                       False
# ...                     ...             ...                         ...
# 1405                   high             low                       False
# 1406                   high            high                       False
# 1407                    low             low                       False
# 1408                   high             low                       False
# 1409                   high             NaN                       False
#
# [1410 rows x 17 columns]

# %% [markdown]
# #### Look at the other waveform features for the "transition" spikes
# There are no significant differences in the waveform features forr the transition spikes vs other spikes

# %%
res = compare_feature_groups(
    df_marked,
    features= ["peak_width","ramp_amp","peak_sharpness", "inflection_amp", "exp_lambda"],
    group_col="is_long_to_short_isi_onset",
    groups=(True, False),              
    group_names=("transition spike ","non-transition spike "),  
    show_plots=True
)
# Out:
# Comparing groups: True (transition spike ) vs False (non-transition spike ) using column 'is_long_to_short_isi_onset'
#
# peak_width          : t-test        (p=0.8901)
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# ramp_amp            : t-test        (p=0.6000)
# peak_sharpness      : t-test        (p=0.5762)
# inflection_amp      : t-test        (p=0.3003)
# exp_lambda          : t-test        (p=0.6920)

# %%
#also look at long ISI vs short ISI

features = ["ramp_amp", "peak_width", "peak_sharpness", "inflection_amp", "exp_lambda"]

compare_feature_groups(
    df_features_clust,
    features= features,
    group_col="log_isi_cluster",
    groups=("high", "low"),              # which two cluster labels to compare
    group_names=("long ISI", "short ISI"),    # names for plot labels
    show_plots=True
)
# Out:
# Comparing groups: high (long ISI) vs low (short ISI) using column 'log_isi_cluster'
#
# ramp_amp            : Welch t-test  (p=0.0127)
# peak_width          : Welch t-test  (p=0.0124)
# peak_sharpness      : t-test        (p=0.0282)
# inflection_amp      : Welch t-test  (p=0.0000)
# exp_lambda          : t-test        (p=0.0052)
#           feature group1 group2  median_group1  median_group2  shapiro_p_g1  \
# 3  inflection_amp   high    low       3.118326       2.890512  8.585416e-14
# 4      exp_lambda   high    low       1.201219       1.146058  2.590537e-03
# 1      peak_width   high    low       1.250000       1.280000  2.653943e-23
# 0        ramp_amp   high    low       0.735919       0.694526  2.590301e-24
# 2  peak_sharpness   high    low       0.640239       0.623925  2.075226e-07
#
#    shapiro_p_g2      levene_p          test   p_value
# 3  3.506170e-12  9.239439e-10  Welch t-test  0.000022
# 4  6.194971e-04  9.830434e-01        t-test  0.005196
# 1  4.905993e-24  4.252096e-02  Welch t-test  0.012447
# 0  9.784694e-30  1.536679e-02  Welch t-test  0.012746
# 2  3.525361e-11  1.118480e-01        t-test  0.028244

# %% [markdown]
# ## LOOK AT PEAK WIDTH CLUSTERS
# #### What do the feature distributions look like for the peak width clusters?
#
# For the peak width groups the other spike feature also follow the same groupping/clustering, except for ISI

# %%
plot_clusters_over_time_min(
    df_features_clust,
    time_col="spk_times_ms",
    label_col="peak_width_cluster",   
    time_unit="ms",
    bin_size_ms=1000,
    sigma_bins=2
)

# %%
trans_mat_peak_width = cluster_transition_matrix(df_features_clust, "log_isi_cluster")
print(trans_mat_peak_width)

sns.heatmap(trans_mat_peak_width, annot=True, cmap="magma", cbar=False)
plt.title("Peak width cluster transition probabilities")
plt.xlabel("Next spike cluster")
plt.ylabel("Current spike cluster")
plt.show()
# Out:
#           high       low
# high  0.279743  0.720257
# low   0.569975  0.430025

# %%
results_pw = compare_feature_groups(
    df_features_clust,
    features= ["ramp_amp","peak_sharpness", "inflection_amp", "exp_lambda", "log_isi"],
    group_col="peak_width_cluster",
    groups=("high", "low"),              # which two cluster labels to compare
    group_names=("wide peak","narrow peak"),    # names for plot labels
    show_plots=True
)

results_pw
# Out:
# Comparing groups: high (wide peak) vs low (narrow peak) using column 'peak_width_cluster'
#
# ramp_amp            : Welch t-test  (p=0.0000)
# peak_sharpness      : Welch t-test  (p=0.0000)
# inflection_amp      : Welch t-test  (p=0.0000)
# exp_lambda          : Welch t-test  (p=0.0000)
# log_isi             : Welch t-test  (p=0.9269)
#           feature group1 group2  median_group1  median_group2  shapiro_p_g1  \
# 1  peak_sharpness   high    low       0.276142       0.717852  7.200130e-02
# 3      exp_lambda   high    low       0.807676       1.281662  7.289739e-02
# 0        ramp_amp   high    low      -0.337511       0.862154  4.416351e-12
# 2  inflection_amp   high    low       3.768011       2.756451  8.893277e-08
# 4         log_isi   high    low       2.186523       2.291117  5.750703e-17
#
#    shapiro_p_g2       levene_p          test        p_value
# 1  1.201092e-07   7.708165e-32  Welch t-test   0.000000e+00
# 3  1.512472e-05   1.703668e-10  Welch t-test  1.908127e-258
# 0  2.610587e-12  6.001930e-101  Welch t-test   2.206813e-92
# 2  6.341525e-21   4.552444e-12  Welch t-test   1.339060e-38
# 4  4.625904e-24   2.538452e-17  Welch t-test   9.269389e-01

# %% [markdown]
# ### STEP 4: Analyze LFP around spikes

# %% [markdown]
# #### A) Transition spikes vs non-transition (control) spikes

# %%
df_marked
# Out:
#       ramp_amp  inflection_time  inflection_amp   peak_amp  peak_width  \
# 0     0.831264             0.76        2.175625  37.159431        1.54
# 1     1.301123             0.68        2.432262  26.044590        1.28
# 2     1.208969             0.66        1.659889  33.597074        1.08
# 3     0.901014             0.66       -1.549076  30.813059        1.12
# 4     0.848046             0.66        3.066991  35.618422        1.08
# ...        ...              ...             ...        ...         ...
# 1405  1.045474             0.66        4.731849  38.264729        1.08
# 1406  0.867023             0.72        3.797083  32.244505        1.14
# 1407  0.927436             0.74        3.426125  25.883916        1.48
# 1408  0.579992             0.64        4.471907  36.945890        1.06
# 1409  1.359570             0.68        1.995027  35.648128        1.10
#
#       peak_sharpness  exp_lambda  exp_const   log_isi  spk_times_idx  \
# 0           0.488185    1.060599   6.280598  1.822091          28974
# 1           0.565906    0.785925   1.198710  1.469320          32295
# 2           0.883541    1.675188   2.721035  3.078032          54213
# 3           0.899997    1.446296  -0.961640  1.517516         114083
# 4           0.978739    1.788263   4.431164  1.679039         118955
# ...              ...         ...        ...       ...            ...
# 1405        0.899013    1.643298   6.161639  1.922207       40394322
# 1406        0.731312    1.293713   3.493535  3.164163       40398504
# 1407        0.471966    0.963138   5.629404  1.815370       40471507
# 1408        0.991244    1.668280   4.414232  1.683380       40474777
# 1409        0.914450    1.806246   4.627336       NaN       40477190
#
#        spk_times_ms  spk_id ramp_amp_cluster peak_width_cluster  \
# 0        579.203281       0             high               high
# 1        645.591564       1             high                low
# 2       1083.742234       2             high                low
# 3       2280.570440       3             high                low
# 4       2377.963910       4             high                low
# ...             ...     ...              ...                ...
# 1405  807500.650423    1405             high                low
# 1406  807584.250482    1406             high                low
# 1407  809043.613260    1407             high                low
# 1408  809108.982030    1408             high                low
# 1409  809157.218984    1409             high                low
#
#      peak_sharpness_cluster log_isi_cluster  is_long_to_short_isi_onset
# 0                       low             low                       False
# 1                      high             low                       False
# 2                      high            high                        True
# 3                      high             low                       False
# 4                      high             low                       False
# ...                     ...             ...                         ...
# 1405                   high             low                       False
# 1406                   high            high                       False
# 1407                    low             low                       False
# 1408                   high             low                       False
# 1409                   high             NaN                       False
#
# [1410 rows x 17 columns]

# %%
#get LFP windows 

transition_spike_extractor = extract_lfp_windows(
    spk_df=df_marked,
    lfp_times_ms=lfp_times,
    lfp_signal=lfp_filt,
    pre_s=1.0,
    post_s=1.5, 
    condition="is_long_to_short_isi_onset"

)

windows_transition = transition_spike_extractor["windows"]
t_rel_transitions = transition_spike_extractor["times_rel_ms"]
spike_times_transition = transition_spike_extractor["spike_times_ms"]
next_spk_times_transition = transition_spike_extractor["next_spike_times_ms"]
meta_df_transitions = transition_spike_extractor["meta_df"]

# %% [markdown]
# #### B) Long ISI vs short ISI spikes

# %% [markdown]
# #### C) Wide vs narrow peak spikes
