# %%
# %load_ext autoreload
# %autoreload 3

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # high res plotting

import sys
sys.path.append('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/spikeparam')
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/'))
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/spe-1/spe1_helper_modules/'))
sys.path.append(('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/shared_helper_modules'))

# General imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import warnings
import pickle

warnings.filterwarnings(
    "ignore",
    message="use_inf_as_na option is deprecated",
    category=FutureWarning,
    module="seaborn")

warnings.filterwarnings(
    "ignore",
    message=r"invalid value encountered in log10",
    category=RuntimeWarning,
    module=r".*specparam.*",
)


# NeuroDSP and FOOOF modules
from neurodsp import spectral

from specparam import Bands


# Custom modules

from spk_feat_cluster_analysis import *

from spe1_plotting import *
from spikeparam.patch.fit import Spike

from config import NPX_CHANNELS, CELL_IDS, DICT_PATCH_FS, DICT_CHAN_PRED, DICT_SPK_THRESH, FILTER_SETTINGS

# %%
cell_num = 3#MODIFY THIS WHEN RUNNING DIFFERENT CELLS 

npx_fs = 30000 # sampling rate
lfp_fs = 3500 # sampling rate

patch_fs = DICT_PATCH_FS[cell_num ]
spk_thresh = DICT_SPK_THRESH[cell_num]

npx_channels = NPX_CHANNELS
npx_patch_channel = DICT_CHAN_PRED[cell_num ]

# %% [markdown]
# ### Loading spe-1 data:
#
# I moved the data loading steps to a separate Jupyter Notebook (spe-1_load_data)

# %% [markdown]
# ## Cell
# ### Analyze Gamma LFP and whole patch clamp AP relationship for cell

# %% [markdown]
# ## Step 0: Get loaded data

# %%
lfp_dir= '/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/Neuropixel Paired Recordings/Recordings/filt_lfp_recordings/c3_lfp.npy'
patch_dir= '/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/Neuropixel Paired Recordings/Recordings/filt_patch_recordings/c3_patch.npy'

# %%
#get cell number 
cell_num = lfp_dir.split('/')[len(lfp_dir.split('/'))-1].split('_')[0]

#get LFP data
lfp_filt = np.load(lfp_dir)
lfp_one_ms = float(lfp_fs / 1000)
lfp_times = np.arange(0, np.shape(lfp_filt)[0]) / lfp_one_ms # in ms instead of sec

#get patch data 
patch_filt = np.load(patch_dir)
patch_one_ms = float(patch_fs  / 1000)
patch_times = np.arange(0, np.shape(patch_filt )[0]) / patch_one_ms # in ms instead of sec

# %%
# Plot simultaneous patch and LFP data
# Convert time arrays to minutes
patch_times_min = patch_times / 60000  # Convert milliseconds to minutes
lfp_times_min = lfp_times / 60000  # Convert milliseconds to minutes

# Set the common time axis in minutes (e.g., from 13.3333 to 35.6667 minutes)
common_time_range_min = np.arange(80000 / 60000, 154000 / 60000, 1 / 60000)  # Adjust as needed

# Interpolate patch data onto the common time axis
patch_interp = np.interp(common_time_range_min, patch_times_min, patch_filt)

# Interpolate LFP data onto the common time axis
lfp_interp = np.interp(common_time_range_min, lfp_times_min, lfp_filt)

# Plot patch data with common time axis in minutes
plt.figure(figsize=(10, 6))
plt.plot(common_time_range_min, patch_interp, label='Patch Data')
plt.xlabel('Time (minutes)')
plt.ylabel('Voltage')
plt.title('Patch Data with Common Time Axis (minutes)')
plt.legend()
plt.show()

# Plot LFP data with common time axis in minutes
plt.figure(figsize=(10, 6))
plt.plot(common_time_range_min, lfp_interp, label='LFP Data')
plt.xlabel('Time (minutes)')
plt.ylabel('Voltage')
plt.title('LFP Data with Common Time Axis (minutes)')
plt.legend()
plt.show()

# %% [markdown]
# ## STEP 1: Detect and fit spikes from patch data

# %%
plt.plot(patch_filt[:1000000] )

# %%
#threshold in mVs
sp = Spike(thresh_amp=2, window_length=(5., 5.), smooth_frac=.01)

# %%
sp.fit(patch_filt, patch_fs, n_jobs=-1, progress=tqdm, flip_signal=False)
# Out:
# Spike:   0%|          | 0/333 [00:00<?, ?it/s]
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
sp.plot()

# %% [markdown]
# ### Filter spikes

# %%
sp.filter_features()  # Applies default filters in-place

# %% [markdown]
# ### Get spike dataframe (with spike times column)

# %%
df_features = sp.df_features

#add columns for spike times, both in idx and ms
df_features['spk_times_idx'] = sp.spike_inds
df_features['spk_times_ms'] = patch_times[sp.spike_inds]
df_features['spk_id'] = range(len(df_features))

# %%
df_features
# Out:
#      ramp_amp  inflection_time  inflection_amp  peak_amp  peak_width  \
# 0    0.264122             1.24        0.270163  7.399766        2.12
# 1    0.305352             0.90        0.924093  7.365608        1.64
# 2    0.063540             1.24        1.044653  7.857697        2.02
# 3    0.400896             1.06        0.945506  7.470144        1.88
# 4    0.348307             1.22        0.503284  7.326033        1.84
# ..        ...              ...             ...       ...         ...
# 326  1.661082             0.84        1.996995  3.558149        1.14
# 329  0.291331             1.16        0.336275  3.747598        2.02
# 330  0.114479             1.00        0.805777  3.821422        1.80
# 331  0.258692             1.00       -0.155027  3.222521        2.08
# 332  0.153041             0.94       -0.059864  3.241686        2.02
#
#      peak_sharpness  exp_lambda  exp_const   log_isi  spk_times_idx  \
# 0          0.076164    0.708176   0.096145  3.118553          74766
# 1          0.060503    0.789848  -0.201041  2.335812         140491
# 2          0.076466    0.662224   0.555727  2.290895         151330
# 3         -0.017055    0.742859   0.652443  3.125300         161104
# 4          0.015681    0.837185   0.219453  2.955037         227858
# ..              ...         ...        ...       ...            ...
# 326        0.000097    0.596642  -0.039214  3.241593       20027616
# 329        0.000489    0.486145  -0.327049  2.464997       20128441
# 330        0.061395    0.705385   0.071986  2.120169       20143035
# 331        0.061493    0.943595   0.398070  3.203483       20149632
# 332       -0.015798    1.004673   0.249591       NaN       20229553
#
#       spk_times_ms  spk_id
# 0      1494.605080       0
# 1      2808.476610       1
# 2      3025.152967       2
# 3      3220.539506       3
# 4      4554.981198       4
# ..             ...     ...
# 326  400360.813815     258
# 329  402376.349716     259
# 330  402668.090166     260
# 331  402799.967085     261
# 332  404397.622872     262
#
# [263 rows x 12 columns]

# %% [markdown]
# ### Get spike times

# %%
spk_times_idx = df_features['spk_times_idx']
spk_times_ms = df_features['spk_times_ms']
spk_ids = df_features['spk_id']

# %%
df_features.columns
# Out:
# Index(['ramp_amp', 'inflection_time', 'inflection_amp', 'peak_amp',
#        'peak_width', 'peak_sharpness', 'exp_lambda', 'exp_const', 'log_isi',
#        'spk_times_idx', 'spk_times_ms', 'spk_id'],
#       dtype='object')

# %% [markdown]
# ## STEP 2: Cluster spike groups (if any)

# %%
# scan all numeric features and only cluster the ones that look multimodal
df_features_clust, rep = cluster_multimodal_features(
    df_features,
    max_k=2,
    suffix="_cluster",
    plot_each=True,  # set True if you want a quick plot per clustered feature, 
    manual_thresholds={'peak_amp':5
    }
)

# %%
df_features_clust
# Out:
#      ramp_amp  inflection_time  inflection_amp  peak_amp  peak_width  \
# 0    0.264122             1.24        0.270163  7.399766        2.12
# 1    0.305352             0.90        0.924093  7.365608        1.64
# 2    0.063540             1.24        1.044653  7.857697        2.02
# 3    0.400896             1.06        0.945506  7.470144        1.88
# 4    0.348307             1.22        0.503284  7.326033        1.84
# ..        ...              ...             ...       ...         ...
# 326  1.661082             0.84        1.996995  3.558149        1.14
# 329  0.291331             1.16        0.336275  3.747598        2.02
# 330  0.114479             1.00        0.805777  3.821422        1.80
# 331  0.258692             1.00       -0.155027  3.222521        2.08
# 332  0.153041             0.94       -0.059864  3.241686        2.02
#
#      peak_sharpness  exp_lambda  exp_const   log_isi  spk_times_idx  \
# 0          0.076164    0.708176   0.096145  3.118553          74766
# 1          0.060503    0.789848  -0.201041  2.335812         140491
# 2          0.076466    0.662224   0.555727  2.290895         151330
# 3         -0.017055    0.742859   0.652443  3.125300         161104
# 4          0.015681    0.837185   0.219453  2.955037         227858
# ..              ...         ...        ...       ...            ...
# 326        0.000097    0.596642  -0.039214  3.241593       20027616
# 329        0.000489    0.486145  -0.327049  2.464997       20128441
# 330        0.061395    0.705385   0.071986  2.120169       20143035
# 331        0.061493    0.943595   0.398070  3.203483       20149632
# 332       -0.015798    1.004673   0.249591       NaN       20229553
#
#       spk_times_ms  spk_id peak_amp_cluster
# 0      1494.605080       0             high
# 1      2808.476610       1             high
# 2      3025.152967       2             high
# 3      3220.539506       3             high
# 4      4554.981198       4             high
# ..             ...     ...              ...
# 326  400360.813815     258              low
# 329  402376.349716     259              low
# 330  402668.090166     260              low
# 331  402799.967085     261              low
# 332  404397.622872     262              low
#
# [263 rows x 13 columns]

# %% [markdown]
# ### CLUSTER REPORTS

# %%
for col in df_features_clust.columns:
    if col.endswith("_cluster"):
        plot_full_cluster_report(df_features_clust, sp, col)
# Out:
# ===== CLUSTER REPORT: peak_amp_cluster =====
# → Plotting spike waveforms by cluster
# → Plotting cluster proportions over time
# → Computing cluster transition matrix
# ===== DONE =====

# %% [markdown]
# ### LFP analysis

# %% [markdown]
# #### Run time-resolved specparam per spike epoch

# %%
print("n spikes in df:", len(df_features_clust))
print("spk_id min / max:", df_features_clust["spk_times"].min(), df_features_clust["spk_times"].max())

print("lfp time range (ms):", lfp_times[0], "→", lfp_times[-1])
print("spike time range (ms):",
      df_features_clust["spk_times_ms"].min(),
      df_features_clust["spk_times_ms"].max())
# Out:
# n spikes in df: 263
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'spk_times'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 2
#       1 print("n spikes in df:", len(df_features_clust))
# ----> 2 print("spk_id min / max:", df_features_clust["spk_times"].min(), df_features_clust["spk_times"].max())
#       4 print("lfp time range (ms):", lfp_times[0], "→", lfp_times[-1])
#       5 print("spike time range (ms):",
#       6       df_features_clust["spk_times_ms"].min(),
#       7       df_features_clust["spk_times_ms"].max())
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'spk_times'

# %%
# Extract LFP windows for ALL spikes (no condition)
all_spike_extractor = extract_lfp_windows(
    spk_df=df_features_clust,
    lfp_times_ms=lfp_times,
    lfp_signal=lfp_filt,
    pre_s=1.0,
    post_s=1.5,
    condition=None
)

windows_all      = all_spike_extractor["windows"]
t_rel_all        = all_spike_extractor["times_rel_ms"]
spike_times_all  = all_spike_extractor["spike_times_ms"]
next_spk_all     = all_spike_extractor["next_spike_times_ms"]
meta_df_all      = all_spike_extractor["meta_df"]

# %%
meta_df_all
# Out:
#      spk_id  spike_time_ms  next_spike_time_ms     t_start_ms       t_end_ms
# 0         0    1494.605080         2808.476610     494.605080    2994.605080
# 1         1    2808.476610         3025.152967    1808.476610    4308.476610
# 2         2    3025.152967         3220.539506    2025.152967    4525.152967
# 3         3    3220.539506         4554.981198    2220.539506    4720.539506
# 4         4    4554.981198         5767.501208    3554.981198    6054.981198
# ..      ...            ...                 ...            ...            ...
# 182     182  275535.442033       277608.510414  274535.442033  277035.442033
# 183     183  277608.510414       279525.673370  276608.510414  279108.510414
# 184     184  279525.673370       282507.906866  278525.673370  281025.673370
# 185     185  282507.906866       284134.728702  281507.906866  284007.906866
# 186     186  284134.728702       288565.029538  283134.728702  285634.728702
#
# [187 rows x 5 columns]

# %%
"""specparam_by_spike = run_time_resolved_specparam_per_spike(
    lfp_windows=windows_all,
    times_rel_list=t_rel_all,
    next_rel_list=next_spk_all,
    fs=lfp_fs,
    inner_window_sec=0.5,
    freq_range=(4, 90),
    n_freqs=256,
    time_bandwidth=2.0,
    decim_factor=10,
    aperiodic_mode="fixed",
)"""
# Out:
# 'specparam_by_spike = run_time_resolved_specparam_per_spike(\n    lfp_windows=windows_all,\n    times_rel_list=t_rel_all,\n    next_rel_list=next_spk_all,\n    fs=lfp_fs,\n    inner_window_sec=0.5,\n    freq_range=(4, 90),\n    n_freqs=256,\n    time_bandwidth=2.0,\n    decim_factor=10,\n    aperiodic_mode="fixed",\n)'

# %%
"""#save as pickle
with open('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/multitaper_pickles/c3/specp_epochs.pkl', 'wb') as file:
    pickle.dump(specparam_by_spike, file)"""
# Out:
# "#save as pickle\nwith open('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/multitaper_pickles/c3/specp_epochs.pkl', 'wb') as file:\n    pickle.dump(specparam_by_spike, file)"

# %%
#open pickle
with open('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/multitaper_pickles/c3/specp_epochs.pkl', 'rb') as file:
    time_res_results = pickle.load(file)

# %% [markdown]
# #### Analyze by group

# %%
spike_inds = df_features_clust.set_index("spk_id")

# %%
def build_group_indices_from_clusters(
    df_features: pd.DataFrame,
    cluster_cols: Optional[list] = None,
    spk_id_col: str = "spk_id",
    dropna: bool = True,
):
    """
    Build spike index groups automatically from cluster columns.

    Returns
    -------
    group_indices : dict
        {
          "log_isi_cluster: low":  [spk_id, ...],
          "log_isi_cluster: high": [spk_id, ...],
          ...
        }
    """
    if spk_id_col not in df_features.columns:
        raise KeyError(f"{spk_id_col} not found in df_features")

    if cluster_cols is None:
        cluster_cols = [c for c in df_features.columns if c.endswith("_cluster")]

    group_indices = {}

    for col in cluster_cols:
        vals = df_features[col].dropna().unique()

        for v in vals:
            mask = df_features[col] == v
            spk_ids = df_features.loc[mask, spk_id_col].astype(int).tolist()

            if len(spk_ids) == 0:
                continue

            key = f"{col}: {v}"
            group_indices[key] = spk_ids

    return group_indices

# %%
group_indices = build_group_indices_from_clusters(df_features_clust)

# %%
# maps spike id → index into windows_all
spk_id_to_win_idx = {
    int(spk_id): i
    for i, spk_id in enumerate(df_features_clust["spk_id"].values)
}

# %%
groups = {}

for group_name, spk_ids in group_indices.items():

    win_inds = [
        spk_id_to_win_idx[i]
        for i in spk_ids
        if i in spk_id_to_win_idx
    ]

    if len(win_inds) == 0:
        continue

    groups[group_name] = {
        "windows":   [windows_all[i]   for i in win_inds],
        "times_rel": [t_rel_all[i] for i in win_inds],
        "next_rel": (
            np.asarray(next_spk_all)[win_inds]
            - np.asarray(spike_times_all)[win_inds]
        ),
    }
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 15
#      11 if len(win_inds) == 0:
#      12     continue
#      14 groups[group_name] = {
# ---> 15     "windows":   [windows_all[i]   for i in win_inds],
#      16     "times_rel": [t_rel_all[i] for i in win_inds],
#      17     "next_rel": (
#      18         np.asarray(next_spk_all)[win_inds]
#      19         - np.asarray(spike_times_all)[win_inds]
#      20     ),
#      21 }
#
# Cell In[47], line 15, in <listcomp>(.0)
#      11 if len(win_inds) == 0:
#      12     continue
#      14 groups[group_name] = {
# ---> 15     "windows":   [windows_all[i]   for i in win_inds],
#      16     "times_rel": [t_rel_all[i] for i in win_inds],
#      17     "next_rel": (
#      18         np.asarray(next_spk_all)[win_inds]
#      19         - np.asarray(spike_times_all)[win_inds]
#      20     ),
#      21 }
#
# IndexError: list index out of range

# %%
df_features_clust
# Out:
#      ramp_amp  inflection_time  inflection_amp  peak_amp  peak_width  \
# 0    0.264122             1.24        0.270163  7.399766        2.12
# 1    0.305352             0.90        0.924093  7.365608        1.64
# 2    0.063540             1.24        1.044653  7.857697        2.02
# 3    0.400896             1.06        0.945506  7.470144        1.88
# 4    0.348307             1.22        0.503284  7.326033        1.84
# ..        ...              ...             ...       ...         ...
# 326  1.661082             0.84        1.996995  3.558149        1.14
# 329  0.291331             1.16        0.336275  3.747598        2.02
# 330  0.114479             1.00        0.805777  3.821422        1.80
# 331  0.258692             1.00       -0.155027  3.222521        2.08
# 332  0.153041             0.94       -0.059864  3.241686        2.02
#
#      peak_sharpness  exp_lambda  exp_const   log_isi  spk_times_idx  \
# 0          0.076164    0.708176   0.096145  3.118553          74766
# 1          0.060503    0.789848  -0.201041  2.335812         140491
# 2          0.076466    0.662224   0.555727  2.290895         151330
# 3         -0.017055    0.742859   0.652443  3.125300         161104
# 4          0.015681    0.837185   0.219453  2.955037         227858
# ..              ...         ...        ...       ...            ...
# 326        0.000097    0.596642  -0.039214  3.241593       20027616
# 329        0.000489    0.486145  -0.327049  2.464997       20128441
# 330        0.061395    0.705385   0.071986  2.120169       20143035
# 331        0.061493    0.943595   0.398070  3.203483       20149632
# 332       -0.015798    1.004673   0.249591       NaN       20229553
#
#       spk_times_ms  spk_id peak_amp_cluster
# 0      1494.605080       0             high
# 1      2808.476610       1             high
# 2      3025.152967       2             high
# 3      3220.539506       3             high
# 4      4554.981198       4             high
# ..             ...     ...              ...
# 326  400360.813815     258              low
# 329  402376.349716     259              low
# 330  402668.090166     260              low
# 331  402799.967085     261              low
# 332  404397.622872     262              low
#
# [263 rows x 13 columns]

# %%
for k, v in group_indices.items():
    print(k, type(v))
    if isinstance(v, list):
        print("  example element:", v[0] if len(v) > 0 else None)

# %%
404397.622872/1000/60
# Out:
# 6.7399603812

# %%
# Patch
print("PATCH:")
print("  n samples:", len(patch_filt))
print("  fs (Hz):  ", patch_fs)
print("  duration (s):", len(patch_filt) / patch_fs)
print("  duration (min):", len(patch_filt) / patch_fs / 60)

# LFP
print("LFP:")
print("  n samples:", len(lfp_filt))
print("  fs (Hz):  ", lfp_fs)
print("  duration (s):", len(lfp_filt) / lfp_fs)
print("  duration (min):", len(lfp_filt) / lfp_fs / 60)
# Out:
# PATCH:
#   n samples: 20260530
#   fs (Hz):   50023.91669944
#   duration (s): 405.0168666666361
#   duration (min): 6.750281111110601
# LFP:
#   n samples: 1012540
#   fs (Hz):   3500
#   duration (s): 289.29714285714283
#   duration (min): 4.8216190476190475

# %%
patch_times_min = patch_times / 60000
lfp_times_min   = lfp_times   / 60000

plt.figure(figsize=(12, 4))
plt.plot(patch_times_min, patch_filt)
plt.title("Patch (full recording)")
plt.xlabel("Time (min)")
plt.show()

plt.figure(figsize=(12, 4))
plt.plot(lfp_times_min, lfp_filt)
plt.title("LFP (full recording)")
plt.xlabel("Time (min)")
plt.show()
