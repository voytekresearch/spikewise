# %%
import os
save_dir = "/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/spe-1/c21_chunks"

print(f"Does directory exist? {os.path.exists(save_dir)}")
if os.path.exists(save_dir):
    files = os.listdir(save_dir)
    print(f"Files found in folder: {len(files)}")
    for f in files:
        file_path = os.path.join(save_dir, f)
        size_mb = os.path.getsize(file_path) / (1024 * 1024)
        print(f" - {f} ({size_mb:.2f} MB)")
else:
    print("The folder hasn't been created yet.")
# Out:
# Does directory exist? False
# The folder hasn't been created yet.
