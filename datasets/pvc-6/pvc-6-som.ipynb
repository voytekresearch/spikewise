# %%
# basic plotting imports
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # high res plotting

import h5py

import numpy as np
import pandas as pd

from neurodsp import spectral
from scipy.signal import find_peaks
from scipy.optimize import curve_fit
from scipy.stats import pearsonr
from scipy.stats import f_oneway
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.preprocessing import OneHotEncoder
from statsmodels.stats.multicomp import pairwise_tukeyhsd

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(12,9)})
sns.set_style('whitegrid')
sns.set_style("whitegrid", {'axes.grid' : False})

# %% [markdown]
# #### Data source
#
# These data are the [PVC-6 data from CRCNS](https://crcns.org/data-sets/vc/pvc-6/about_pvc-6). From their summary:
#
# >The data sets consist of whole cell current clamp slice electrophysiology recordings made from single neurons from coronal sections of the visual cortex of adult male mice. The experiments were performed in the presence of blockers of fast synaptic transmission with the goal of understanding the diversity of intrinsic neuronal excitability between cell classes. These experiments represent preliminary datasets being used to refine methods working towards producing slice electrophysiology data at scale.
#
# These data are ideal for several reasons. First, and most critical for us, is that they're sampled at 200,000 Hz! So if we want to parameterize individual action potentials, for a 1ms AP we'll have 200 data points. This is much more approachable than the 20-40 datapoints that have been limiting us on the other datsets.
#
# Second, these are intracellular patch clamp recordings, so they're not susceptible to our concern that extracellular AP shapes are affected by the position of the electrode relative to the neuron, which is not necessaily stable over time (meaning that any observed AP shape differences could theoretically be driven by movement rather than physiology).
#
# Finally, these neurons were driven by 1/f pink noise, which we like a lot. The variability of the 1/f exponent over time will allow us to link stimulus parameters to any variation in AP shape parameters.

# %%
# open and load the data

fs = 200000 # sampling rate
one_ms = int(fs / 1000)

total_sweeps = 66

# 153098_04_02_data has 0 through 66 sweeps
# 151145_04_Data  has 0 through 91 sweeps
filename = '/Users/blancamartin/Downloads/153098.04.02_data.h5' # filename

# open file
f = h5py.File(filename, 'r')

# list(f.keys())

# qc_data = f['qcSweep_Key']
# qc_data[0, :, :]

# %%
# helper functions

# load sweeps
def load_sweep(sweep_number):
    # load sweep
    dset = f['Sweep_' + str(sweep_number)]

    # create array of time indices
    convert_to_ms = (fs / 1000)
    times = np.arange(0, np.shape(dset)[0]) / convert_to_ms # in ms instead of sec

    return dset, times

# get the power spectrum of the stimulus
def get_stim_spectrum(dset, fs, nperseg, all_data=True):
    
    if all_data == True:
        stim_data = dset[:, 0]
        fxx, pxx = spectral.compute_spectrum(stim_data, fs, method='welch',
                    window='hann', nperseg=nperseg)
    
    if all_data == False:
        fxx, pxx = spectral.compute_spectrum(dset, fs, method='welch',
                window='hann', nperseg=nperseg)
        
    return fxx, pxx

# plot the ephys data
def plot_ephys_data(dset, times, index_start, index_end):
    plot_range = (index_start, index_end)
    plt.plot(times[plot_range[0]:plot_range[1]],
        dset[plot_range[0]:plot_range[1], 1], '.')

# plot the stimulus
def plot_stim_data(dset, times, index_start, index_end):
    plot_range = (index_start, index_end)
    plt.plot(times[plot_range[0]:plot_range[1]],
        dset[plot_range[0]:plot_range[1], 0], '.')

# plot the stimulus spectrum
def plot_stim_spectrum(fxx, pxx, xlim, ylim):
    plt.loglog(fxx, pxx)
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Power (V^2/Hz)')
    plt.xlim(xlim)
    plt.ylim(ylim)

# find the spike times
def find_spike_times(data, thresh_mv, thresh_ms):
    # thresh_mv is the voltage threshold that needs to be crossed
    # thresh_ms is how many ms each peak needs to be from the next

    peaks = find_peaks(data, height=thresh_mv, distance=thresh_ms)
    idx_spikes = peaks[0] # spike indices
    amp_spikes = peaks[1]['peak_heights'] # spike amplitudes

    return idx_spikes, amp_spikes

# define exponential function
def exp_func(times, exp_amp, exp_lambda, exp_timeshift, exp_const):
    return exp_amp * np.exp(-exp_lambda * (times - exp_timeshift)) + exp_const

# fit exponential data
def fit_exp_nonlinear(times, data, initial_guesses, bounds):
    popt, _ = curve_fit(exp_func, times, data, p0=initial_guesses, bounds=bounds,  maxfev=10000)
    exp_amp, exp_lambda, exp_timeshift, exp_const = popt
    return exp_amp, exp_lambda, exp_timeshift, exp_const

# %% [markdown]
# #### Constant current
#
# Some of the sweeps are driven by a constant current, as can be seen below. For now we'll ignore these, but in theory, depending on the stimulus parameters, these could be used to measure any AP shape parameter adaptation over time, as well as a control to compare against 1/f pink noise stimulation.

# %%
sweep_number = 3
index_start = 403900
index_end = 406000

dset, times = load_sweep(sweep_number)
plot_ephys_data(dset, times, index_start, index_end)
plot_stim_data(dset, times, index_start, index_end)
plt.show()

# %% [markdown]
# #### Pink noise (1/f) stimulation
#
# Many of the sweeps are drive by pink noise, and we can leverage the variability in this stimulus to examine the link between variations in the stimulus and AP shape parameters.

# %%
sweep_number = 14
index_start = 0
index_end = int(10e10)

dset, times = load_sweep(sweep_number)
plot_ephys_data(dset, times, index_start, index_end)
plot_stim_data(dset, times, index_start, index_end)
plt.show()

# %% [markdown]
# #### Pink noise stimulus spectrum
#
# You can see below that the stimulus is only 1/f in the range of ~[10, 200], so for future 1/f paramterization, we'll fit a linear regression to the loglog spectrum on that range, if the time windows are sufficient. - the analysis here was running specparam on the data not the stimulus :0

# %% [markdown]
# ### Do all the pink noise info gathering here

# %%
#generate dict with info of pink noise variations
all_pink_noise = {}
pink_type_num = 0
#pink_stim_dict = {}
pink_types = []



# 0 through 66 sweeps
for i_sweeps in range(66):


    #load data
    dset, times = load_sweep(i_sweeps)

    stim_data = dset[:, 0] # current injection
    

    # set the first 25 ms to zero to get rid of mini-pulse at beginning
    #stim_data[0:5000] = 0
    #stim_data = stim_data[stim_data!=0]
    
 

    if np.size(stim_data) > 2:
        # a pearson correlation between current and time is
            # nan for constant, near 1.0 for ramp, and low for pink noise
        r, _ = pearsonr(np.arange(np.size(stim_data)), stim_data)
        

        # check stim type
        if (np.isnan(r)):
            stim_type = 'constant'
            pink_type = 'none'
        elif (~np.isnan(r) & (r>0.95)):
            stim_type = 'ramp'
            pink_type = "none"
        elif (~np.isnan(r) & (r<0.95)):
            stim_type = 'pink'
    else:
        stim_type = 'none'
        pink_type = 'none'


    if stim_type == 'pink':
        
        #get specific variation of pink noise 
        if r  not in all_pink_noise:
            pink_type_num = pink_type_num + 1
            pink_type = 'PinkNoise'+str(pink_type_num)
            all_pink_noise[r] = pink_type
            #get power spec for that pink noise type 
            fxx, pxx = get_stim_spectrum(stim_data, fs, nperseg=fs/4, all_data = False)
            xlim = (10e-2, 10e5)
            ylim = (10e-10, 10e-1)
            plot_stim_spectrum(fxx, pxx, xlim, ylim)
            plt.axvline(x=10)
            plt.axvline(x=200)
            plt.title(pink_type)
            plt.show()


        else:
            pink_type = all_pink_noise[r]
            
    pink_types.append(pink_type)

# %% [markdown]
# #### Process the data!
#
# The pink noise sweeps all begin with a brief (sub-threshold, always?) stimulus, and then the pink noise stimulus that evokes APs. I use a simple peak-finding approach to find all APs, and then extract time windows around those APs for parameterization of both the APs and the stimulus.
#
# In order to find the inflection point where the AP "starts", we take the difference (~derivative) of the intracellular data around the spike, and find the point where that derivative rises above the noise. This differenced time series is smoothed using simple lowess smoothing, to make things easier.
#
# One cool thing to note here is how similar to an extracelluar AP this derivative of the intracellular AP looks! This probably isn't a coincidence, and has been remarked upon for a very long time. It's worth considering in our future analyses.

# %%
# Plot single spike, and its derivative
i_sweeps = 14

dset, times = load_sweep(i_sweeps)

stim = dset[:, 0] # current injection
data = dset[:, 1] # ephys data

#########################
# find spikes
thresh_mv = -10
thresh_ms = one_ms * 1 # 1 ms

idx_spikes, amp_spikes = find_spike_times(data, thresh_mv, thresh_ms)

#########################
i_spikes = 0
    
# get windows around spikes
# create window indices
window_length = (10, 10) # in ms
window_pre = int(one_ms * window_length[0])
window_post = int(one_ms * window_length[1])

# get window
window_spike_pre = (idx_spikes[i_spikes]-window_pre)
window_spike_post = (idx_spikes[i_spikes]+window_post)

# get window for times as well
windowed_times = times[(idx_spikes[i_spikes]-window_pre):
                    (idx_spikes[i_spikes]+window_post)]

# get data window
windowed_data = data[window_spike_pre:window_spike_post]

# difference of data, and smooth it
d_windowed_data = np.diff(windowed_data)
smoothed_data = sm.nonparametric.lowess(d_windowed_data, windowed_times[1:], frac=0.008)

# smoothed data
d_smoothed_times = smoothed_data[:, 0]
d_smoothed_data = smoothed_data[:, 1]

plt.plot(windowed_times, windowed_data, 'b', alpha = 0.8, linewidth = 3., label='intra')
plt.plot(d_smoothed_times, (d_smoothed_data*80)-50, 'k', linewidth = 3., label='differenced')
plt.legend()
plt.show()

# %%
# set up data for appending, to move to df because ugh
df_sweep = []
df_stim_type = []
df_spike_number = []
df_voltage_ramp = []
df_inflection_time = []
df_inflection_mv = []
df_peak_amplitude = []
df_peak_sharpness = []
df_decay_lambda = []
df_decay_const = []
# df_spike_width = []
df_stim_exp = []
df_stim_mean = []
df_stim_std = []
df_pink_subtype = []

# 0 through 66 sweeps
for i_sweeps in range(66):

    #load data
    dset, times = load_sweep(i_sweeps)

    stim = dset[:, 0] # current injection
    data = dset[:, 1] # ephys data

    #########################
    # find spikes
    thresh_mv = -10
    thresh_ms = one_ms * 1 # 1 ms

    idx_spikes, amp_spikes = find_spike_times(data, thresh_mv, thresh_ms)

    #########################
    # loop across spikes
    if np.size(idx_spikes) > 0:

        #########################
        # check if sweep stim is constant, ramp, or pink

        stim_data = dset[:, 0]

        # set the first 25 ms to zero to get rid of mini-pulse at beginning
        stim_data[0:5000] = 0
        stim_data = stim_data[stim_data!=0]

        if np.size(stim_data) > 2:
            # a pearson correlation between current and time is
                # nan for constant, near 1.0 for ramp, and low for pink noise
            r, _ = pearsonr(np.arange(np.size(stim_data)), stim_data)

            # check stim type
            if (np.isnan(r)):
                stim_type = 'constant'
            elif (~np.isnan(r) & (r>0.95)):
                stim_type = 'ramp'
            elif (~np.isnan(r) & (r<0.95)):
                stim_type = 'pink'
                
        else:
            stim_type = 'none'

        #########################
        # paramterize each spike
        for i_spikes in range(np.size(idx_spikes)):
            # get windows around spikes
            # create window indices
            window_length = (10, 10) # in ms
            window_pre = int(one_ms * window_length[0])
            window_post = int(one_ms * window_length[1])

            # get window
            window_spike_pre = (idx_spikes[i_spikes]-window_pre)
            window_spike_post = (idx_spikes[i_spikes]+window_post)

            # get window for times as well
            windowed_times = times[(idx_spikes[i_spikes]-window_pre):
                                (idx_spikes[i_spikes]+window_post)]

            # get data window
            windowed_data = data[window_spike_pre:window_spike_post]

            # difference of data, and smooth it
            d_windowed_data = np.diff(windowed_data)
            smoothed_data = sm.nonparametric.lowess(d_windowed_data, windowed_times[1:], frac=0.008)

            # smoothed data
            d_smoothed_times = smoothed_data[:, 0]
            d_smoothed_data = smoothed_data[:, 1]


            #########################
            # inflection_time
            thresh_zscore = 40 # zscore threshold for inflection point
                                # REALLY high, since it's so low noise

            # get mean and std of first ms of data
            noise_window = d_smoothed_data[0:one_ms] 
            noise_mean = np.mean(noise_window)
            noise_std = np.std(noise_window)

            # zscore spike relative to window above
            z_data = (d_smoothed_data-noise_mean) / noise_std

            # find the peak of the zscored data
            idx_z_peak, _ = find_spike_times(z_data, thresh_zscore, thresh_ms)

            # find the peak of the real data
            idx_spike_peak, _ = find_spike_times(windowed_data, thresh_mv, thresh_ms)

            # find inflection voltage and time relative to spike peak
            inflection_time = np.abs(z_data[0:idx_z_peak[0]]-thresh_zscore)
            idx_inflection = np.argmin(inflection_time)

            # get the voltage ramp slope for the 0.5 ms before inflection point
            idx_ramp_start = idx_inflection - int(0.5 * one_ms) # 0.5 ms before
            ramp_times = windowed_times[idx_ramp_start:idx_inflection]

            voltage_ramp, _ = np.polyfit(ramp_times, windowed_data[idx_ramp_start:idx_inflection], 1)

            inflection_time = idx_spike_peak - idx_inflection
            inflection_time = inflection_time[0] / one_ms

            inflection_mv = windowed_data[idx_inflection]


            #########################
            # peak voltage
            idx_spike_peak, amp_spike_peak = find_spike_times(windowed_data, thresh_mv, thresh_ms)
            mv_peak = amp_spike_peak[0]


            #########################
            # peak sharpness
                # this is just Scott's simple oscillation sharpness approach
            sharpness_peak = ((windowed_data[idx_spike_peak[0]]-windowed_data[idx_spike_peak[0]-5]) + 
            (windowed_data[idx_spike_peak[0]]-windowed_data[idx_spike_peak[0]+5])) / 2


            #########################
            # voltage decay rate and voltage floor
            decay_curve_shift = one_ms/2 # the ap peak is curved, so shift to the right to get a cleaner decay
            decay_curve_floor_time = one_ms*5 # decide when to call it the floor
            idx_spike_peak, amp_peak = find_spike_times(windowed_data, thresh_mv, thresh_ms)
            exp_window = idx_spike_peak[0]+int(decay_curve_shift) # shift to the right
            exp_window_end = exp_window+int(decay_curve_floor_time) # when to end the curve
            exp_data = windowed_data[exp_window:exp_window_end]
            exp_times = windowed_times[exp_window:exp_window_end]

            # initial guesses, derived from physiological estimating
            initial_guesses = np.array([50, 1, windowed_times[exp_window], -60], dtype=np.float64)
            bounds = ([0, 0, 0, -100], [1000, 3, 10e9, 50]) # set some reasonable bounds

            # fit the dang thing
            exp_amp, exp_lambda, exp_timeshift, exp_const = \
                fit_exp_nonlinear(exp_times, exp_data, initial_guesses, bounds)

            # # check the fit
            # fitted_model = exp_func(exp_times, exp_amp, exp_lambda, exp_timeshift, exp_const)

            # # plot it!
            # plt.plot(exp_times, exp_data, 'k')
            # plt.plot(exp_times, fitted_model, 'b')
            # plt.show()


            if stim_type == 'pink':
                pink_type = pink_types[i_sweeps]
                
                #########################
                # quantify stimulus parameters

                # create window indices
                window_length = (10, 10) # in ms
                window_pre = int(one_ms * window_length[0])
                window_post = int(one_ms * window_length[1])
                
                # get the 5 ms before the inflection point
                inflection_pre_window = int(idx_inflection - (one_ms * 5))

                # get window
                window_spike_pre = (idx_spikes[i_spikes]-window_pre)
                window_spike_post = (idx_spikes[i_spikes]+window_post)

                windowed_stim = stim[window_spike_pre:window_spike_post]
                windowed_stim = windowed_stim[inflection_pre_window:idx_inflection]

                # get slope of spectrum (exponent)
                fxx, pxx = spectral.compute_spectrum(windowed_stim, fs, method='welch',
                                window='hann', nperseg=np.size(windowed_stim))

                # get rid of zero Hz
                fxx = fxx[1:]
                pxx = pxx[1:]

                stim_exp, _ = np.polyfit(np.log10(fxx), np.log10(pxx), 1)
                stim_exp = -stim_exp # change from slope to exponent

                # stim mean and std
                stim_mean = np.mean(windowed_stim)
                stim_std = np.std(windowed_stim)
            
            else: # not pink noise, so set stim params to nan
                stim_exp = np.nan
                stim_mean = np.nan
                stim_std = np.nan


            #########################
            # collect all the relevant features
            df_sweep.append(i_sweeps)
            df_stim_type.append(stim_type)
            df_spike_number.append(i_spikes)
            df_voltage_ramp.append(voltage_ramp)
            df_inflection_time.append(inflection_time)
            df_inflection_mv.append(inflection_mv)
            df_peak_amplitude.append(mv_peak)
            df_peak_sharpness.append(sharpness_peak)
            df_decay_lambda.append(exp_lambda)
            df_decay_const.append(exp_const)
            # df_spike_width.append(spike_width)
            df_stim_exp.append(stim_exp)
            df_stim_mean.append(stim_mean)
            df_stim_std.append(stim_std)
            df_pink_subtype.append(pink_type)

        # print(voltage_ramp, inflection_time, inflection_mv, mv_peak, sharpness_peak, exp_lambda, exp_const,
        #         stim_exp, stim_mean, stim_std)
# Out:
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/2491107949.py:50: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, _ = pearsonr(np.arange(np.size(stim_data)), stim_data)

# %%
# create df
    # stim_type = 'constant', 'ramp', 'pink'
df = pd.DataFrame({'sweep': df_sweep, 'stim_type': df_stim_type, 'spike_num': df_spike_number,
                    'voltage_ramp': df_voltage_ramp, 'inflection_time': df_inflection_time,
                    'inflection_amp': df_inflection_mv, 'peak_amp': df_peak_amplitude,
                    'peak_sharp': df_peak_sharpness, 'decay_exp': df_decay_lambda,
                    'decay_const': df_decay_const, 'stim_exp': df_stim_exp, 'stim_mean': df_stim_mean,
                    'stim_std': df_stim_std,'pink_subtype':df_pink_subtype },
        columns=['sweep', 'stim_type', 'spike_num', 'voltage_ramp', 'inflection_time', 'inflection_amp',
                'peak_amp', 'peak_sharp', 'decay_exp', 'decay_const', 'stim_exp', 'stim_mean', 'stim_std', 'pink_subtype'])

# %%
df
# Out:
#      sweep stim_type  spike_num  voltage_ramp  inflection_time  \
# 0        0      ramp          0      3.762189            0.710
# 1        0      ramp          1      2.989387            0.805
# 2        0      ramp          2      3.652115            0.790
# 3        0      ramp          3      3.607448            0.800
# 4        1      ramp          0      3.763689            0.725
# ..     ...       ...        ...           ...              ...
# 815     65  constant         45      5.625113            0.880
# 816     65  constant         46      5.939582            0.835
# 817     65  constant         47      8.396302            0.770
# 818     65  constant         48      5.400015            0.865
# 819     65  constant         49      6.580258            0.800
#
#      inflection_amp  peak_amp  peak_sharp  decay_exp  decay_const  stim_exp  \
# 0        -41.781251   9.03125    0.140625   1.602289   -61.798569       NaN
# 1        -40.625001   8.40625    0.140625   1.524883   -61.218840       NaN
# 2        -39.593751   7.71875    0.125000   1.501875   -60.876914       NaN
# 3        -40.093751   8.06250    0.125000   1.539862   -60.350603       NaN
# 4        -41.093751   9.15625    0.125000   1.631701   -63.028807       NaN
# ..              ...       ...         ...        ...          ...       ...
# 815      -39.093751   1.00000    0.125000   1.346511   -58.107196       NaN
# 816      -39.000001   1.93750    0.156250   1.457372   -57.555227       NaN
# 817      -36.531251   1.28125    0.062500   1.437226   -57.256073       NaN
# 818      -38.500001   0.62500    0.093750   1.352120   -57.821610       NaN
# 819      -37.250001   1.59375    0.125000   1.384833   -57.400574       NaN
#
#      stim_mean  stim_std pink_subtype
# 0          NaN       NaN         none
# 1          NaN       NaN         none
# 2          NaN       NaN         none
# 3          NaN       NaN         none
# 4          NaN       NaN         none
# ..         ...       ...          ...
# 815        NaN       NaN   PinkNoise9
# 816        NaN       NaN   PinkNoise9
# 817        NaN       NaN   PinkNoise9
# 818        NaN       NaN   PinkNoise9
# 819        NaN       NaN   PinkNoise9
#
# [820 rows x 14 columns]

# %%
df_pink = df.loc[df['stim_type'] == 'pink']
df_pink = df_pink.drop(['sweep', 'stim_type', 'pink_subtype'], axis=1)

pd.plotting.scatter_matrix(df_pink, alpha=0.5)
plt.show()

spikes_corr = df_pink.corr()
# plot the heatmap and annotation on it
sns.heatmap(spikes_corr, xticklabels=spikes_corr.columns, yticklabels=spikes_corr.columns, annot=True)
plt.show()

rho = df_pink.corr()
pval = df_pink.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [0.001,0.01,0.05] if x<=t]))
rho.round(2).astype(str) + p
# Out:
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/1229981892.py:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   p = pval.applymap(lambda x: ''.join(['*' for t in [0.001,0.01,0.05] if x<=t]))
#                 spike_num voltage_ramp inflection_time inflection_amp  \
# spike_num          1.0***      0.32***          0.6***        0.53***
# voltage_ramp      0.32***       1.0***            0.1*        0.76***
# inflection_time    0.6***         0.1*          1.0***        0.63***
# inflection_amp    0.53***      0.76***         0.63***         1.0***
# peak_amp         -0.48***     -0.56***        -0.63***       -0.79***
# peak_sharp       -0.27***     -0.19***         -0.4***       -0.39***
# decay_exp        -0.68***     -0.48***        -0.82***       -0.88***
# decay_const       0.71***      0.42***         0.66***        0.66***
# stim_exp           -0.12*        -0.09           -0.06          -0.06
# stim_mean         0.36***        0.11*            0.02           0.01
# stim_std          0.18***         0.07            0.08           0.06
#
#                  peak_amp peak_sharp decay_exp decay_const  stim_exp  \
# spike_num        -0.48***   -0.27***  -0.68***     0.71***    -0.12*
# voltage_ramp     -0.56***   -0.19***  -0.48***     0.42***     -0.09
# inflection_time  -0.63***    -0.4***  -0.82***     0.66***     -0.06
# inflection_amp   -0.79***   -0.39***  -0.88***     0.66***     -0.06
# peak_amp           1.0***    0.35***   0.77***    -0.59***      0.09
# peak_sharp        0.35***     1.0***   0.43***     -0.3***      0.1*
# decay_exp         0.77***    0.43***    1.0***    -0.71***      0.08
# decay_const      -0.59***    -0.3***  -0.71***      1.0***    -0.11*
# stim_exp             0.09       0.1*      0.08      -0.11*    1.0***
# stim_mean           -0.03       0.02     -0.04     0.48***     -0.04
# stim_std           -0.11*      -0.1*     -0.09     0.18***  -0.85***
#
#                 stim_mean  stim_std
# spike_num         0.36***   0.18***
# voltage_ramp        0.11*      0.07
# inflection_time      0.02      0.08
# inflection_amp       0.01      0.06
# peak_amp            -0.03    -0.11*
# peak_sharp           0.02     -0.1*
# decay_exp           -0.04     -0.09
# decay_const       0.48***   0.18***
# stim_exp            -0.04  -0.85***
# stim_mean          1.0***    0.14**
# stim_std           0.14**    1.0***

# %%
df
# Out:
#      sweep stim_type  spike_num  voltage_ramp  inflection_time  \
# 0        0      ramp          0      3.762189            0.710
# 1        0      ramp          1      2.989387            0.805
# 2        0      ramp          2      3.652115            0.790
# 3        0      ramp          3      3.607448            0.800
# 4        1      ramp          0      3.763689            0.725
# ..     ...       ...        ...           ...              ...
# 815     65  constant         45      5.625113            0.880
# 816     65  constant         46      5.939582            0.835
# 817     65  constant         47      8.396302            0.770
# 818     65  constant         48      5.400015            0.865
# 819     65  constant         49      6.580258            0.800
#
#      inflection_amp  peak_amp  peak_sharp  decay_exp  decay_const  stim_exp  \
# 0        -41.781251   9.03125    0.140625   1.602289   -61.798569       NaN
# 1        -40.625001   8.40625    0.140625   1.524883   -61.218840       NaN
# 2        -39.593751   7.71875    0.125000   1.501875   -60.876914       NaN
# 3        -40.093751   8.06250    0.125000   1.539862   -60.350603       NaN
# 4        -41.093751   9.15625    0.125000   1.631701   -63.028807       NaN
# ..              ...       ...         ...        ...          ...       ...
# 815      -39.093751   1.00000    0.125000   1.346511   -58.107196       NaN
# 816      -39.000001   1.93750    0.156250   1.457372   -57.555227       NaN
# 817      -36.531251   1.28125    0.062500   1.437226   -57.256073       NaN
# 818      -38.500001   0.62500    0.093750   1.352120   -57.821610       NaN
# 819      -37.250001   1.59375    0.125000   1.384833   -57.400574       NaN
#
#      stim_mean  stim_std pink_subtype
# 0          NaN       NaN         none
# 1          NaN       NaN         none
# 2          NaN       NaN         none
# 3          NaN       NaN         none
# 4          NaN       NaN         none
# ..         ...       ...          ...
# 815        NaN       NaN   PinkNoise9
# 816        NaN       NaN   PinkNoise9
# 817        NaN       NaN   PinkNoise9
# 818        NaN       NaN   PinkNoise9
# 819        NaN       NaN   PinkNoise9
#
# [820 rows x 14 columns]

# %% [markdown]
# ### Compare spike features for pink noise subtype

# %% [markdown]
# #### Boxplots

# %%
# Group the dataframe by pink subtype
grouped_df = df.groupby('pink_subtype')

# Iterate over each feature
for feature in df.columns:
    if feature not in ['sweep', 'stim_type', 'pink_subtype']:
        print("Feature:", feature)
        # Boxplot for each feature across pink subtypes
        plt.figure(figsize=(10, 6))
        sns.boxplot(x='pink_subtype', y=feature, data=df)
        plt.title(f'Boxplot of {feature} across Pink Subtypes')
        plt.xticks(rotation=45)
        plt.show()
# Out:
# Feature: spike_num
# Feature: voltage_ramp
# Feature: inflection_time
# Feature: inflection_amp
# Feature: peak_amp
# Feature: peak_sharp
# Feature: decay_exp
# Feature: decay_const
# Feature: stim_exp
# Feature: stim_mean
# Feature: stim_std

# %% [markdown]
# #### ANOVAs

# %%
# Create an empty list to store the ANOVA results
anova_results = []

# Perform ANOVA for each feature
for column in df.columns:
    if column not in ['sweep', 'stim_type', 'pink_subtype']:
        # Filter out NaNs and exclude 'none' subtype for stim features
        if 'stim' in column:
            df_filtered = df[df['pink_subtype'] != 'none'].dropna(subset=[column])
        else:
            df_filtered = df.dropna(subset=[column])
            
        # Perform ANOVA
        model = ols(f'{column} ~ C(pink_subtype)', data=df_filtered).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)
        
        # Extract F-value and p-value
        f_value = anova_table['F'][0]
        p_value = anova_table['PR(>F)'][0]
        
        # Append results to the list
        anova_results.append({'Feature': column, 'F-value': f_value, 'p-value': p_value})

# Create a DataFrame from the list
anova_results_df = pd.DataFrame(anova_results)
# Out:
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_value = anova_table['F'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_table['PR(>F)'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_value = anova_table['F'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_table['PR(>F)'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_value = anova_table['F'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_table['PR(>F)'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_value = anova_table['F'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_table['PR(>F)'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_value = anova_table['F'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_table['PR(>F)'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_value = anova_table['F'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_table['PR(>F)'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_value = anova_table['F'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_table['PR(>F)'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_value = anova_table['F'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_table['PR(>F)'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_value = anova_table['F'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_table['PR(>F)'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_value = anova_table['F'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_table['PR(>F)'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_value = anova_table['F'][0]
# /var/folders/rr/tk8wmt7x4xlgzgmcy768y1rm0000gn/T/ipykernel_1630/433610263.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = anova_table['PR(>F)'][0]

# %%
# Threshold for significance
threshold = 0.05

# Function to determine significance
def is_significant(p_value):
    return 'Yes' if p_value < threshold else 'No'

# Add a column for significance
anova_results_df['Significance'] = anova_results_df['p-value'].apply(is_significant)

# Display ANOVA results with significance
print("ANOVA results with significance:")
print(anova_results_df)
# Out:
# ANOVA results with significance:
#             Feature    F-value        p-value Significance
# 0         spike_num  22.105817   9.186600e-37          Yes
# 1      voltage_ramp  11.571733   9.833565e-19          Yes
# 2   inflection_time  11.294141   3.052535e-18          Yes
# 3    inflection_amp  10.994770   1.037228e-17          Yes
# 4          peak_amp  68.522063  8.381357e-101          Yes
# 5        peak_sharp   3.217576   4.479023e-04          Yes
# 6         decay_exp  16.703077   1.095654e-27          Yes
# 7       decay_const  32.761625   1.503761e-53          Yes
# 8          stim_exp   2.356183   1.333733e-02          Yes
# 9         stim_mean  39.303642   3.666852e-50          Yes
# 10         stim_std   4.983334   2.236412e-06          Yes

# %% [markdown]
# #### Tukey's HSD posthoc

# %%
# List to store Tukey's HSD test results
tukey_results = []

# Perform Tukey's HSD test for each numerical column
for column in df.select_dtypes(include=['float64', 'int64']).columns:
    if column not in ['sweep', 'stim_type', 'pink_subtype']:
        if 'stim' in column:
            df_filtered = df[df['pink_subtype'] != 'none'].dropna(subset=[column])
        else:
            df_filtered = df.dropna(subset=[column])
        
        tukey_result = pairwise_tukeyhsd(df_filtered[column], df_filtered['pink_subtype'])
        tukey_results.append((column, tukey_result))

# Print the summary of the Tukey's HSD test for each column
for column, result in tukey_results:
    print(f"Tukey's HSD test for {column}:")
    print(result)
    print()

# Plot the results
for column, result in tukey_results:
    result.plot_simultaneous()
    plt.xlabel('Mean Difference')
    plt.title(f'Tukey\'s HSD for {column}')
    plt.show()
# Out:
# Tukey's HSD test for spike_num:
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1      group2   meandiff p-adj   lower    upper  reject
# ---------------------------------------------------------------
#  PinkNoise1 PinkNoise10   0.8407    1.0  -18.028 19.7093  False
#  PinkNoise1  PinkNoise2   1.0714    1.0 -21.6059 23.7487  False
#  PinkNoise1  PinkNoise3   0.9048    1.0 -14.9514 16.7609  False
#  PinkNoise1  PinkNoise4   3.8143 0.9994 -11.6773 19.3058  False
#  PinkNoise1  PinkNoise5   4.7691  0.995 -10.3051 19.8433  False
#  PinkNoise1  PinkNoise6   3.2026 0.9998 -11.3151 17.7202  False
#  PinkNoise1  PinkNoise7  11.1578 0.2828  -3.0213  25.337  False
#  PinkNoise1  PinkNoise8  11.1085 0.2892  -3.0707 25.2876  False
#  PinkNoise1  PinkNoise9  21.3135    0.0   7.9985 34.6284   True
#  PinkNoise1        none   7.4193 0.8816  -7.5337 22.3722  False
# PinkNoise10  PinkNoise2   0.2308    1.0 -22.7354  23.197  False
# PinkNoise10  PinkNoise3   0.0641    1.0 -16.2025 16.3307  False
# PinkNoise10  PinkNoise4   2.9736    1.0 -12.9378 18.8851  False
# PinkNoise10  PinkNoise5   3.9284 0.9992  -11.577 19.4339  False
# PinkNoise10  PinkNoise6   2.3619    1.0  -12.603 17.3268  False
# PinkNoise10  PinkNoise7  10.3172  0.452  -4.3196 24.9539  False
# PinkNoise10  PinkNoise8  10.2678 0.4596   -4.369 24.9046  False
# PinkNoise10  PinkNoise9  20.4728 0.0001   6.6716 34.2741   True
# PinkNoise10        none   6.5786 0.9531   -8.809 21.9662  False
#  PinkNoise2  PinkNoise3  -0.1667    1.0 -20.7297 20.3963  False
#  PinkNoise2  PinkNoise4   2.7429    1.0 -17.5404 23.0261  False
#  PinkNoise2  PinkNoise5   3.6977    1.0 -16.2686 23.6639  False
#  PinkNoise2  PinkNoise6   2.1311    1.0 -17.4184 21.6806  False
#  PinkNoise2  PinkNoise7  10.0864 0.8421   -9.213 29.3859  False
#  PinkNoise2  PinkNoise8   10.037 0.8462  -9.2624 29.3365  False
#  PinkNoise2  PinkNoise9  20.2421  0.021   1.5683 38.9158   True
#  PinkNoise2        none   6.3478 0.9946 -13.5271 26.2227  False
#  PinkNoise3  PinkNoise4   2.9095 0.9995  -9.2792 15.0982  False
#  PinkNoise3  PinkNoise5   3.8643 0.9927  -7.7893  15.518  False
#  PinkNoise3  PinkNoise6   2.2978 0.9999  -8.6264  13.222  False
#  PinkNoise3  PinkNoise7  10.2531  0.061  -0.2171 20.7233  False
#  PinkNoise3  PinkNoise8  10.2037 0.0638  -0.2665 20.6739  False
#  PinkNoise3  PinkNoise9  20.4087    0.0  11.1424  29.675   True
#  PinkNoise3        none   6.5145 0.7625  -4.9819 18.0109  False
#  PinkNoise4  PinkNoise5   0.9548    1.0 -10.1977 12.1074  False
#  PinkNoise4  PinkNoise6  -0.6117    1.0 -10.9997  9.7763  False
#  PinkNoise4  PinkNoise7   7.3436 0.3729  -2.5658  17.253  False
#  PinkNoise4  PinkNoise8   7.2942 0.3834  -2.6152 17.2036  False
#  PinkNoise4  PinkNoise9  17.4992    0.0   8.8716 26.1268   True
#  PinkNoise4        none    3.605 0.9933  -7.3832 14.5931  False
#  PinkNoise5  PinkNoise6  -1.5665    1.0 -11.3212  8.1881  False
#  PinkNoise5  PinkNoise7   6.3887 0.4832  -2.8546 15.6321  False
#  PinkNoise5  PinkNoise8   6.3394 0.4955   -2.904 15.5827  False
#  PinkNoise5  PinkNoise9  16.5444    0.0   8.6908  24.398   True
#  PinkNoise5        none   2.6502 0.9992  -7.7413 13.0416  False
#  PinkNoise6  PinkNoise7   7.9553 0.0744  -0.3496 16.2601  False
#  PinkNoise6  PinkNoise8   7.9059 0.0785   -0.399 16.2107  False
#  PinkNoise6  PinkNoise9  18.1109    0.0  11.3871 24.8347   True
#  PinkNoise6        none   4.2167 0.9426  -5.3496  13.783  False
#  PinkNoise7  PinkNoise8  -0.0494    1.0  -7.7472  7.6484  False
#  PinkNoise7  PinkNoise9  10.1556    0.0   4.1978 16.1135   True
#  PinkNoise7        none  -3.7386 0.9626 -12.7829  5.3057  False
#  PinkNoise8  PinkNoise9   10.205    0.0   4.2472 16.1629   True
#  PinkNoise8        none  -3.6892 0.9659 -12.7335  5.3551  False
#  PinkNoise9        none -13.8942    0.0 -21.5126 -6.2759   True
# ---------------------------------------------------------------
#
# Tukey's HSD test for voltage_ramp:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#    group1      group2   meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#  PinkNoise1 PinkNoise10  -0.1717    1.0 -2.0102  1.6668  False
#  PinkNoise1  PinkNoise2  -0.5769  0.999 -2.7865  1.6326  False
#  PinkNoise1  PinkNoise3  -0.1836    1.0 -1.7286  1.3613  False
#  PinkNoise1  PinkNoise4   0.3055 0.9999 -1.2039  1.8149  False
#  PinkNoise1  PinkNoise5   0.3638 0.9994  -1.105  1.8326  False
#  PinkNoise1  PinkNoise6   0.3112 0.9998 -1.1033  1.7258  False
#  PinkNoise1  PinkNoise7   0.5926  0.952  -0.789  1.9741  False
#  PinkNoise1  PinkNoise8   0.7517 0.8054 -0.6299  2.1332  False
#  PinkNoise1  PinkNoise9   1.3645 0.0296  0.0672  2.6619   True
#  PinkNoise1        none   0.0371    1.0 -1.4199   1.494  False
# PinkNoise10  PinkNoise2  -0.4052    1.0  -2.643  1.8325  False
# PinkNoise10  PinkNoise3  -0.0119    1.0 -1.5969   1.573  False
# PinkNoise10  PinkNoise4   0.4772  0.996 -1.0731  2.0276  False
# PinkNoise10  PinkNoise5   0.5355 0.9877 -0.9752  2.0463  False
# PinkNoise10  PinkNoise6    0.483 0.9928 -0.9752  1.9411  False
# PinkNoise10  PinkNoise7   0.7643 0.8198 -0.6619  2.1904  False
# PinkNoise10  PinkNoise8   0.9234 0.5849 -0.5028  2.3495  False
# PinkNoise10  PinkNoise9   1.5362 0.0109  0.1915   2.881   True
# PinkNoise10        none   0.2088    1.0 -1.2905  1.7081  False
#  PinkNoise2  PinkNoise3   0.3933 0.9999 -1.6103  2.3969  False
#  PinkNoise2  PinkNoise4   0.8824 0.9376 -1.0939  2.8588  False
#  PinkNoise2  PinkNoise5   0.9408  0.898 -1.0047  2.8862  False
#  PinkNoise2  PinkNoise6   0.8882 0.9181 -1.0166   2.793  False
#  PinkNoise2  PinkNoise7   1.1695 0.6438  -0.711    3.05  False
#  PinkNoise2  PinkNoise8   1.3286 0.4483 -0.5519  3.2091  False
#  PinkNoise2  PinkNoise9   1.9415 0.0252   0.122   3.761   True
#  PinkNoise2        none    0.614 0.9949 -1.3225  2.5506  False
#  PinkNoise3  PinkNoise4   0.4891 0.9635 -0.6985  1.6768  False
#  PinkNoise3  PinkNoise5   0.5475 0.8998  -0.588  1.6829  False
#  PinkNoise3  PinkNoise6   0.4949 0.9196 -0.5695  1.5593  False
#  PinkNoise3  PinkNoise7   0.7762 0.3324  -0.244  1.7964  False
#  PinkNoise3  PinkNoise8   0.9353 0.1069 -0.0849  1.9555  False
#  PinkNoise3  PinkNoise9   1.5482    0.0  0.6453   2.451   True
#  PinkNoise3        none   0.2207 0.9999 -0.8994  1.3409  False
#  PinkNoise4  PinkNoise5   0.0583    1.0 -1.0283   1.145  False
#  PinkNoise4  PinkNoise6   0.0057    1.0 -1.0064  1.0179  False
#  PinkNoise4  PinkNoise7   0.2871  0.997 -0.6785  1.2526  False
#  PinkNoise4  PinkNoise8   0.4462 0.9226 -0.5194  1.4117  False
#  PinkNoise4  PinkNoise9    1.059 0.0026  0.2184  1.8997   True
#  PinkNoise4        none  -0.2684 0.9993  -1.339  0.8022  False
#  PinkNoise5  PinkNoise6  -0.0526    1.0  -1.003  0.8979  False
#  PinkNoise5  PinkNoise7   0.2287 0.9992 -0.6719  1.1294  False
#  PinkNoise5  PinkNoise8   0.3878 0.9508 -0.5128  1.2885  False
#  PinkNoise5  PinkNoise9   1.0007 0.0014  0.2355  1.7659   True
#  PinkNoise5        none  -0.3267 0.9941 -1.3392  0.6858  False
#  PinkNoise6  PinkNoise7   0.2813 0.9894 -0.5279  1.0905  False
#  PinkNoise6  PinkNoise8   0.4404  0.805 -0.3688  1.2496  False
#  PinkNoise6  PinkNoise9   1.0533    0.0  0.3981  1.7084   True
#  PinkNoise6        none  -0.2741 0.9972 -1.2062   0.658  False
#  PinkNoise7  PinkNoise8   0.1591 0.9998 -0.5909  0.9091  False
#  PinkNoise7  PinkNoise9    0.772  0.001  0.1915  1.3525   True
#  PinkNoise7        none  -0.5555 0.6246 -1.4367  0.3258  False
#  PinkNoise8  PinkNoise9   0.6129 0.0284  0.0324  1.1934   True
#  PinkNoise8        none  -0.7146 0.2414 -1.5958  0.1667  False
#  PinkNoise9        none  -1.3274    0.0 -2.0697 -0.5851   True
# --------------------------------------------------------------
#
# Tukey's HSD test for inflection_time:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#    group1      group2   meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#  PinkNoise1 PinkNoise10  -0.0226 0.9994 -0.1151    0.07  False
#  PinkNoise1  PinkNoise2  -0.0096    1.0 -0.1208  0.1016  False
#  PinkNoise1  PinkNoise3    0.002    1.0 -0.0757  0.0798  False
#  PinkNoise1  PinkNoise4   0.0109    1.0  -0.065  0.0869  False
#  PinkNoise1  PinkNoise5   0.0118    1.0 -0.0621  0.0857  False
#  PinkNoise1  PinkNoise6   0.0209 0.9973 -0.0503  0.0921  False
#  PinkNoise1  PinkNoise7   0.0291 0.9595 -0.0404  0.0986  False
#  PinkNoise1  PinkNoise8   0.0461 0.5479 -0.0234  0.1156  False
#  PinkNoise1  PinkNoise9   0.0713 0.0192   0.006  0.1366   True
#  PinkNoise1        none   0.0172 0.9996 -0.0561  0.0906  False
# PinkNoise10  PinkNoise2   0.0129    1.0 -0.0997  0.1255  False
# PinkNoise10  PinkNoise3   0.0246 0.9959 -0.0552  0.1044  False
# PinkNoise10  PinkNoise4   0.0335 0.9518 -0.0445  0.1115  False
# PinkNoise10  PinkNoise5   0.0344 0.9325 -0.0417  0.1104  False
# PinkNoise10  PinkNoise6   0.0435 0.7091 -0.0299  0.1169  False
# PinkNoise10  PinkNoise7   0.0516 0.4195 -0.0201  0.1234  False
# PinkNoise10  PinkNoise8   0.0687 0.0751 -0.0031  0.1404  False
# PinkNoise10  PinkNoise9   0.0939 0.0004  0.0262  0.1615   True
# PinkNoise10        none   0.0398 0.8343 -0.0357  0.1152  False
#  PinkNoise2  PinkNoise3   0.0117    1.0 -0.0891  0.1125  False
#  PinkNoise2  PinkNoise4   0.0206 0.9999 -0.0789    0.12  False
#  PinkNoise2  PinkNoise5   0.0215 0.9998 -0.0764  0.1194  False
#  PinkNoise2  PinkNoise6   0.0306 0.9947 -0.0653  0.1264  False
#  PinkNoise2  PinkNoise7   0.0387 0.9652 -0.0559  0.1334  False
#  PinkNoise2  PinkNoise8   0.0558  0.716 -0.0389  0.1504  False
#  PinkNoise2  PinkNoise9    0.081   0.14 -0.0106  0.1725  False
#  PinkNoise2        none   0.0269 0.9984 -0.0706  0.1243  False
#  PinkNoise3  PinkNoise4   0.0089    1.0 -0.0509  0.0686  False
#  PinkNoise3  PinkNoise5   0.0098    1.0 -0.0474  0.0669  False
#  PinkNoise3  PinkNoise6   0.0189 0.9883 -0.0347  0.0724  False
#  PinkNoise3  PinkNoise7    0.027 0.8357 -0.0243  0.0784  False
#  PinkNoise3  PinkNoise8   0.0441 0.1713 -0.0073  0.0954  False
#  PinkNoise3  PinkNoise9   0.0693 0.0001  0.0238  0.1147   True
#  PinkNoise3        none   0.0152 0.9987 -0.0412  0.0716  False
#  PinkNoise4  PinkNoise5   0.0009    1.0 -0.0538  0.0556  False
#  PinkNoise4  PinkNoise6     0.01 0.9999 -0.0409  0.0609  False
#  PinkNoise4  PinkNoise7   0.0181 0.9818 -0.0304  0.0667  False
#  PinkNoise4  PinkNoise8   0.0352 0.4091 -0.0134  0.0838  False
#  PinkNoise4  PinkNoise9   0.0604 0.0002  0.0181  0.1027   True
#  PinkNoise4        none   0.0063    1.0 -0.0476  0.0602  False
#  PinkNoise5  PinkNoise6   0.0091 0.9999 -0.0387  0.0569  False
#  PinkNoise5  PinkNoise7   0.0173 0.9791 -0.0281  0.0626  False
#  PinkNoise5  PinkNoise8   0.0343 0.3407  -0.011  0.0796  False
#  PinkNoise5  PinkNoise9   0.0595    0.0   0.021   0.098   True
#  PinkNoise5        none   0.0054    1.0 -0.0455  0.0564  False
#  PinkNoise6  PinkNoise7   0.0082 0.9999 -0.0326  0.0489  False
#  PinkNoise6  PinkNoise8   0.0252  0.651 -0.0155  0.0659  False
#  PinkNoise6  PinkNoise9   0.0504 0.0001  0.0174  0.0834   True
#  PinkNoise6        none  -0.0037    1.0 -0.0506  0.0432  False
#  PinkNoise7  PinkNoise8    0.017 0.9332 -0.0207  0.0548  False
#  PinkNoise7  PinkNoise9   0.0422 0.0002   0.013  0.0715   True
#  PinkNoise7        none  -0.0118 0.9988 -0.0562  0.0325  False
#  PinkNoise8  PinkNoise9   0.0252 0.1656  -0.004  0.0544  False
#  PinkNoise8        none  -0.0289 0.5761 -0.0732  0.0155  False
#  PinkNoise9        none  -0.0541 0.0002 -0.0914 -0.0167   True
# --------------------------------------------------------------
#
# Tukey's HSD test for inflection_amp:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#    group1      group2   meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#  PinkNoise1 PinkNoise10  -0.5586    1.0 -3.9362  2.8191  False
#  PinkNoise1  PinkNoise2  -1.0558  0.999 -5.1153  3.0037  False
#  PinkNoise1  PinkNoise3  -0.0451    1.0 -2.8835  2.7933  False
#  PinkNoise1  PinkNoise4   0.7897 0.9979 -1.9834  3.5629  False
#  PinkNoise1  PinkNoise5   0.9138 0.9914 -1.7847  3.6122  False
#  PinkNoise1  PinkNoise6   0.7914 0.9963 -1.8074  3.3902  False
#  PinkNoise1  PinkNoise7   1.4363 0.7641 -1.1019  3.9745  False
#  PinkNoise1  PinkNoise8   1.7943 0.4474 -0.7439  4.3326  False
#  PinkNoise1  PinkNoise9   2.6929 0.0126  0.3094  5.0764   True
#  PinkNoise1        none   0.5981 0.9997 -2.0786  3.2749  False
# PinkNoise10  PinkNoise2  -0.4973    1.0 -4.6084  3.6139  False
# PinkNoise10  PinkNoise3   0.5135    1.0 -2.3984  3.4254  False
# PinkNoise10  PinkNoise4   1.3483 0.9102    -1.5  4.1966  False
# PinkNoise10  PinkNoise5   1.4723 0.8292 -1.3033   4.248  False
# PinkNoise10  PinkNoise6   1.3499 0.8707 -1.3289  4.0288  False
# PinkNoise10  PinkNoise7   1.9949 0.3314 -0.6253   4.615  False
# PinkNoise10  PinkNoise8   2.3529 0.1251 -0.2672   4.973  False
# PinkNoise10  PinkNoise9   3.2515 0.0012  0.7809   5.722   True
# PinkNoise10        none   1.1567 0.9584 -1.5979  3.9112  False
#  PinkNoise2  PinkNoise3   1.0107 0.9985 -2.6703  4.6917  False
#  PinkNoise2  PinkNoise4   1.8455 0.8643 -1.7854  5.4764  False
#  PinkNoise2  PinkNoise5   1.9696 0.7925 -1.6046  5.5438  False
#  PinkNoise2  PinkNoise6   1.8472 0.8336 -1.6524  5.3468  False
#  PinkNoise2  PinkNoise7   2.4921 0.4153 -0.9627  5.9469  False
#  PinkNoise2  PinkNoise8   2.8501 0.2188 -0.6047  6.3049  False
#  PinkNoise2  PinkNoise9   3.7487 0.0139  0.4059  7.0915   True
#  PinkNoise2        none   1.6539 0.9196 -1.9039  5.2117  False
#  PinkNoise3  PinkNoise4   0.8348 0.9784 -1.3471  3.0167  False
#  PinkNoise3  PinkNoise5   0.9589 0.9251 -1.1273   3.045  False
#  PinkNoise3  PinkNoise6   0.8365 0.9529 -1.1191   2.792  False
#  PinkNoise3  PinkNoise7   1.4814 0.2766 -0.3929  3.3557  False
#  PinkNoise3  PinkNoise8   1.8394 0.0598 -0.0348  3.7137  False
#  PinkNoise3  PinkNoise9    2.738    0.0  1.0793  4.3968   True
#  PinkNoise3        none   0.6432 0.9954 -1.4148  2.7012  False
#  PinkNoise4  PinkNoise5    0.124    1.0 -1.8724  2.1205  False
#  PinkNoise4  PinkNoise6   0.0017    1.0 -1.8579  1.8612  False
#  PinkNoise4  PinkNoise7   0.6466 0.9849 -1.1273  2.4205  False
#  PinkNoise4  PinkNoise8   1.0046 0.7632 -0.7693  2.7785  False
#  PinkNoise4  PinkNoise9   1.9032 0.0036  0.3588  3.4476   True
#  PinkNoise4        none  -0.1916    1.0 -2.1586  1.7754  False
#  PinkNoise5  PinkNoise6  -0.1224    1.0 -1.8686  1.6238  False
#  PinkNoise5  PinkNoise7   0.5225  0.995 -1.1321  2.1772  False
#  PinkNoise5  PinkNoise8   0.8806 0.8263 -0.7741  2.5352  False
#  PinkNoise5  PinkNoise9   1.7792 0.0024  0.3733   3.185   True
#  PinkNoise5        none  -0.3157    1.0 -2.1758  1.5445  False
#  PinkNoise6  PinkNoise7   0.6449 0.9483 -0.8417  2.1316  False
#  PinkNoise6  PinkNoise8    1.003 0.5215 -0.4837  2.4896  False
#  PinkNoise6  PinkNoise9   1.9015    0.0  0.6979  3.1052   True
#  PinkNoise6        none  -0.1933    1.0 -1.9057  1.5192  False
#  PinkNoise7  PinkNoise8    0.358  0.999   -1.02   1.736  False
#  PinkNoise7  PinkNoise9   1.2566 0.0071  0.1901  2.3231   True
#  PinkNoise7        none  -0.8382 0.8499 -2.4572  0.7808  False
#  PinkNoise8  PinkNoise9   0.8986 0.1928 -0.1679  1.9651  False
#  PinkNoise8        none  -1.1962 0.3776 -2.8152  0.4228  False
#  PinkNoise9        none  -2.0948    0.0 -3.4586 -0.7311   True
# --------------------------------------------------------------
#
# Tukey's HSD test for peak_amp:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#    group1      group2   meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#  PinkNoise1 PinkNoise10  -0.0896    1.0 -2.0763  1.8971  False
#  PinkNoise1  PinkNoise2   2.1964 0.1041 -0.1913  4.5841  False
#  PinkNoise1  PinkNoise3  -0.3473 0.9999 -2.0168  1.3222  False
#  PinkNoise1  PinkNoise4  -0.8554 0.8392 -2.4865  0.7758  False
#  PinkNoise1  PinkNoise5   -0.696 0.9445 -2.2832  0.8912  False
#  PinkNoise1  PinkNoise6  -1.2103  0.274 -2.7389  0.3182  False
#  PinkNoise1  PinkNoise7  -1.2839 0.1692 -2.7768   0.209  False
#  PinkNoise1  PinkNoise8  -1.4185 0.0798 -2.9115  0.0744  False
#  PinkNoise1  PinkNoise9  -2.9345    0.0 -4.3364 -1.5325   True
#  PinkNoise1        none   2.4437    0.0  0.8693  4.0181   True
# PinkNoise10  PinkNoise2   2.2861 0.0833 -0.1321  4.7042  False
# PinkNoise10  PinkNoise3  -0.2577    1.0 -1.9704   1.455  False
# PinkNoise10  PinkNoise4  -0.7657 0.9277  -2.441  0.9096  False
# PinkNoise10  PinkNoise5  -0.6064 0.9826  -2.239  1.0262  False
# PinkNoise10  PinkNoise6  -1.1207 0.4377 -2.6964   0.455  False
# PinkNoise10  PinkNoise7  -1.1943 0.3051 -2.7354  0.3468  False
# PinkNoise10  PinkNoise8  -1.3289 0.1662   -2.87  0.2122  False
# PinkNoise10  PinkNoise9  -2.8448    0.0  -4.298 -1.3917   True
# PinkNoise10        none   2.5333    0.0  0.9132  4.1535   True
#  PinkNoise2  PinkNoise3  -2.5438 0.0074 -4.7088 -0.3787   True
#  PinkNoise2  PinkNoise4  -3.0518 0.0002 -5.1874 -0.9162   True
#  PinkNoise2  PinkNoise5  -2.8924 0.0005 -4.9947 -0.7902   True
#  PinkNoise2  PinkNoise6  -3.4068    0.0 -5.4651 -1.3484   True
#  PinkNoise2  PinkNoise7  -3.4803    0.0 -5.5124 -1.4483   True
#  PinkNoise2  PinkNoise8   -3.615    0.0  -5.647 -1.5829   True
#  PinkNoise2  PinkNoise9  -5.1309    0.0  -7.097 -3.1647   True
#  PinkNoise2        none   0.2473    1.0 -1.8453  2.3399  False
#  PinkNoise3  PinkNoise4   -0.508 0.9724 -1.7914  0.7753  False
#  PinkNoise3  PinkNoise5  -0.3487 0.9979 -1.5757  0.8783  False
#  PinkNoise3  PinkNoise6   -0.863 0.3537 -2.0132  0.2872  False
#  PinkNoise3  PinkNoise7  -0.9366  0.183  -2.039  0.1658  False
#  PinkNoise3  PinkNoise8  -1.0712 0.0655 -2.1736  0.0312  False
#  PinkNoise3  PinkNoise9  -2.5871    0.0 -3.5628 -1.6115   True
#  PinkNoise3        none    2.791    0.0  1.5806  4.0015   True
#  PinkNoise4  PinkNoise5   0.1593    1.0 -1.0149  1.3336  False
#  PinkNoise4  PinkNoise6   -0.355 0.9938 -1.4487  0.7388  False
#  PinkNoise4  PinkNoise7  -0.4285 0.9642 -1.4719  0.6148  False
#  PinkNoise4  PinkNoise8  -0.5632 0.8131 -1.6065  0.4802  False
#  PinkNoise4  PinkNoise9  -2.0791    0.0 -2.9875 -1.1707   True
#  PinkNoise4        none   3.2991    0.0  2.1421   4.456   True
#  PinkNoise5  PinkNoise6  -0.5143 0.8752 -1.5414  0.5127  False
#  PinkNoise5  PinkNoise7  -0.5879 0.6839 -1.5611  0.3854  False
#  PinkNoise5  PinkNoise8  -0.7225 0.3701 -1.6958  0.2507  False
#  PinkNoise5  PinkNoise9  -2.2384    0.0 -3.0653 -1.4115   True
#  PinkNoise5        none   3.1397    0.0  2.0456  4.2338   True
#  PinkNoise6  PinkNoise7  -0.0736    1.0  -0.948  0.8009  False
#  PinkNoise6  PinkNoise8  -0.2082 0.9996 -1.0826  0.6662  False
#  PinkNoise6  PinkNoise9  -1.7241    0.0 -2.4321 -1.0162   True
#  PinkNoise6        none    3.654    0.0  2.6468  4.6613   True
#  PinkNoise7  PinkNoise8  -0.1346    1.0 -0.9451  0.6759  False
#  PinkNoise7  PinkNoise9  -1.6506    0.0 -2.2779 -1.0233   True
#  PinkNoise7        none   3.7276    0.0  2.7753  4.6799   True
#  PinkNoise8  PinkNoise9  -1.5159    0.0 -2.1432 -0.8886   True
#  PinkNoise8        none   3.8623    0.0    2.91  4.8145   True
#  PinkNoise9        none   5.3782    0.0   4.576  6.1803   True
# --------------------------------------------------------------
#
# Tukey's HSD test for peak_sharp:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================
#    group1      group2   meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------
#  PinkNoise1 PinkNoise10   0.0056    1.0 -0.0443 0.0555  False
#  PinkNoise1  PinkNoise2   0.0078    1.0 -0.0522 0.0678  False
#  PinkNoise1  PinkNoise3  -0.0028    1.0 -0.0447 0.0392  False
#  PinkNoise1  PinkNoise4  -0.0011    1.0 -0.0421 0.0399  False
#  PinkNoise1  PinkNoise5  -0.0064    1.0 -0.0463 0.0335  False
#  PinkNoise1  PinkNoise6  -0.0024    1.0 -0.0408  0.036  False
#  PinkNoise1  PinkNoise7  -0.0122 0.9939 -0.0497 0.0253  False
#  PinkNoise1  PinkNoise8  -0.0137 0.9845 -0.0512 0.0238  False
#  PinkNoise1  PinkNoise9  -0.0201 0.7569 -0.0553 0.0152  False
#  PinkNoise1        none  -0.0029    1.0 -0.0425 0.0366  False
# PinkNoise10  PinkNoise2   0.0022    1.0 -0.0585  0.063  False
# PinkNoise10  PinkNoise3  -0.0083 0.9999 -0.0514 0.0347  False
# PinkNoise10  PinkNoise4  -0.0067    1.0 -0.0488 0.0354  False
# PinkNoise10  PinkNoise5   -0.012 0.9974  -0.053  0.029  False
# PinkNoise10  PinkNoise6  -0.0079 0.9999 -0.0475 0.0316  False
# PinkNoise10  PinkNoise7  -0.0177 0.9263 -0.0565  0.021  False
# PinkNoise10  PinkNoise8  -0.0193 0.8787  -0.058 0.0194  False
# PinkNoise10  PinkNoise9  -0.0256 0.4579 -0.0621 0.0109  False
# PinkNoise10        none  -0.0085 0.9999 -0.0492 0.0322  False
#  PinkNoise2  PinkNoise3  -0.0106 0.9999  -0.065 0.0438  False
#  PinkNoise2  PinkNoise4  -0.0089    1.0 -0.0626 0.0447  False
#  PinkNoise2  PinkNoise5  -0.0142 0.9987  -0.067 0.0386  False
#  PinkNoise2  PinkNoise6  -0.0102 0.9999 -0.0619 0.0415  False
#  PinkNoise2  PinkNoise7    -0.02 0.9745  -0.071 0.0311  False
#  PinkNoise2  PinkNoise8  -0.0215 0.9572 -0.0726 0.0295  False
#  PinkNoise2  PinkNoise9  -0.0279 0.7673 -0.0773 0.0215  False
#  PinkNoise2        none  -0.0107 0.9999 -0.0633 0.0418  False
#  PinkNoise3  PinkNoise4   0.0016    1.0 -0.0306 0.0339  False
#  PinkNoise3  PinkNoise5  -0.0037    1.0 -0.0345 0.0272  False
#  PinkNoise3  PinkNoise6   0.0004    1.0 -0.0285 0.0293  False
#  PinkNoise3  PinkNoise7  -0.0094 0.9911 -0.0371 0.0183  False
#  PinkNoise3  PinkNoise8   -0.011 0.9725 -0.0386 0.0167  False
#  PinkNoise3  PinkNoise9  -0.0173 0.4496 -0.0418 0.0072  False
#  PinkNoise3        none  -0.0002    1.0 -0.0306 0.0302  False
#  PinkNoise4  PinkNoise5  -0.0053    1.0 -0.0348 0.0242  False
#  PinkNoise4  PinkNoise6  -0.0012    1.0 -0.0287 0.0262  False
#  PinkNoise4  PinkNoise7  -0.0111 0.9572 -0.0373 0.0152  False
#  PinkNoise4  PinkNoise8  -0.0126 0.9018 -0.0388 0.0136  False
#  PinkNoise4  PinkNoise9  -0.0189 0.2112 -0.0418 0.0039  False
#  PinkNoise4        none  -0.0018    1.0 -0.0309 0.0273  False
#  PinkNoise5  PinkNoise6   0.0041    1.0 -0.0217 0.0298  False
#  PinkNoise5  PinkNoise7  -0.0058 0.9996 -0.0302 0.0187  False
#  PinkNoise5  PinkNoise8  -0.0073 0.9969 -0.0317 0.0171  False
#  PinkNoise5  PinkNoise9  -0.0136 0.5631 -0.0344 0.0071  False
#  PinkNoise5        none   0.0035    1.0  -0.024  0.031  False
#  PinkNoise6  PinkNoise7  -0.0098 0.9377 -0.0318 0.0122  False
#  PinkNoise6  PinkNoise8  -0.0113 0.8515 -0.0333 0.0106  False
#  PinkNoise6  PinkNoise9  -0.0177 0.0525 -0.0355 0.0001  False
#  PinkNoise6        none  -0.0006    1.0 -0.0259 0.0247  False
#  PinkNoise7  PinkNoise8  -0.0015    1.0 -0.0219 0.0188  False
#  PinkNoise7  PinkNoise9  -0.0079 0.8755 -0.0236 0.0079  False
#  PinkNoise7        none   0.0093 0.9765 -0.0147 0.0332  False
#  PinkNoise8  PinkNoise9  -0.0063 0.9689 -0.0221 0.0094  False
#  PinkNoise8        none   0.0108 0.9331 -0.0131 0.0347  False
#  PinkNoise9        none   0.0171 0.1814  -0.003 0.0373  False
# -------------------------------------------------------------
#
# Tukey's HSD test for decay_exp:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#    group1      group2   meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#  PinkNoise1 PinkNoise10   0.0214    1.0 -0.1871  0.2298  False
#  PinkNoise1  PinkNoise2   0.0674 0.9987 -0.1831   0.318  False
#  PinkNoise1  PinkNoise3  -0.0213    1.0 -0.1965  0.1538  False
#  PinkNoise1  PinkNoise4  -0.0416 0.9995 -0.2127  0.1296  False
#  PinkNoise1  PinkNoise5  -0.0605 0.9852 -0.2271   0.106  False
#  PinkNoise1  PinkNoise6  -0.0629 0.9743 -0.2232  0.0975  False
#  PinkNoise1  PinkNoise7  -0.0967 0.6544 -0.2533    0.06  False
#  PinkNoise1  PinkNoise8  -0.1401 0.1291 -0.2967  0.0166  False
#  PinkNoise1  PinkNoise9  -0.1894 0.0018 -0.3365 -0.0423   True
#  PinkNoise1        none   0.0352 0.9998   -0.13  0.2004  False
# PinkNoise10  PinkNoise2   0.0461    1.0 -0.2077  0.2998  False
# PinkNoise10  PinkNoise3  -0.0427 0.9996 -0.2224   0.137  False
# PinkNoise10  PinkNoise4  -0.0629 0.9868 -0.2387  0.1129  False
# PinkNoise10  PinkNoise5  -0.0819 0.9047 -0.2532  0.0894  False
# PinkNoise10  PinkNoise6  -0.0842 0.8627 -0.2496  0.0811  False
# PinkNoise10  PinkNoise7  -0.1181 0.3962 -0.2798  0.0436  False
# PinkNoise10  PinkNoise8  -0.1615 0.0508 -0.3232  0.0003  False
# PinkNoise10  PinkNoise9  -0.2107 0.0005 -0.3632 -0.0583   True
# PinkNoise10        none   0.0138    1.0 -0.1562  0.1838  False
#  PinkNoise2  PinkNoise3  -0.0888 0.9748  -0.316  0.1384  False
#  PinkNoise2  PinkNoise4   -0.109 0.8944 -0.3331  0.1151  False
#  PinkNoise2  PinkNoise5   -0.128 0.7351 -0.3486  0.0926  False
#  PinkNoise2  PinkNoise6  -0.1303 0.6857 -0.3463  0.0857  False
#  PinkNoise2  PinkNoise7  -0.1641  0.315 -0.3774  0.0491  False
#  PinkNoise2  PinkNoise8  -0.2075 0.0645 -0.4207  0.0057  False
#  PinkNoise2  PinkNoise9  -0.2568 0.0031 -0.4631 -0.0505   True
#  PinkNoise2        none  -0.0322    1.0 -0.2518  0.1874  False
#  PinkNoise3  PinkNoise4  -0.0202    1.0 -0.1549  0.1144  False
#  PinkNoise3  PinkNoise5  -0.0392 0.9963 -0.1679  0.0896  False
#  PinkNoise3  PinkNoise6  -0.0415 0.9903 -0.1622  0.0792  False
#  PinkNoise3  PinkNoise7  -0.0754 0.5755  -0.191  0.0403  False
#  PinkNoise3  PinkNoise8  -0.1187 0.0384 -0.2344 -0.0031   True
#  PinkNoise3  PinkNoise9   -0.168    0.0 -0.2704 -0.0657   True
#  PinkNoise3        none   0.0565 0.9388 -0.0705  0.1836  False
#  PinkNoise4  PinkNoise5   -0.019    1.0 -0.1422  0.1043  False
#  PinkNoise4  PinkNoise6  -0.0213    1.0  -0.136  0.0935  False
#  PinkNoise4  PinkNoise7  -0.0551 0.8713 -0.1646  0.0544  False
#  PinkNoise4  PinkNoise8  -0.0985 0.1233  -0.208   0.011  False
#  PinkNoise4  PinkNoise9  -0.1478    0.0 -0.2431 -0.0525   True
#  PinkNoise4        none   0.0768 0.6196 -0.0446  0.1982  False
#  PinkNoise5  PinkNoise6  -0.0023    1.0 -0.1101  0.1055  False
#  PinkNoise5  PinkNoise7  -0.0362 0.9878 -0.1383   0.066  False
#  PinkNoise5  PinkNoise8  -0.0796 0.2974 -0.1817  0.0226  False
#  PinkNoise5  PinkNoise9  -0.1288 0.0001 -0.2156 -0.0421   True
#  PinkNoise5        none   0.0957 0.2052 -0.0191  0.2106  False
#  PinkNoise6  PinkNoise7  -0.0338 0.9835 -0.1256  0.0579  False
#  PinkNoise6  PinkNoise8  -0.0772 0.1939  -0.169  0.0145  False
#  PinkNoise6  PinkNoise9  -0.1265    0.0 -0.2008 -0.0522   True
#  PinkNoise6        none   0.0981 0.0972 -0.0076  0.2038  False
#  PinkNoise7  PinkNoise8  -0.0434 0.8615 -0.1284  0.0417  False
#  PinkNoise7  PinkNoise9  -0.0927 0.0003 -0.1585 -0.0269   True
#  PinkNoise7        none   0.1319 0.0011   0.032  0.2318   True
#  PinkNoise8  PinkNoise9  -0.0493 0.3567 -0.1151  0.0165  False
#  PinkNoise8        none   0.1753    0.0  0.0754  0.2752   True
#  PinkNoise9        none   0.2246    0.0  0.1404  0.3088   True
# --------------------------------------------------------------
#
# Tukey's HSD test for decay_const:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#    group1      group2   meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#  PinkNoise1 PinkNoise10  -0.0914    1.0 -1.9716  1.7887  False
#  PinkNoise1  PinkNoise2    0.106    1.0 -2.1536  2.3657  False
#  PinkNoise1  PinkNoise3   0.2783    1.0 -1.3017  1.8583  False
#  PinkNoise1  PinkNoise4   0.7848 0.8641 -0.7588  2.3285  False
#  PinkNoise1  PinkNoise5   0.8766 0.7279 -0.6254  2.3787  False
#  PinkNoise1  PinkNoise6   0.9764 0.5207 -0.4702   2.423  False
#  PinkNoise1  PinkNoise7   1.5247 0.0222  0.1118  2.9376   True
#  PinkNoise1  PinkNoise8   1.6262 0.0099  0.2134  3.0391   True
#  PinkNoise1  PinkNoise9    2.889    0.0  1.5622  4.2157   True
#  PinkNoise1        none    1.959 0.0012  0.4691   3.449   True
# PinkNoise10  PinkNoise2   0.1975    1.0  -2.091  2.4859  False
# PinkNoise10  PinkNoise3   0.3697 0.9997 -1.2511  1.9906  False
# PinkNoise10  PinkNoise4   0.8763 0.7895 -0.7092  2.4617  False
# PinkNoise10  PinkNoise5   0.9681 0.6332  -0.577  2.5131  False
# PinkNoise10  PinkNoise6   1.0679 0.4268 -0.4233   2.559  False
# PinkNoise10  PinkNoise7   1.6161 0.0161  0.1576  3.0746   True
# PinkNoise10  PinkNoise8   1.7177 0.0072  0.2592  3.1761   True
# PinkNoise10  PinkNoise9   2.9804    0.0  1.6052  4.3556   True
# PinkNoise10        none   2.0505 0.0009  0.5172  3.5837   True
#  PinkNoise2  PinkNoise3   0.1723    1.0 -1.8767  2.2212  False
#  PinkNoise2  PinkNoise4   0.6788 0.9919 -1.3423  2.6999  False
#  PinkNoise2  PinkNoise5   0.7706 0.9764 -1.2189  2.7601  False
#  PinkNoise2  PinkNoise6   0.8704 0.9374 -1.0776  2.8184  False
#  PinkNoise2  PinkNoise7   1.4186   0.38 -0.5044  3.3417  False
#  PinkNoise2  PinkNoise8   1.5202 0.2764 -0.4029  3.4433  False
#  PinkNoise2  PinkNoise9   2.7829 0.0001  0.9222  4.6437   True
#  PinkNoise2        none    1.853 0.0908 -0.1274  3.8334  False
#  PinkNoise3  PinkNoise4   0.5065 0.9603  -0.708  1.7211  False
#  PinkNoise3  PinkNoise5   0.5983 0.8538 -0.5629  1.7596  False
#  PinkNoise3  PinkNoise6   0.6981 0.5991 -0.3904  1.7867  False
#  PinkNoise3  PinkNoise7   1.2464 0.0058  0.2031  2.2897   True
#  PinkNoise3  PinkNoise8   1.3479 0.0017  0.3046  2.3912   True
#  PinkNoise3  PinkNoise9   2.6107    0.0  1.6874   3.534   True
#  PinkNoise3        none   1.6807 0.0001  0.5352  2.8263   True
#  PinkNoise4  PinkNoise5   0.0918    1.0 -1.0195  1.2031  False
#  PinkNoise4  PinkNoise6   0.1916    1.0 -0.8435  1.2267  False
#  PinkNoise4  PinkNoise7   0.7399 0.3558 -0.2476  1.7273  False
#  PinkNoise4  PinkNoise8   0.8414 0.1796  -0.146  1.8288  False
#  PinkNoise4  PinkNoise9   2.1041    0.0  1.2445  2.9638   True
#  PinkNoise4        none   1.1742 0.0238  0.0793  2.2691   True
#  PinkNoise5  PinkNoise6   0.0998    1.0 -0.8722  1.0718  False
#  PinkNoise5  PinkNoise7    0.648 0.4549  -0.273  1.5691  False
#  PinkNoise5  PinkNoise8   0.7496 0.2365 -0.1715  1.6706  False
#  PinkNoise5  PinkNoise9   2.0123    0.0  1.2298  2.7949   True
#  PinkNoise5        none   1.0824 0.0317  0.0469  2.1178   True
#  PinkNoise6  PinkNoise7   0.5483 0.5497 -0.2793  1.3758  False
#  PinkNoise6  PinkNoise8   0.6498 0.2859 -0.1777  1.4773  False
#  PinkNoise6  PinkNoise9   1.9126    0.0  1.2426  2.5825   True
#  PinkNoise6        none   0.9826 0.0368  0.0294  1.9358   True
#  PinkNoise7  PinkNoise8   0.1015    1.0 -0.6655  0.8686  False
#  PinkNoise7  PinkNoise9   1.3643    0.0  0.7706   1.958   True
#  PinkNoise7        none   0.4343    0.9 -0.4669  1.3356  False
#  PinkNoise8  PinkNoise9   1.2628    0.0  0.6691  1.8564   True
#  PinkNoise8        none   0.3328 0.9833 -0.5684   1.234  False
#  PinkNoise9        none    -0.93  0.004 -1.6891 -0.1708   True
# --------------------------------------------------------------
#
# Tukey's HSD test for stim_exp:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================
#    group1      group2   meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------
#  PinkNoise1 PinkNoise10   0.0236    1.0 -0.3391 0.3864  False
#  PinkNoise1  PinkNoise2  -0.0945 0.9996 -0.5304 0.3415  False
#  PinkNoise1  PinkNoise3    0.011    1.0  -0.311  0.333  False
#  PinkNoise1  PinkNoise4  -0.0574 0.9998 -0.3553 0.2404  False
#  PinkNoise1  PinkNoise5  -0.1478 0.8366 -0.4376  0.142  False
#  PinkNoise1  PinkNoise6  -0.0144    1.0 -0.3079  0.279  False
#  PinkNoise1  PinkNoise7   -0.074 0.9974 -0.3466 0.1986  False
#  PinkNoise1  PinkNoise8  -0.1515 0.7546 -0.4241  0.121  False
#  PinkNoise1  PinkNoise9  -0.1801 0.5249 -0.4522 0.0921  False
# PinkNoise10  PinkNoise2  -0.1181 0.9977 -0.5596 0.3234  False
# PinkNoise10  PinkNoise3  -0.0126    1.0 -0.3421 0.3169  False
# PinkNoise10  PinkNoise4  -0.0811 0.9978  -0.387 0.2248  False
# PinkNoise10  PinkNoise5  -0.1714 0.7161 -0.4695 0.1267  False
# PinkNoise10  PinkNoise6  -0.0381    1.0 -0.3397 0.2636  False
# PinkNoise10  PinkNoise7  -0.0977 0.9842  -0.379 0.1837  False
# PinkNoise10  PinkNoise8  -0.1752 0.6134 -0.4565 0.1062  False
# PinkNoise10  PinkNoise9  -0.2037 0.3869 -0.4846 0.0772  False
#  PinkNoise2  PinkNoise3   0.1055 0.9982 -0.3032 0.5142  False
#  PinkNoise2  PinkNoise4    0.037    1.0 -0.3529  0.427  False
#  PinkNoise2  PinkNoise5  -0.0533    1.0 -0.4372 0.3305  False
#  PinkNoise2  PinkNoise6   0.0801 0.9997 -0.3065 0.4666  False
#  PinkNoise2  PinkNoise7   0.0205    1.0 -0.3506 0.3915  False
#  PinkNoise2  PinkNoise8  -0.0571    1.0 -0.4281  0.314  False
#  PinkNoise2  PinkNoise9  -0.0856 0.9993 -0.4562 0.2851  False
#  PinkNoise3  PinkNoise4  -0.0685 0.9977 -0.3247 0.1878  False
#  PinkNoise3  PinkNoise5  -0.1588 0.5665 -0.4057 0.0881  False
#  PinkNoise3  PinkNoise6  -0.0254    1.0 -0.2766 0.2257  False
#  PinkNoise3  PinkNoise7   -0.085 0.9729 -0.3115 0.1414  False
#  PinkNoise3  PinkNoise8  -0.1626 0.4017  -0.389 0.0639  False
#  PinkNoise3  PinkNoise9  -0.1911 0.1805 -0.4169 0.0348  False
#  PinkNoise4  PinkNoise5  -0.0903 0.9436 -0.3048 0.1241  False
#  PinkNoise4  PinkNoise6    0.043 0.9998 -0.1763 0.2623  False
#  PinkNoise4  PinkNoise7  -0.0166    1.0 -0.2071 0.1739  False
#  PinkNoise4  PinkNoise8  -0.0941 0.8613 -0.2846 0.0964  False
#  PinkNoise4  PinkNoise9  -0.1226 0.5605 -0.3124 0.0672  False
#  PinkNoise5  PinkNoise6   0.1334 0.5731 -0.0749 0.3416  False
#  PinkNoise5  PinkNoise7   0.0738 0.9485 -0.1039 0.2515  False
#  PinkNoise5  PinkNoise8  -0.0037    1.0 -0.1814  0.174  False
#  PinkNoise5  PinkNoise9  -0.0323 0.9999 -0.2092 0.1447  False
#  PinkNoise6  PinkNoise7  -0.0596 0.9901 -0.2432  0.124  False
#  PinkNoise6  PinkNoise8  -0.1371 0.3429 -0.3207 0.0464  False
#  PinkNoise6  PinkNoise9  -0.1656 0.1141 -0.3485 0.0172  False
#  PinkNoise7  PinkNoise8  -0.0775 0.8138 -0.2255 0.0705  False
#  PinkNoise7  PinkNoise9   -0.106 0.3958 -0.2531 0.0411  False
#  PinkNoise8  PinkNoise9  -0.0285 0.9998 -0.1756 0.1186  False
# -------------------------------------------------------------
#
# Tukey's HSD test for stim_mean:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#    group1      group2   meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#  PinkNoise1 PinkNoise10   0.5282    1.0 -4.6973  5.7537  False
#  PinkNoise1  PinkNoise2   2.7054 0.9355 -3.5749  8.9857  False
#  PinkNoise1  PinkNoise3   1.4025 0.9941 -3.2358  6.0408  False
#  PinkNoise1  PinkNoise4   5.9908 0.0005  1.7005  10.281   True
#  PinkNoise1  PinkNoise5   7.0854    0.0  2.9107 11.2601   True
#  PinkNoise1  PinkNoise6   7.7866    0.0  3.5597 12.0136   True
#  PinkNoise1  PinkNoise7  12.4955    0.0  8.5687 16.4223   True
#  PinkNoise1  PinkNoise8   11.723    0.0  7.7962 15.6498   True
#  PinkNoise1  PinkNoise9  11.9169    0.0  7.9971 15.8367   True
# PinkNoise10  PinkNoise2   2.1772 0.9856 -4.1831  8.5375  False
# PinkNoise10  PinkNoise3   0.8743 0.9999 -3.8718  5.6204  False
# PinkNoise10  PinkNoise4   5.4625 0.0037   1.056  9.8691   True
# PinkNoise10  PinkNoise5   6.5572 0.0001  2.2631 10.8513   True
# PinkNoise10  PinkNoise6   7.2584    0.0  2.9135 11.6033   True
# PinkNoise10  PinkNoise7  11.9673    0.0  7.9138 16.0208   True
# PinkNoise10  PinkNoise8  11.1948    0.0  7.1413 15.2484   True
# PinkNoise10  PinkNoise9  11.3887    0.0  7.3419 15.4355   True
#  PinkNoise2  PinkNoise3  -1.3029 0.9995 -7.1903  4.5845  False
#  PinkNoise2  PinkNoise4   3.2854 0.6956 -2.3319  8.9026  False
#  PinkNoise2  PinkNoise5     4.38 0.2609 -1.1495  9.9095  False
#  PinkNoise2  PinkNoise6   5.0812 0.1081 -0.4878 10.6503  False
#  PinkNoise2  PinkNoise7   9.7901    0.0  4.4453  15.135   True
#  PinkNoise2  PinkNoise8   9.0176    0.0  3.6728 14.3625   True
#  PinkNoise2  PinkNoise9   9.2115    0.0  3.8718 14.5512   True
#  PinkNoise3  PinkNoise4   4.5882 0.0036   0.897  8.2795   True
#  PinkNoise3  PinkNoise5   5.6829    0.0  2.1266  9.2392   True
#  PinkNoise3  PinkNoise6   6.3841    0.0  2.7666 10.0016   True
#  PinkNoise3  PinkNoise7   11.093    0.0  7.8313 14.3547   True
#  PinkNoise3  PinkNoise8  10.3205    0.0  7.0588 13.5823   True
#  PinkNoise3  PinkNoise9  10.5144    0.0  7.2611 13.7677   True
#  PinkNoise4  PinkNoise5   1.0946 0.9817  -1.994  4.1833  False
#  PinkNoise4  PinkNoise6   1.7959 0.7295  -1.363  4.9548  False
#  PinkNoise4  PinkNoise7   6.5048    0.0  3.7604  9.2491   True
#  PinkNoise4  PinkNoise8   5.7323    0.0  2.9879  8.4766   True
#  PinkNoise4  PinkNoise9   5.9262    0.0  3.1918  8.6605   True
#  PinkNoise5  PinkNoise6   0.7012 0.9992 -2.2988  3.7012  False
#  PinkNoise5  PinkNoise7   5.4101    0.0  2.8502    7.97   True
#  PinkNoise5  PinkNoise8   4.6376    0.0  2.0778  7.1975   True
#  PinkNoise5  PinkNoise9   4.8315    0.0  2.2824  7.3807   True
#  PinkNoise6  PinkNoise7   4.7089    0.0  2.0647  7.3531   True
#  PinkNoise6  PinkNoise8   3.9364 0.0001  1.2922  6.5806   True
#  PinkNoise6  PinkNoise9   4.1303    0.0  1.4964  6.7641   True
#  PinkNoise7  PinkNoise8  -0.7725 0.9787 -2.9043  1.3594  False
#  PinkNoise7  PinkNoise9  -0.5786 0.9973 -2.6976  1.5404  False
#  PinkNoise8  PinkNoise9   0.1939    1.0 -1.9251  2.3129  False
# --------------------------------------------------------------
#
# Tukey's HSD test for stim_std:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================
#    group1      group2   meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------
#  PinkNoise1 PinkNoise10  -0.1273 0.9999 -0.8679 0.6132  False
#  PinkNoise1  PinkNoise2  -0.0184    1.0 -0.9085 0.8716  False
#  PinkNoise1  PinkNoise3  -0.0035    1.0 -0.6609 0.6538  False
#  PinkNoise1  PinkNoise4   0.1881  0.993 -0.4199 0.7961  False
#  PinkNoise1  PinkNoise5   0.3853 0.5487 -0.2064 0.9769  False
#  PinkNoise1  PinkNoise6   0.0739    1.0 -0.5252 0.6729  False
#  PinkNoise1  PinkNoise7   0.2965 0.7981   -0.26 0.8529  False
#  PinkNoise1  PinkNoise8   0.4132 0.3515 -0.1433 0.9697  False
#  PinkNoise1  PinkNoise9   0.5747 0.0359  0.0192 1.1302   True
# PinkNoise10  PinkNoise2   0.1089    1.0 -0.7925 1.0103  False
# PinkNoise10  PinkNoise3   0.1238 0.9999 -0.5488 0.7964  False
# PinkNoise10  PinkNoise4   0.3154 0.8444 -0.3091 0.9399  False
# PinkNoise10  PinkNoise5   0.5126 0.1855  -0.096 1.1211  False
# PinkNoise10  PinkNoise6   0.2012 0.9896 -0.4146 0.8169  False
# PinkNoise10  PinkNoise7   0.4238 0.3612 -0.1507 0.9982  False
# PinkNoise10  PinkNoise8   0.5406  0.085 -0.0339  1.115  False
# PinkNoise10  PinkNoise9    0.702 0.0045  0.1285 1.2755   True
#  PinkNoise2  PinkNoise3   0.0149    1.0 -0.8195 0.8492  False
#  PinkNoise2  PinkNoise4   0.2065 0.9982 -0.5896 1.0026  False
#  PinkNoise2  PinkNoise5   0.4037 0.8282 -0.3799 1.1873  False
#  PinkNoise2  PinkNoise6   0.0923    1.0 -0.6969 0.8815  False
#  PinkNoise2  PinkNoise7   0.3149 0.9481 -0.4426 1.0723  False
#  PinkNoise2  PinkNoise8   0.4317 0.7267 -0.3258 1.1891  False
#  PinkNoise2  PinkNoise9   0.5931  0.275 -0.1636 1.3499  False
#  PinkNoise3  PinkNoise4   0.1916 0.9771 -0.3315 0.7147  False
#  PinkNoise3  PinkNoise5   0.3888 0.2968 -0.1152 0.8928  False
#  PinkNoise3  PinkNoise6   0.0774    1.0 -0.4353 0.5901  False
#  PinkNoise3  PinkNoise7      0.3 0.5537 -0.1623 0.7622  False
#  PinkNoise3  PinkNoise8   0.4168  0.118 -0.0455  0.879  False
#  PinkNoise3  PinkNoise9   0.5782 0.0031  0.1172 1.0393   True
#  PinkNoise4  PinkNoise5   0.1972 0.9162 -0.2405 0.6349  False
#  PinkNoise4  PinkNoise6  -0.1142 0.9984 -0.5619 0.3334  False
#  PinkNoise4  PinkNoise7   0.1084 0.9968 -0.2806 0.4973  False
#  PinkNoise4  PinkNoise8   0.2251 0.7081 -0.1638 0.6141  False
#  PinkNoise4  PinkNoise9   0.3866 0.0511 -0.0009 0.7741  False
#  PinkNoise5  PinkNoise6  -0.3114 0.3718 -0.7366 0.1138  False
#  PinkNoise5  PinkNoise7  -0.0888 0.9988 -0.4516  0.274  False
#  PinkNoise5  PinkNoise8    0.028    1.0 -0.3348 0.3907  False
#  PinkNoise5  PinkNoise9   0.1894 0.8127 -0.1718 0.5507  False
#  PinkNoise6  PinkNoise7   0.2226 0.6761 -0.1521 0.5973  False
#  PinkNoise6  PinkNoise8   0.3394 0.1143 -0.0354 0.7141  False
#  PinkNoise6  PinkNoise9   0.5008  0.001  0.1276 0.8741   True
#  PinkNoise7  PinkNoise8   0.1168 0.9673 -0.1853 0.4189  False
#  PinkNoise7  PinkNoise9   0.2783 0.0961  -0.022 0.5786  False
#  PinkNoise8  PinkNoise9   0.1615  0.789 -0.1388 0.4618  False
# -------------------------------------------------------------

# %% [markdown]
# ### See if there is something in the pink stimuli that affects the features but is not fully captured by the stim features we are looking at right now  (mean, exp, std)

# %%
# Copy the original dataframe
df_encoded = df_pink.copy()

# Perform one-hot encoding for the 'pink_subtype' column
encoder = OneHotEncoder(sparse=False, drop='first')
encoded_cols = pd.DataFrame(encoder.fit_transform(df_pink[['pink_subtype']]), columns=encoder.get_feature_names(['pink_subtype']))

# Concatenate the encoded columns with the original dataframe
df_encoded = pd.concat([df_encoded, encoded_cols], axis=1)

# Drop the original 'pink_subtype' column
df_encoded.drop(columns=['pink_subtype'], inplace=True)

# Now df_encoded contains the original dataframe with one-hot encoded columns
print(df_encoded.head())
# Out:
#     voltage_ramp  inflection_time  inflection_amp  peak_amp  peak_sharp  \
# 46      2.674580            0.640      -46.937501   8.84375    0.125000
# 47      2.704808            0.710      -44.062501   7.75000    0.171875
# 48      2.949145            0.730      -43.000001   7.78125    0.203125
# 49      3.965534            0.695      -42.187501   7.84375    0.093750
# 50      2.559444            0.695      -45.312501   8.62500    0.171875
#
#     decay_exp  decay_const  stim_exp  stim_mean  stim_std  \
# 46   1.851459   -63.746040  1.835463  16.707375  0.304002
# 47   1.701840   -63.492398  1.665509  18.229250  0.809035
# 48   1.693839   -63.534429  1.787092  17.260000  0.258590
# 49   1.674876   -63.231221  1.584740  18.178375  0.821875
# 50   1.857355   -63.798701  1.835471  12.729375  0.101533
#
#     pink_subtype_PinkNoise10  pink_subtype_PinkNoise2  \
# 46                       0.0                      0.0
# 47                       0.0                      0.0
# 48                       0.0                      0.0
# 49                       0.0                      0.0
# 50                       0.0                      0.0
#
#     pink_subtype_PinkNoise3  pink_subtype_PinkNoise4  pink_subtype_PinkNoise5  \
# 46                      0.0                      0.0                      0.0
# 47                      0.0                      0.0                      0.0
# 48                      0.0                      0.0                      0.0
# 49                      0.0                      0.0                      0.0
# 50                      0.0                      0.0                      0.0
#
#     pink_subtype_PinkNoise6  pink_subtype_PinkNoise7  pink_subtype_PinkNoise8  \
# 46                      1.0                      0.0                      0.0
# 47                      1.0                      0.0                      0.0
# 48                      1.0                      0.0                      0.0
# 49                      1.0                      0.0                      0.0
# 50                      1.0                      0.0                      0.0
#
#     pink_subtype_PinkNoise9
# 46                      0.0
# 47                      0.0
# 48                      0.0
# 49                      0.0
# 50                      0.0
# /Users/blancamartin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Assuming df_encoded is the DataFrame containing one-hot encoded columns


# Remove rows with NaN values
df_encoded = df_encoded.dropna()

# Define independent variables (stim_mean, stim_exp, stim_std, and the one-hot encoded columns)
X = df_encoded[['stim_mean', 'stim_exp', 'stim_std'] + list(bool_columns)]

# Add a constant column to the independent variables
X = sm.add_constant(X)

# Fit the regression model for each column
results = {}
for column in df_encoded.columns:
    if column not in ['stim_mean', 'stim_exp', 'stim_std'] + bool_columns:
        y = df_encoded[column]
        model = sm.OLS(y, X).fit()
        results[column] = model

# Print the summary of the regression models
for column, model in results.items():
    print(f"Regression results for column: {column}")
    print(model.summary())
# Out:
# Regression results for column: voltage_ramp
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           voltage_ramp   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     1.932
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):             0.0350
# Time:                        18:17:04   Log-Likelihood:                -488.47
# No. Observations:                 316   AIC:                             1001.
# Df Residuals:                     304   BIC:                             1046.
# Df Model:                          11
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        4.7322      0.881      5.373      0.000       2.999       6.465
# stim_mean                    0.0103      0.013      0.778      0.437      -0.016       0.036
# stim_exp                    -0.4819      0.422     -1.143      0.254      -1.311       0.348
# stim_std                    -0.1059      0.206     -0.514      0.607      -0.511       0.299
# pink_subtype_PinkNoise10     0.0530      0.491      0.108      0.914      -0.914       1.020
# pink_subtype_PinkNoise2    9.37e-16   2.34e-16      3.999      0.000    4.76e-16     1.4e-15
# pink_subtype_PinkNoise3      0.3232      0.476      0.679      0.498      -0.614       1.260
# pink_subtype_PinkNoise4      0.1928      0.437      0.441      0.660      -0.667       1.053
# pink_subtype_PinkNoise5      0.4809      0.429      1.121      0.263      -0.363       1.325
# pink_subtype_PinkNoise6      0.0359      0.423      0.085      0.932      -0.797       0.869
# pink_subtype_PinkNoise7     -0.4622      0.418     -1.105      0.270      -1.285       0.361
# pink_subtype_PinkNoise8     -0.0717      0.401     -0.179      0.858      -0.861       0.717
# pink_subtype_PinkNoise9      0.0276      0.395      0.070      0.944      -0.750       0.805
# ==============================================================================
# Omnibus:                      256.722   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5776.505
# Skew:                           3.158   Prob(JB):                         0.00
# Kurtosis:                      22.971   Cond. No.                     2.30e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.12e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Regression results for column: inflection_time
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        inflection_time   R-squared:                       0.132
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                     4.220
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):           7.78e-06
# Time:                        18:17:04   Log-Likelihood:                 452.17
# No. Observations:                 316   AIC:                            -880.3
# Df Residuals:                     304   BIC:                            -835.3
# Df Model:                          11
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.7211      0.045     16.066      0.000       0.633       0.809
# stim_mean                   -0.0005      0.001     -0.786      0.432      -0.002       0.001
# stim_exp                     0.0168      0.021      0.782      0.435      -0.025       0.059
# stim_std                     0.0058      0.010      0.556      0.579      -0.015       0.026
# pink_subtype_PinkNoise10     0.0327      0.025      1.307      0.192      -0.017       0.082
# pink_subtype_PinkNoise2   1.453e-16   1.19e-17     12.165      0.000    1.22e-16    1.69e-16
# pink_subtype_PinkNoise3      0.0067      0.024      0.276      0.783      -0.041       0.054
# pink_subtype_PinkNoise4      0.0385      0.022      1.726      0.085      -0.005       0.082
# pink_subtype_PinkNoise5     -0.0052      0.022     -0.239      0.812      -0.048       0.038
# pink_subtype_PinkNoise6      0.0308      0.022      1.429      0.154      -0.012       0.073
# pink_subtype_PinkNoise7     -0.0292      0.021     -1.371      0.172      -0.071       0.013
# pink_subtype_PinkNoise8     -0.0255      0.020     -1.249      0.213      -0.066       0.015
# pink_subtype_PinkNoise9     -0.0166      0.020     -0.822      0.412      -0.056       0.023
# ==============================================================================
# Omnibus:                        2.540   Durbin-Watson:                   1.611
# Prob(Omnibus):                  0.281   Jarque-Bera (JB):                2.319
# Skew:                          -0.205   Prob(JB):                        0.314
# Kurtosis:                       3.092   Cond. No.                     2.30e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.12e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Regression results for column: inflection_amp
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         inflection_amp   R-squared:                       0.087
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     2.620
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):            0.00331
# Time:                        18:17:04   Log-Likelihood:                -719.68
# No. Observations:                 316   AIC:                             1463.
# Df Residuals:                     304   BIC:                             1508.
# Df Model:                          11
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                      -41.0447      1.831    -22.420      0.000     -44.647     -37.442
# stim_mean                   -0.0356      0.027     -1.298      0.195      -0.090       0.018
# stim_exp                    -0.1173      0.876     -0.134      0.894      -1.841       1.607
# stim_std                    -0.0823      0.428     -0.192      0.848      -0.925       0.760
# pink_subtype_PinkNoise10     1.6458      1.021      1.612      0.108      -0.364       3.655
# pink_subtype_PinkNoise2  -9.122e-15   4.87e-16    -18.730      0.000   -1.01e-14   -8.16e-15
# pink_subtype_PinkNoise3      0.6607      0.990      0.667      0.505      -1.287       2.609
# pink_subtype_PinkNoise4      1.6015      0.909      1.763      0.079      -0.186       3.389
# pink_subtype_PinkNoise5      1.0387      0.891      1.165      0.245      -0.715       2.793
# pink_subtype_PinkNoise6      1.0922      0.880      1.241      0.215      -0.639       2.824
# pink_subtype_PinkNoise7     -1.0440      0.870     -1.201      0.231      -2.755       0.667
# pink_subtype_PinkNoise8     -0.2372      0.833     -0.285      0.776      -1.877       1.403
# pink_subtype_PinkNoise9      0.1927      0.822      0.235      0.815      -1.424       1.810
# ==============================================================================
# Omnibus:                        5.665   Durbin-Watson:                   1.640
# Prob(Omnibus):                  0.059   Jarque-Bera (JB):                7.917
# Skew:                           0.066   Prob(JB):                       0.0191
# Kurtosis:                       3.764   Cond. No.                     2.30e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.12e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Regression results for column: peak_amp
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               peak_amp   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.180
# Method:                 Least Squares   F-statistic:                     7.282
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):           4.80e-11
# Time:                        18:17:04   Log-Likelihood:                -530.82
# No. Observations:                 316   AIC:                             1086.
# Df Residuals:                     304   BIC:                             1131.
# Df Model:                          11
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        3.9956      1.007      3.968      0.000       2.014       5.977
# stim_mean                    0.0480      0.015      3.179      0.002       0.018       0.078
# stim_exp                    -0.0955      0.482     -0.198      0.843      -1.044       0.853
# stim_std                    -0.0883      0.236     -0.375      0.708      -0.552       0.375
# pink_subtype_PinkNoise10    -0.7534      0.562     -1.341      0.181      -1.859       0.352
# pink_subtype_PinkNoise2    1.31e-15   2.68e-16      4.890      0.000    7.83e-16    1.84e-15
# pink_subtype_PinkNoise3     -0.2510      0.545     -0.461      0.645      -1.323       0.821
# pink_subtype_PinkNoise4     -0.8718      0.500     -1.744      0.082      -1.855       0.112
# pink_subtype_PinkNoise5     -0.7045      0.490     -1.437      0.152      -1.669       0.260
# pink_subtype_PinkNoise6     -0.3459      0.484     -0.715      0.475      -1.298       0.607
# pink_subtype_PinkNoise7      1.5351      0.478      3.209      0.001       0.594       2.476
# pink_subtype_PinkNoise8      0.0897      0.458      0.196      0.845      -0.812       0.992
# pink_subtype_PinkNoise9     -0.5611      0.452     -1.241      0.215      -1.450       0.328
# ==============================================================================
# Omnibus:                       14.898   Durbin-Watson:                   1.135
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               37.216
# Skew:                          -0.016   Prob(JB):                     8.29e-09
# Kurtosis:                       4.681   Cond. No.                     2.30e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.12e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Regression results for column: peak_sharp
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             peak_sharp   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     1.253
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):              0.251
# Time:                        18:17:04   Log-Likelihood:                 569.47
# No. Observations:                 316   AIC:                            -1115.
# Df Residuals:                     304   BIC:                            -1070.
# Df Model:                          11
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.1158      0.031      3.741      0.000       0.055       0.177
# stim_mean                    0.0007      0.000      1.408      0.160      -0.000       0.002
# stim_exp                    -0.0098      0.015     -0.660      0.510      -0.039       0.019
# stim_std                    -0.0084      0.007     -1.160      0.247      -0.023       0.006
# pink_subtype_PinkNoise10    -0.0030      0.017     -0.174      0.862      -0.037       0.031
# pink_subtype_PinkNoise2   3.047e-17   8.24e-18      3.699      0.000    1.43e-17    4.67e-17
# pink_subtype_PinkNoise3      0.0228      0.017      1.362      0.174      -0.010       0.056
# pink_subtype_PinkNoise4      0.0038      0.015      0.246      0.806      -0.026       0.034
# pink_subtype_PinkNoise5      0.0171      0.015      1.134      0.257      -0.013       0.047
# pink_subtype_PinkNoise6      0.0166      0.015      1.117      0.265      -0.013       0.046
# pink_subtype_PinkNoise7      0.0314      0.015      2.134      0.034       0.002       0.060
# pink_subtype_PinkNoise8      0.0228      0.014      1.616      0.107      -0.005       0.051
# pink_subtype_PinkNoise9      0.0196      0.014      1.409      0.160      -0.008       0.047
# ==============================================================================
# Omnibus:                        0.516   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.773   Jarque-Bera (JB):                0.561
# Skew:                           0.096   Prob(JB):                        0.756
# Kurtosis:                       2.925   Cond. No.                     2.30e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.12e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Regression results for column: decay_exp
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              decay_exp   R-squared:                       0.140
# Model:                            OLS   Adj. R-squared:                  0.109
# Method:                 Least Squares   F-statistic:                     4.516
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):           2.45e-06
# Time:                        18:17:04   Log-Likelihood:                 177.90
# No. Observations:                 316   AIC:                            -331.8
# Df Residuals:                     304   BIC:                            -286.7
# Df Model:                          11
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        1.5664      0.107     14.651      0.000       1.356       1.777
# stim_mean                    0.0018      0.002      1.112      0.267      -0.001       0.005
# stim_exp                    -0.0034      0.051     -0.066      0.947      -0.104       0.097
# stim_std                    -0.0003      0.025     -0.012      0.991      -0.049       0.049
# pink_subtype_PinkNoise10    -0.0971      0.060     -1.629      0.104      -0.215       0.020
# pink_subtype_PinkNoise2   3.588e-16   2.84e-17     12.615      0.000    3.03e-16    4.15e-16
# pink_subtype_PinkNoise3     -0.0554      0.058     -0.959      0.338      -0.169       0.058
# pink_subtype_PinkNoise4     -0.1217      0.053     -2.293      0.023      -0.226      -0.017
# pink_subtype_PinkNoise5     -0.0657      0.052     -1.262      0.208      -0.168       0.037
# pink_subtype_PinkNoise6     -0.0984      0.051     -1.914      0.057      -0.199       0.003
# pink_subtype_PinkNoise7      0.0709      0.051      1.396      0.164      -0.029       0.171
# pink_subtype_PinkNoise8      0.0264      0.049      0.542      0.588      -0.069       0.122
# pink_subtype_PinkNoise9     -0.0199      0.048     -0.414      0.679      -0.114       0.075
# ==============================================================================
# Omnibus:                       52.112   Durbin-Watson:                   1.359
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.559
# Skew:                           1.003   Prob(JB):                     5.30e-18
# Kurtosis:                       4.421   Cond. No.                     2.30e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.12e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Regression results for column: decay_const
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            decay_const   R-squared:                       0.441
# Model:                            OLS   Adj. R-squared:                  0.421
# Method:                 Least Squares   F-statistic:                     21.84
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):           1.27e-32
# Time:                        18:17:04   Log-Likelihood:                -316.04
# No. Observations:                 316   AIC:                             656.1
# Df Residuals:                     304   BIC:                             701.2
# Df Model:                          11
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                      -64.1566      0.510   -125.705      0.000     -65.161     -63.152
# stim_mean                    0.0646      0.008      8.445      0.000       0.050       0.080
# stim_exp                     0.1396      0.244      0.572      0.568      -0.341       0.620
# stim_std                     0.1057      0.119      0.885      0.377      -0.129       0.341
# pink_subtype_PinkNoise10     0.3325      0.285      1.168      0.244      -0.228       0.893
# pink_subtype_PinkNoise2  -1.376e-14   1.36e-16   -101.332      0.000    -1.4e-14   -1.35e-14
# pink_subtype_PinkNoise3      0.4401      0.276      1.595      0.112      -0.103       0.983
# pink_subtype_PinkNoise4      0.4958      0.253      1.957      0.051      -0.003       0.994
# pink_subtype_PinkNoise5      0.5326      0.248      2.143      0.033       0.044       1.022
# pink_subtype_PinkNoise6      0.6709      0.245      2.735      0.007       0.188       1.154
# pink_subtype_PinkNoise7     -0.1454      0.242     -0.600      0.549      -0.622       0.332
# pink_subtype_PinkNoise8     -0.1193      0.232     -0.514      0.608      -0.576       0.338
# pink_subtype_PinkNoise9      0.1942      0.229      0.848      0.397      -0.257       0.645
# ==============================================================================
# Omnibus:                        3.317   Durbin-Watson:                   1.239
# Prob(Omnibus):                  0.190   Jarque-Bera (JB):                3.397
# Skew:                          -0.238   Prob(JB):                        0.183
# Kurtosis:                       2.824   Cond. No.                     2.30e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.12e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# #### Visualize regression results

# %%
# Plot residuals for each dependent variable
for column, model in results.items():
    residuals = model.resid
    index = np.arange(len(residuals))  # Create an index array with the same length as residuals
    plt.figure(figsize=(8, 6))
    plt.scatter(index, residuals)
    plt.axhline(y=0, color='r', linestyle='-')
    plt.title(f"Residual Plot for {column}")
    plt.xlabel("Index")
    plt.ylabel("Residuals")
    plt.show()

# %%
# Plot predicted vs actual for each dependent variable
for column, model in results.items():
    predicted = model.fittedvalues
    actual = df_pink[column]
    
    # Ensure actual and predicted have the same index and same length
    actual = actual[predicted.index]
    
    plt.figure(figsize=(8, 6))
    plt.scatter(actual, predicted)
    plt.plot([actual.min(), actual.max()], [actual.min(), actual.max()], 'k--', lw=2)
    plt.title(f"Predicted vs Actual for {column}")
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.show()

# %%
# Plot coefficients with error bars
for column, model in results.items():
    coeffs = model.params.drop('const')  # Exclude the constant term
    conf_int = model.conf_int().drop('const')  # Exclude the constant term
    
    # Take absolute values of the confidence interval
    conf_int = conf_int.abs().values.T
    
    plt.figure(figsize=(8, 6))
    coeffs.plot(kind='bar', yerr=conf_int, capsize=5)
    plt.title(f"Coefficients for {column}")
    plt.xlabel("Independent Variables")
    plt.ylabel("Coefficient Value")
    plt.show()
