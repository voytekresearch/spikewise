# %%
'''
Author: David Brin
Date Created: 4/2/2025

This notebook is to rerun stats and plots from 'Plots_Stats_byGroup'
data will now be split by pulse type and analysis rerun
'''
# Out:
# "\nAuthor: David Brin\nDate Created: 4/2/2025\n\nThis notebook is to rerun stats and plots from 'Plots_Stats_byGroup'\ndata will now be split by pulse type and analysis rerun\n"

# %%
# %run "./grouping_and_analysis.py"
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# /Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/datasets/primate_dataset/grouping_and_analysis.py:50: DeprecationWarning:
# The `fooof` package is being deprecated and replaced by the `specparam` (spectral parameterization) package.
# This version of `fooof` (1.1) is fully functional, but will not be further updated.
# New projects are recommended to update to using `specparam` (see Changelog for details).
#   from fooof import FOOOF

# %%
df_SP = load_dataframe_from_pickle(r"/Users/blancamartin/Downloads/df_SP_filt.pkl")
df_LP = load_dataframe_from_pickle(r"/Users/blancamartin/Downloads/df_LP_filt.pkl")
combined_dict = load_dict_from_pickle(r"/Users/blancamartin/Downloads/combined_dict_filt (1).pkl")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/pickle.py:202, in read_pickle(filepath_or_buffer, compression, storage_options)
#     201         warnings.simplefilter("ignore", Warning)
# --> 202         return pickle.load(handles.handle)
#     203 except excs_to_catch:
#     204     # e.g.
#     205     #  "No module named 'pandas.core.sparse.series'"
#     206     #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/_core/numeric.py:26
#      25 from . import umath
# ---> 26 from . import shape_base
#      27 from .overrides import set_array_function_like_doc, set_module
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/_core/shape_base.py:12
#      11 from .multiarray import array, asanyarray, normalize_axis_index
# ...

# %%
df_LP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8531 entries, 1 to 12549
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ramp_amp         8531 non-null   float64
#  1   inflection_time  8531 non-null   float64
#  2   inflection_amp   8531 non-null   float64
#  3   peak_amp         8531 non-null   float64
#  4   peak_width       8531 non-null   float64
#  5   peak_sharpness   8531 non-null   float64
#  6   exp_lambda       8531 non-null   float64
#  7   exp_const        8531 non-null   float64
#  8   r_squared_ramp   8531 non-null   float64
#  9   r_squared_exp    8531 non-null   float64
#  10  Sweep_#          8531 non-null   object
#  11  Spike_#          8531 non-null   int64
#  12  Spike_ID         8531 non-null   object
#  13  file_name        8531 non-null   object
#  14  dendriticType    8531 non-null   object
#  15  SomaLayerLoc     8531 non-null   object
# ...

# %%
group_res_SP, sub_dfs_SP = create_comparison_groups(df_SP)
group_res_LP, sub_dfs_LP = create_comparison_groups(df_LP)
# Out:
# 30
# 47

# %%
group_res_SP = group_res_SP.drop([2, 8, 12, 27, 14])

# %%
printAll_stats(sub_dfs_SP, anova = False, postH = False)
# Out:
# What are we even doing here then?

# %%
printAll_stats(sub_dfs_SP)
# Out:
# dendriticType 1
# CONDITION:  dendriticType
#
# === ANOVA Results ===
#   Skipping ANOVA for log_isi due to empty group(s).
#   ramp_amp             | F = 3.0845, p = 1.2247e-01
#   inflection_time      | F = 254.6524, p = 9.2110e-07
#   inflection_amp       | F = 222.2426, p = 1.4654e-06
#   peak_amp             | F = 646.8342, p = 3.7107e-08
#   peak_width           | F = 356.4343, p = 2.9078e-07
#   peak_sharpness       | F = 122.7013, p = 1.0859e-05
#   exp_lambda           | F = 375.1247, p = 2.4388e-07
#   exp_const            | F = 3152.7309, p = 1.4906e-10
#   r_squared_ramp       | F = 1.8244, p = 2.1882e-01
# ===PostHoc Tukey Results===
# Skipping log_isi: not enough data or no variation.
# Tukey's test results for ramp_amp:
# No significant differences found for ramp_amp.
#
#
# Tukey's test results for inflection_time:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj lower  upper  reject
# ...

# %%
printAll_stats(sub_dfs_LP)
# Out:
# dendriticType 1
# CONDITION:  dendriticType
#
# === ANOVA Results ===
#   ramp_amp             | F = 195.1954, p = 8.0490e-29
#   inflection_time      | F = 524.2922, p = 1.6956e-50
#   inflection_amp       | F = 481.6691, p = 2.1798e-48
#   peak_amp             | F = 8001.6831, p = 9.8845e-131
#   peak_width           | F = 725.5721, p = 6.2958e-59
#   peak_sharpness       | F = 487.2011, p = 1.1396e-48
#   exp_lambda           | F = 2788.3879, p = 6.4317e-98
#   exp_const            | F = 991.9486, p = 1.7207e-67
#   log_isi              | F = 25.9085, p = 1.2690e-06
#   r_squared_ramp       | F = 4.7983, p = 3.0052e-02
# ===PostHoc Tukey Results===
# Tukey's test results for ramp_amp:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      A      S   -1.097   0.0 -1.2521 -0.9418   True
# ---------------------------------------------------
#
#
# ...

# %%
generate_plots(sub_dfs_SP, group_res_SP, combined_dict, waveforms = True, boxplots = True, med = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 generate_plots(sub_dfs_SP, group_res_SP, combined_dict, waveforms = True, boxplots = True, med = False)
#
# NameError: name 'generate_plots' is not defined

# %%
s
