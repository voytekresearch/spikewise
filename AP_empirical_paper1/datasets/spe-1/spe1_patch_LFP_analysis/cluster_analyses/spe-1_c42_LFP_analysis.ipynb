# %%
# %load_ext autoreload
# %autoreload 3

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import sys, os
sys.path.append('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/spikeparam')
sys.path.append('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/')
sys.path.append('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/AP_empirical_paper1/datasets/spe-1/spe1_helper_modules/')
sys.path.append('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/AP_empirical_paper1/datasets/shared_helper_modules')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import warnings
import pickle

warnings.filterwarnings("ignore", message="use_inf_as_na option is deprecated", category=FutureWarning, module="seaborn")
warnings.filterwarnings("ignore", message=r"invalid value encountered in log10", category=RuntimeWarning, module=r".*specparam.*")

from specparam import Bands
from spk_feat_cluster_analysis import *
from spe1_plotting import *
from config import NPX_CHANNELS, CELL_IDS, DICT_PATCH_FS, DICT_CHAN_PRED, DICT_SPK_THRESH, FILTER_SETTINGS, SPE1_DATA_ROOT, SPE1_PICKLE_ROOT, LFP_FS

# %%
cell_num = 42

lfp_fs   = LFP_FS                    # from config
patch_fs = DICT_PATCH_FS[cell_num]

FORCE_LFP    = False  # True → reextract LFP windows even if pickle exists
FORCE_SIMPLE = False  # True → recompute simple LFP features even if pickle exists
FORCE_STATS  = False  # True → rerun sliding-window stats even if pickle exists

# %%
# Parameters
FORCE_LFP = True
FORCE_SIMPLE = True
FORCE_STATS = True

# %%
# Load pre-processed .npy recordings
lfp_dir   = os.path.join(SPE1_DATA_ROOT, 'filt_lfp_recordings',  f'c{cell_num}_lfp.npy')
patch_dir = os.path.join(SPE1_DATA_ROOT, 'filt_patch_recordings', f'c{cell_num}_patch.npy')

lfp_filt   = np.load(lfp_dir)
patch_filt = np.load(patch_dir)

lfp_times   = np.arange(len(lfp_filt))   / (lfp_fs   / 1000.0)  # ms
patch_times = np.arange(len(patch_filt)) / (patch_fs  / 1000.0)  # ms

# %%
# Load cluster DataFrame from pickle (run spe-1_c{cell_num}_clusters.ipynb first)
cluster_pickle = os.path.join(SPE1_PICKLE_ROOT, 'cluster_pickles', f'c{cell_num}_cluster_df.pkl')
with open(cluster_pickle, 'rb') as f:
    df_features_clust = pickle.load(f)
print(f"Loaded {len(df_features_clust)} spikes with columns: {[c for c in df_features_clust.columns if '_cluster' in c]}")
# Out:
# Loaded 828 spikes with columns: ['peak_amp_cluster', 'peak_width_cluster', 'log_isi_cluster']

# %%
# Load or extract LFP windows around each spike
lfp_win_pickle = os.path.join(SPE1_PICKLE_ROOT, 'lfp_window_pickles', f'c{cell_num}_lfp_windows.pkl')

if FORCE_LFP or not os.path.exists(lfp_win_pickle):
    all_spike_extractor = extract_lfp_windows(
        spk_df=df_features_clust,
        lfp_times_ms=lfp_times,
        lfp_signal=lfp_filt,
        pre_s=1.0, post_s=1.5,
        condition=None,
    )
    with open(lfp_win_pickle, 'wb') as f:
        pickle.dump(all_spike_extractor, f)
    print(f"  Saved: {os.path.basename(lfp_win_pickle)}")
else:
    print(f"  [cache] {os.path.basename(lfp_win_pickle)}")
    with open(lfp_win_pickle, 'rb') as f:
        all_spike_extractor = pickle.load(f)

windows_all     = all_spike_extractor["windows"]
t_rel_all       = all_spike_extractor["times_rel_ms"]
next_spk_all    = all_spike_extractor["next_spike_times_ms"]
# Out:
#   Saved: c42_lfp_windows.pkl

# %%
# Load pre-computed specparam chunks
chunk_dir = os.path.join(SPE1_PICKLE_ROOT, 'multitaper_pickles', f'c{cell_num}')
specparam_by_spike = load_chunked_specparam_results(save_dir=chunk_dir, prefix=f"c{cell_num}_specparam")
specparam_by_spike = trim_edges(specparam_by_spike, edge_sec=0.5)
print(f"Loaded specparam for {len(specparam_by_spike)} spikes")
# Out:
# No files found in /Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/multitaper_pickles/c42 starting with 'c42_specparam'.
# Loaded specparam for 0 spikes

# %%
groups = build_lfp_groups_from_clusters(df_features_clust, all_spike_extractor)
print(f"Groups: {list(groups.keys())}")
# Out:
# Groups: ['peak_amp_cluster: high', 'peak_amp_cluster: low', 'peak_width_cluster: low', 'peak_width_cluster: high', 'log_isi_cluster: high', 'log_isi_cluster: low']

# %%
# Compute (or load) simple LFP features per spike window
simple_pickle = os.path.join(SPE1_PICKLE_ROOT, 'simple_lfp_pickles', f'c{cell_num}_simple_lfp.pkl')

if FORCE_SIMPLE or not os.path.exists(simple_pickle):
    lfp_windows_by_spike = compute_simple_lfp_by_spike(
        windows_all=windows_all,
        times_rel_list=t_rel_all,
        fs=lfp_fs,
        inner_window_s=0.5,
        step_s=0.025,
        freq_range=(4, 90),
    )
    with open(simple_pickle, 'wb') as f:
        pickle.dump(lfp_windows_by_spike, f)
    print(f"  Saved: {os.path.basename(simple_pickle)}")
else:
    print(f"  [cache] {os.path.basename(simple_pickle)}")
    with open(simple_pickle, 'rb') as f:
        lfp_windows_by_spike = pickle.load(f)
# Out:
#   Saved: c42_simple_lfp.pkl

# %% [markdown]
# ## Run sliding-window LFP-spike group analysis

# %%
features_list = [
    {"feature": "exponent",     "label": "Aperiodic Exponent"},
    {"feature": "offset",       "label": "Aperiodic Offset"},
    {"feature": "band",  "band": "theta",  "label": "Theta AUC"},
    {"feature": "band",  "band": "beta",   "label": "Beta AUC"},
    {"feature": "band",  "band": "gamma",  "label": "Gamma AUC"},
    {"feature": "r_squared",    "label": "r-squared"},
    {"feature": "lfp_mean",     "label": "LFP Mean Amplitude"},
    {"feature": "lfp_std",      "label": "LFP Std"},
    {"feature": "lfp_exponent", "label": "LFP Spectral Exponent"},
]

master_results = run_master_LFP_spk_analysis(
    cell_id=str(cell_num),
    specparam_by_spike=specparam_by_spike,
    groups=groups,
    features_to_analyze=features_list,
    lfp_windows_by_spike=lfp_windows_by_spike,
    window_width=0.05,
    step_size=0.025,
    p_threshold=0.05,
    force_recompute=FORCE_STATS,
    plot=True,
)
# Out:
# ============================================================
#   RUNNING PIPELINE FOR: APERIODIC EXPONENT
# ============================================================
#
#
# ============================================================
#   RUNNING PIPELINE FOR: APERIODIC OFFSET
# ============================================================
#
#
# ============================================================
#   RUNNING PIPELINE FOR: THETA AUC
# ============================================================
#
#
# ============================================================
#   RUNNING PIPELINE FOR: BETA AUC
# ============================================================
#
#
# ============================================================
#   RUNNING PIPELINE FOR: GAMMA AUC
# ============================================================
#
#
# ============================================================
#   RUNNING PIPELINE FOR: R-SQUARED
# ============================================================
#
#
# ============================================================
#   RUNNING PIPELINE FOR: LFP MEAN AMPLITUDE
# ============================================================
# ============================================================
#   RUNNING PIPELINE FOR: LFP STD
# ============================================================
# ============================================================
#   RUNNING PIPELINE FOR: LFP SPECTRAL EXPONENT
# ============================================================
#   Saved: /Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/lfp_spk_group_pickles/42_sliding_stats.pkl
#   Saved: /Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/lfp_spk_group_pickles/42_per_spike_data.pkl

# %% [markdown]
# ## Plot significant windows

# %%
plot_significant_windows_spectra(df_features_clust, specparam_by_spike, master_results)
# Out:
# Extacting peak_amp_cluster at significant window: -0.750s to -0.625s
#   -> Failed to extract valid spectra at t=-0.6871813651299308s
#
# Extacting peak_amp_cluster at significant window: -0.475s to 0.400s
#   -> Failed to extract valid spectra at t=-0.03718136512993017s
#
# Extacting peak_amp_cluster at significant window: 0.500s to 1.225s
#   -> Failed to extract valid spectra at t=0.8628186348700706s
#
# Extacting peak_amp_cluster at significant window: -0.750s to -0.550s
#   -> Failed to extract valid spectra at t=-0.6496813651299307s
#
# Extacting peak_amp_cluster at significant window: -0.475s to 0.500s
#   -> Failed to extract valid spectra at t=0.0128186348700699s
#
# Extacting peak_amp_cluster at significant window: 0.750s to 1.225s
#   -> Failed to extract valid spectra at t=0.9878186348700707s
#
# Extacting peak_amp_cluster at significant window: -0.750s to -0.575s
#   -> Failed to extract valid spectra at t=-0.6621813651299306s
#
# Extacting peak_amp_cluster at significant window: -0.350s to -0.300s
#   -> Failed to extract valid spectra at t=-0.3246813651299304s
#
# Extacting peak_amp_cluster at significant window: -0.125s to -0.025s
#   -> Failed to extract valid spectra at t=-0.0746813651299302s
#
# Extacting peak_amp_cluster at significant window: 0.150s to 0.200s
#   -> Failed to extract valid spectra at t=0.17531863487007002s
#
# Extacting peak_width_cluster at significant window: -0.750s to -0.575s
#   -> Failed to extract valid spectra at t=-0.6622736523897144s
#
# Extacting peak_width_cluster at significant window: -0.450s to 0.350s
#   -> Failed to extract valid spectra at t=-0.0497736523897139s
#
# Extacting peak_width_cluster at significant window: 0.475s to 1.225s
#   -> Failed to extract valid spectra at t=0.8502263476102868s
#
# Extacting peak_width_cluster at significant window: -0.750s to -0.525s
#   -> Failed to extract valid spectra at t=-0.6372736523897145s
#
# Extacting peak_width_cluster at significant window: -0.450s to 0.450s
#   -> Failed to extract valid spectra at t=0.0002263476102861428s
#
# Extacting peak_width_cluster at significant window: 0.700s to 1.225s
#   -> Failed to extract valid spectra at t=0.962726347610287s
#
# Extacting peak_width_cluster at significant window: -0.525s to -0.250s
#   -> Failed to extract valid spectra at t=-0.38727365238971423s
#
# Extacting peak_width_cluster at significant window: -0.100s to 0.025s
#   -> Failed to extract valid spectra at t=-0.037273652389713884s
#
# Extacting peak_width_cluster at significant window: 0.350s to 0.400s
#   -> Failed to extract valid spectra at t=0.3752263476102865s
#
# Extacting log_isi_cluster at significant window: -0.750s to -0.525s
#   -> Failed to extract valid spectra at t=-0.6372736523897145s
#
# Extacting log_isi_cluster at significant window: -0.300s to 0.000s
#   -> Failed to extract valid spectra at t=-0.149773652389714s
#
# Extacting log_isi_cluster at significant window: 1.075s to 1.225s
#   -> Failed to extract valid spectra at t=1.1502263476102872s
#
# Extacting log_isi_cluster at significant window: -0.750s to -0.575s
#   -> Failed to extract valid spectra at t=-0.6622736523897144s
#
# Extacting log_isi_cluster at significant window: -0.425s to -0.250s
#   -> Failed to extract valid spectra at t=-0.3372736523897142s
#
# Extacting log_isi_cluster at significant window: 0.075s to 0.225s
#   -> Failed to extract valid spectra at t=0.15022634761028628s
#
# Extacting log_isi_cluster at significant window: 0.400s to 0.475s
#   -> Failed to extract valid spectra at t=0.4377263476102866s
#
# Extacting log_isi_cluster at significant window: 0.500s to 0.750s
#   -> Failed to extract valid spectra at t=0.6252263476102867s
#
# Extacting log_isi_cluster at significant window: 1.025s to 1.225s
#   -> Failed to extract valid spectra at t=1.1252263476102873s
#
# Extacting log_isi_cluster at significant window: -0.500s to -0.275s
#   -> Failed to extract valid spectra at t=-0.38727365238971423s
#
# Extacting log_isi_cluster at significant window: 0.400s to 0.550s
#   -> Failed to extract valid spectra at t=0.4752263476102866s
