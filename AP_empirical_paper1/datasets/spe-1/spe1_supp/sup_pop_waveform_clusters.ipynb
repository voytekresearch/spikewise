# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import importlib

sys.path.append('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/AP_empirical_paper1/datasets/spe-1/spe1_helper_modules/')
import spk_feat_cluster_comp_analysis
importlib.reload(spk_feat_cluster_comp_analysis)
from spk_feat_cluster_comp_analysis import (
    compile_experiment_results,
    patch_r2_into_cluster_pickles,
    plot_r2_overview,
    plot_feature_distribution_r2,
)

import config
from config import SPE1_PICKLE_ROOT

# %%
cluster_pickle_dir = '/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/cluster_pickles/'
spike_fit_dir      = '/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spe1_pickles/spike_fit_pickles/'

# R² is now embedded directly in cluster pickles by each cluster notebook.
# patch_r2_into_cluster_pickles is only needed as a backfill for old pickles
# that were saved before this change.
patch_r2_into_cluster_pickles(spike_fit_dir, cluster_pickle_dir, force=False)

# %%
df_master = compile_experiment_results(cluster_pickle_dir)
df_master.head()

# %% [markdown]
# ## Cluster R² by feature distribution — exp decay
#
# Each panel = one cell × one spike feature with ≥2 detected clusters.
# **x-axis** = spike feature value.  **y-axis** = cluster label (low / mid / high, with jitter).
# **Color** = per-spike exp-decay R² on viridis (dark = low R², yellow = high R²).
# Shows whether fit quality (R²) varies across the feature distribution and across cluster assignments.

# %%
plot_r2_overview(cluster_pickle_dir, r2_type='exp')

# %%
plot_feature_distribution_r2(
    df_master,
    cluster_pickle_dir,
    r2_type='exp',
)

# %% [markdown]
# ## Cluster R² by feature distribution — ramp fit
#
# Same layout as above but color encodes per-spike ramp-fit R².

# %%
plot_r2_overview(cluster_pickle_dir, r2_type='ramp')

# %%
plot_feature_distribution_r2(
    df_master,
    cluster_pickle_dir,
    r2_type='ramp',
)
