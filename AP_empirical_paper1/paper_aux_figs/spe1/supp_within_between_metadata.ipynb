# %% [markdown]
# # Supplementary: Within-between variability vs cell metadata
#
# **Purpose:** Examine whether the % of within-cell spikes exceeding the median between-cell nRMSE threshold relates to cell-level metadata (cell type, patch type, current type, cortical depth).

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import sys
import importlib

sys.path.append('/Users/blancamartin/Desktop/Voytek_Lab/spike_waveform/spikeparam/AP_empirical_paper1/datasets/spe-1/spe1_helper_modules/')
import spk_feat_cluster_comp_analysis
importlib.reload(spk_feat_cluster_comp_analysis)
from spk_feat_cluster_comp_analysis import (
    compile_experiment_results,
    plot_pct_within_vs_metadata,
)
import config

CLUSTER_PKL_DIR = config.SPE1_PICKLE_ROOT + '/cluster_pickles/'
SPIKE_FIT_DIR   = config.SPE1_PICKLE_ROOT + '/spike_fit_pickles/'

# %%
df_master = compile_experiment_results(CLUSTER_PKL_DIR)

# %% [markdown]
# ## Within-cell % above between-cell threshold vs metadata
#
# Panels: **cell type** (PC vs IN) · **patch type** (Juxta vs WC) · **current type** (IC vs VC) · **cortical depth** (scatter)

# %%
plot_pct_within_vs_metadata(
    df_master,
    wf_dir=CLUSTER_PKL_DIR,
    spike_fit_dir=SPIKE_FIT_DIR,
)

# %% [markdown]
# ---
# ## Figure caption (draft)
#
# **Supplementary Figure X. Within-cell waveform variability vs cell metadata.**
#
# *[Caption placeholder — fill in after reviewing output.]*
